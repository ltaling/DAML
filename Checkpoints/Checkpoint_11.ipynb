# %%
import numpy as np
import pandas as pd
import math
import matplotlib.pyplot as plt

# %%
# Read in the files 

truthData = pd.read_csv( "output_nt_Truth.csv", comment="#", names=[ "EventID", "Phi", "Theta", "Momentum" ] )
tracker1Data = pd.read_csv( "output_nt_Tracker1.csv", comment="#", names=[ "EventID", "Phi", "Theta" ] )
tracker2Data = pd.read_csv( "output_nt_Tracker2.csv", comment="#", names=[ "EventID", "Phi", "Theta" ] )

# %% [markdown]
# # Part 1

# %%
# Initialise empty arrays
TrueParticles = []
Layer1Hits = []
Layer2Hits = []

# Loop over all 1000 events
for i in range(1000):
    TrueParticles.append(len(truthData.EventID[truthData.EventID == i])) # sums the number of entries corresponding to event i
    Layer1Hits.append(len(tracker1Data.EventID[tracker1Data.EventID == i]))# sums the number of entries corresponding to event i
    Layer2Hits.append(len(tracker2Data.EventID[tracker2Data.EventID == i]))# sums the number of entries corresponding to event i

# Loop over the events to print them
for j in range(1000):
    print("Number of true particles in event {:} = {:}".format(j,TrueParticles[j]))
    print("Number of layer 1 hits in event {:} = {:}".format(j,Layer1Hits[j]))
    print("Number of layer 2 hits in event {:} = {:}".format(j,Layer2Hits[j]))
    print("")
    
# These values appear correct as they match up to what I see when opening the .csv file in excel
# Out:
# Number of true particles in event 0 = 2
# Number of layer 1 hits in event 0 = 0
# Number of layer 2 hits in event 0 = 1
#
# Number of true particles in event 1 = 2
# Number of layer 1 hits in event 1 = 2
# Number of layer 2 hits in event 1 = 7
#
# Number of true particles in event 2 = 2
# Number of layer 1 hits in event 2 = 2
# Number of layer 2 hits in event 2 = 2
#
# Number of true particles in event 3 = 2
# Number of layer 1 hits in event 3 = 2
# Number of layer 2 hits in event 3 = 6
#
# Number of true particles in event 4 = 2
# Number of layer 1 hits in event 4 = 34
# Number of layer 2 hits in event 4 = 2
#
# Number of true particles in event 5 = 2
# Number of layer 1 hits in event 5 = 2
# Number of layer 2 hits in event 5 = 2
#
# Number of true particles in event 6 = 2
# Number of layer 1 hits in event 6 = 20
# Number of layer 2 hits in event 6 = 8
#
# Number of true particles in event 7 = 2
# Number of layer 1 hits in event 7 = 0
# Number of layer 2 hits in event 7 = 0
#
# Number of true particles in event 8 = 2
# Number of layer 1 hits in event 8 = 0
# Number of layer 2 hits in event 8 = 0
#
# Number of true particles in event 9 = 2
# Number of layer 1 hits in event 9 = 0
# Number of layer 2 hits in event 9 = 0
#
# Number of true particles in event 10 = 2
# Number of layer 1 hits in event 10 = 0
# Number of layer 2 hits in event 10 = 0
#
# Number of true particles in event 11 = 2
# Number of layer 1 hits in event 11 = 0
# Number of layer 2 hits in event 11 = 0
#
# Number of true particles in event 12 = 2
# Number of layer 1 hits in event 12 = 0
# Number of layer 2 hits in event 12 = 0
#
# Number of true particles in event 13 = 2
# Number of layer 1 hits in event 13 = 13
# Number of layer 2 hits in event 13 = 15
#
# Number of true particles in event 14 = 2
# Number of layer 1 hits in event 14 = 2
# Number of layer 2 hits in event 14 = 2
#
# Number of true particles in event 15 = 2
# Number of layer 1 hits in event 15 = 0
# Number of layer 2 hits in event 15 = 0
#
# Number of true particles in event 16 = 2
# Number of layer 1 hits in event 16 = 0
# Number of layer 2 hits in event 16 = 0
#
# Number of true particles in event 17 = 2
# Number of layer 1 hits in event 17 = 2
# Number of layer 2 hits in event 17 = 2
#
# Number of true particles in event 18 = 2
# Number of layer 1 hits in event 18 = 2
# Number of layer 2 hits in event 18 = 2
#
# Number of true particles in event 19 = 2
# Number of layer 1 hits in event 19 = 0
# Number of layer 2 hits in event 19 = 0
#
# Number of true particles in event 20 = 2
# Number of layer 1 hits in event 20 = 2
# Number of layer 2 hits in event 20 = 2
#
# Number of true particles in event 21 = 2
# Number of layer 1 hits in event 21 = 0
# Number of layer 2 hits in event 21 = 0
#
# Number of true particles in event 22 = 2
# Number of layer 1 hits in event 22 = 0
# Number of layer 2 hits in event 22 = 0
#
# Number of true particles in event 23 = 2
# Number of layer 1 hits in event 23 = 2
# Number of layer 2 hits in event 23 = 2
#
# Number of true particles in event 24 = 2
# Number of layer 1 hits in event 24 = 2
# Number of layer 2 hits in event 24 = 2
#
# Number of true particles in event 25 = 2
# Number of layer 1 hits in event 25 = 2
# Number of layer 2 hits in event 25 = 11
#
# Number of true particles in event 26 = 2
# Number of layer 1 hits in event 26 = 1
# Number of layer 2 hits in event 26 = 1
#
# Number of true particles in event 27 = 2
# Number of layer 1 hits in event 27 = 2
# Number of layer 2 hits in event 27 = 2
#
# Number of true particles in event 28 = 2
# Number of layer 1 hits in event 28 = 0
# Number of layer 2 hits in event 28 = 0
#
# Number of true particles in event 29 = 2
# Number of layer 1 hits in event 29 = 0
# Number of layer 2 hits in event 29 = 0
#
# Number of true particles in event 30 = 2
# Number of layer 1 hits in event 30 = 2
# Number of layer 2 hits in event 30 = 2
#
# Number of true particles in event 31 = 2
# Number of layer 1 hits in event 31 = 0
# Number of layer 2 hits in event 31 = 0
#
# Number of true particles in event 32 = 2
# Number of layer 1 hits in event 32 = 2
# Number of layer 2 hits in event 32 = 17
#
# Number of true particles in event 33 = 2
# Number of layer 1 hits in event 33 = 6
# Number of layer 2 hits in event 33 = 2
#
# Number of true particles in event 34 = 2
# Number of layer 1 hits in event 34 = 2
# Number of layer 2 hits in event 34 = 7
#
# Number of true particles in event 35 = 2
# Number of layer 1 hits in event 35 = 2
# Number of layer 2 hits in event 35 = 27
#
# Number of true particles in event 36 = 2
# Number of layer 1 hits in event 36 = 0
# Number of layer 2 hits in event 36 = 0
#
# Number of true particles in event 37 = 2
# Number of layer 1 hits in event 37 = 2
# Number of layer 2 hits in event 37 = 28
#
# Number of true particles in event 38 = 2
# Number of layer 1 hits in event 38 = 2
# Number of layer 2 hits in event 38 = 2
#
# Number of true particles in event 39 = 2
# Number of layer 1 hits in event 39 = 0
# Number of layer 2 hits in event 39 = 0
#
# Number of true particles in event 40 = 2
# Number of layer 1 hits in event 40 = 2
# Number of layer 2 hits in event 40 = 2
#
# Number of true particles in event 41 = 2
# Number of layer 1 hits in event 41 = 2
# Number of layer 2 hits in event 41 = 2
#
# Number of true particles in event 42 = 2
# Number of layer 1 hits in event 42 = 2
# Number of layer 2 hits in event 42 = 2
#
# Number of true particles in event 43 = 2
# Number of layer 1 hits in event 43 = 0
# Number of layer 2 hits in event 43 = 0
#
# Number of true particles in event 44 = 2
# Number of layer 1 hits in event 44 = 2
# Number of layer 2 hits in event 44 = 2
#
# Number of true particles in event 45 = 2
# Number of layer 1 hits in event 45 = 2
# Number of layer 2 hits in event 45 = 2
#
# Number of true particles in event 46 = 2
# Number of layer 1 hits in event 46 = 0
# Number of layer 2 hits in event 46 = 0
#
# Number of true particles in event 47 = 2
# Number of layer 1 hits in event 47 = 2
# Number of layer 2 hits in event 47 = 2
#
# Number of true particles in event 48 = 2
# Number of layer 1 hits in event 48 = 2
# Number of layer 2 hits in event 48 = 8
#
# Number of true particles in event 49 = 2
# Number of layer 1 hits in event 49 = 10
# Number of layer 2 hits in event 49 = 2
#
# Number of true particles in event 50 = 2
# Number of layer 1 hits in event 50 = 0
# Number of layer 2 hits in event 50 = 0
#
# Number of true particles in event 51 = 2
# Number of layer 1 hits in event 51 = 2
# Number of layer 2 hits in event 51 = 2
#
# Number of true particles in event 52 = 2
# Number of layer 1 hits in event 52 = 2
# Number of layer 2 hits in event 52 = 21
#
# Number of true particles in event 53 = 2
# Number of layer 1 hits in event 53 = 2
# Number of layer 2 hits in event 53 = 2
#
# Number of true particles in event 54 = 2
# Number of layer 1 hits in event 54 = 2
# Number of layer 2 hits in event 54 = 2
#
# Number of true particles in event 55 = 2
# Number of layer 1 hits in event 55 = 2
# Number of layer 2 hits in event 55 = 2
#
# Number of true particles in event 56 = 2
# Number of layer 1 hits in event 56 = 2
# Number of layer 2 hits in event 56 = 2
#
# Number of true particles in event 57 = 2
# Number of layer 1 hits in event 57 = 0
# Number of layer 2 hits in event 57 = 0
#
# Number of true particles in event 58 = 2
# Number of layer 1 hits in event 58 = 3
# Number of layer 2 hits in event 58 = 2
#
# Number of true particles in event 59 = 2
# Number of layer 1 hits in event 59 = 6
# Number of layer 2 hits in event 59 = 2
#
# Number of true particles in event 60 = 2
# Number of layer 1 hits in event 60 = 0
# Number of layer 2 hits in event 60 = 0
#
# Number of true particles in event 61 = 2
# Number of layer 1 hits in event 61 = 2
# Number of layer 2 hits in event 61 = 2
#
# Number of true particles in event 62 = 2
# Number of layer 1 hits in event 62 = 3
# Number of layer 2 hits in event 62 = 2
#
# Number of true particles in event 63 = 2
# Number of layer 1 hits in event 63 = 0
# Number of layer 2 hits in event 63 = 0
#
# Number of true particles in event 64 = 2
# Number of layer 1 hits in event 64 = 2
# Number of layer 2 hits in event 64 = 19
#
# Number of true particles in event 65 = 2
# Number of layer 1 hits in event 65 = 2
# Number of layer 2 hits in event 65 = 2
#
# Number of true particles in event 66 = 2
# Number of layer 1 hits in event 66 = 0
# Number of layer 2 hits in event 66 = 0
#
# Number of true particles in event 67 = 2
# Number of layer 1 hits in event 67 = 2
# Number of layer 2 hits in event 67 = 2
#
# Number of true particles in event 68 = 2
# Number of layer 1 hits in event 68 = 0
# Number of layer 2 hits in event 68 = 0
#
# Number of true particles in event 69 = 2
# Number of layer 1 hits in event 69 = 0
# Number of layer 2 hits in event 69 = 0
#
# Number of true particles in event 70 = 2
# Number of layer 1 hits in event 70 = 0
# Number of layer 2 hits in event 70 = 0
#
# Number of true particles in event 71 = 2
# Number of layer 1 hits in event 71 = 3
# Number of layer 2 hits in event 71 = 2
#
# Number of true particles in event 72 = 2
# Number of layer 1 hits in event 72 = 2
# Number of layer 2 hits in event 72 = 8
#
# Number of true particles in event 73 = 2
# Number of layer 1 hits in event 73 = 0
# Number of layer 2 hits in event 73 = 0
#
# Number of true particles in event 74 = 2
# Number of layer 1 hits in event 74 = 0
# Number of layer 2 hits in event 74 = 0
#
# Number of true particles in event 75 = 2
# Number of layer 1 hits in event 75 = 2
# Number of layer 2 hits in event 75 = 2
#
# Number of true particles in event 76 = 2
# Number of layer 1 hits in event 76 = 0
# Number of layer 2 hits in event 76 = 0
#
# Number of true particles in event 77 = 2
# Number of layer 1 hits in event 77 = 0
# Number of layer 2 hits in event 77 = 0
#
# Number of true particles in event 78 = 2
# Number of layer 1 hits in event 78 = 2
# Number of layer 2 hits in event 78 = 2
#
# Number of true particles in event 79 = 2
# Number of layer 1 hits in event 79 = 0
# Number of layer 2 hits in event 79 = 0
#
# Number of true particles in event 80 = 2
# Number of layer 1 hits in event 80 = 2
# Number of layer 2 hits in event 80 = 2
#
# Number of true particles in event 81 = 2
# Number of layer 1 hits in event 81 = 2
# Number of layer 2 hits in event 81 = 2
#
# Number of true particles in event 82 = 2
# Number of layer 1 hits in event 82 = 2
# Number of layer 2 hits in event 82 = 20
#
# Number of true particles in event 83 = 2
# Number of layer 1 hits in event 83 = 8
# Number of layer 2 hits in event 83 = 12
#
# Number of true particles in event 84 = 2
# Number of layer 1 hits in event 84 = 0
# Number of layer 2 hits in event 84 = 0
#
# Number of true particles in event 85 = 2
# Number of layer 1 hits in event 85 = 2
# Number of layer 2 hits in event 85 = 2
#
# Number of true particles in event 86 = 2
# Number of layer 1 hits in event 86 = 2
# Number of layer 2 hits in event 86 = 9
#
# Number of true particles in event 87 = 2
# Number of layer 1 hits in event 87 = 0
# Number of layer 2 hits in event 87 = 0
#
# Number of true particles in event 88 = 2
# Number of layer 1 hits in event 88 = 2
# Number of layer 2 hits in event 88 = 2
#
# Number of true particles in event 89 = 2
# Number of layer 1 hits in event 89 = 2
# Number of layer 2 hits in event 89 = 2
#
# Number of true particles in event 90 = 2
# Number of layer 1 hits in event 90 = 0
# Number of layer 2 hits in event 90 = 0
#
# Number of true particles in event 91 = 2
# Number of layer 1 hits in event 91 = 2
# Number of layer 2 hits in event 91 = 2
#
# Number of true particles in event 92 = 2
# Number of layer 1 hits in event 92 = 0
# Number of layer 2 hits in event 92 = 0
#
# Number of true particles in event 93 = 2
# Number of layer 1 hits in event 93 = 0
# Number of layer 2 hits in event 93 = 0
#
# Number of true particles in event 94 = 2
# Number of layer 1 hits in event 94 = 0
# Number of layer 2 hits in event 94 = 0
#
# Number of true particles in event 95 = 2
# Number of layer 1 hits in event 95 = 0
# Number of layer 2 hits in event 95 = 0
#
# Number of true particles in event 96 = 2
# Number of layer 1 hits in event 96 = 0
# Number of layer 2 hits in event 96 = 0
#
# Number of true particles in event 97 = 2
# Number of layer 1 hits in event 97 = 0
# Number of layer 2 hits in event 97 = 0
#
# Number of true particles in event 98 = 2
# Number of layer 1 hits in event 98 = 2
# Number of layer 2 hits in event 98 = 76
#
# Number of true particles in event 99 = 2
# Number of layer 1 hits in event 99 = 2
# Number of layer 2 hits in event 99 = 2
#
# Number of true particles in event 100 = 2
# Number of layer 1 hits in event 100 = 2
# Number of layer 2 hits in event 100 = 7
#
# Number of true particles in event 101 = 2
# Number of layer 1 hits in event 101 = 2
# Number of layer 2 hits in event 101 = 2
#
# Number of true particles in event 102 = 2
# Number of layer 1 hits in event 102 = 2
# Number of layer 2 hits in event 102 = 2
#
# Number of true particles in event 103 = 2
# Number of layer 1 hits in event 103 = 0
# Number of layer 2 hits in event 103 = 0
#
# Number of true particles in event 104 = 2
# Number of layer 1 hits in event 104 = 2
# Number of layer 2 hits in event 104 = 2
#
# Number of true particles in event 105 = 2
# Number of layer 1 hits in event 105 = 0
# Number of layer 2 hits in event 105 = 0
#
# Number of true particles in event 106 = 2
# Number of layer 1 hits in event 106 = 2
# Number of layer 2 hits in event 106 = 2
#
# Number of true particles in event 107 = 2
# Number of layer 1 hits in event 107 = 2
# Number of layer 2 hits in event 107 = 2
#
# Number of true particles in event 108 = 2
# Number of layer 1 hits in event 108 = 0
# Number of layer 2 hits in event 108 = 0
#
# Number of true particles in event 109 = 2
# Number of layer 1 hits in event 109 = 15
# Number of layer 2 hits in event 109 = 2
#
# Number of true particles in event 110 = 2
# Number of layer 1 hits in event 110 = 2
# Number of layer 2 hits in event 110 = 2
#
# Number of true particles in event 111 = 2
# Number of layer 1 hits in event 111 = 2
# Number of layer 2 hits in event 111 = 26
#
# Number of true particles in event 112 = 2
# Number of layer 1 hits in event 112 = 2
# Number of layer 2 hits in event 112 = 2
#
# Number of true particles in event 113 = 2
# Number of layer 1 hits in event 113 = 0
# Number of layer 2 hits in event 113 = 0
#
# Number of true particles in event 114 = 2
# Number of layer 1 hits in event 114 = 0
# Number of layer 2 hits in event 114 = 0
#
# Number of true particles in event 115 = 2
# Number of layer 1 hits in event 115 = 2
# Number of layer 2 hits in event 115 = 2
#
# Number of true particles in event 116 = 2
# Number of layer 1 hits in event 116 = 2
# Number of layer 2 hits in event 116 = 2
#
# Number of true particles in event 117 = 2
# Number of layer 1 hits in event 117 = 2
# Number of layer 2 hits in event 117 = 40
#
# Number of true particles in event 118 = 2
# Number of layer 1 hits in event 118 = 2
# Number of layer 2 hits in event 118 = 2
#
# Number of true particles in event 119 = 2
# Number of layer 1 hits in event 119 = 2
# Number of layer 2 hits in event 119 = 2
#
# Number of true particles in event 120 = 2
# Number of layer 1 hits in event 120 = 0
# Number of layer 2 hits in event 120 = 0
#
# Number of true particles in event 121 = 2
# Number of layer 1 hits in event 121 = 17
# Number of layer 2 hits in event 121 = 2
#
# Number of true particles in event 122 = 2
# Number of layer 1 hits in event 122 = 2
# Number of layer 2 hits in event 122 = 16
#
# Number of true particles in event 123 = 2
# Number of layer 1 hits in event 123 = 0
# Number of layer 2 hits in event 123 = 0
#
# Number of true particles in event 124 = 2
# Number of layer 1 hits in event 124 = 0
# Number of layer 2 hits in event 124 = 0
#
# Number of true particles in event 125 = 2
# Number of layer 1 hits in event 125 = 0
# Number of layer 2 hits in event 125 = 0
#
# Number of true particles in event 126 = 2
# Number of layer 1 hits in event 126 = 5
# Number of layer 2 hits in event 126 = 2
#
# Number of true particles in event 127 = 2
# Number of layer 1 hits in event 127 = 0
# Number of layer 2 hits in event 127 = 0
#
# Number of true particles in event 128 = 2
# Number of layer 1 hits in event 128 = 37
# Number of layer 2 hits in event 128 = 2
#
# Number of true particles in event 129 = 2
# Number of layer 1 hits in event 129 = 2
# Number of layer 2 hits in event 129 = 2
#
# Number of true particles in event 130 = 2
# Number of layer 1 hits in event 130 = 2
# Number of layer 2 hits in event 130 = 17
#
# Number of true particles in event 131 = 2
# Number of layer 1 hits in event 131 = 2
# Number of layer 2 hits in event 131 = 2
#
# Number of true particles in event 132 = 2
# Number of layer 1 hits in event 132 = 2
# Number of layer 2 hits in event 132 = 2
#
# Number of true particles in event 133 = 2
# Number of layer 1 hits in event 133 = 2
# Number of layer 2 hits in event 133 = 2
#
# Number of true particles in event 134 = 2
# Number of layer 1 hits in event 134 = 0
# Number of layer 2 hits in event 134 = 0
#
# Number of true particles in event 135 = 2
# Number of layer 1 hits in event 135 = 15
# Number of layer 2 hits in event 135 = 2
#
# Number of true particles in event 136 = 2
# Number of layer 1 hits in event 136 = 2
# Number of layer 2 hits in event 136 = 10
#
# Number of true particles in event 137 = 2
# Number of layer 1 hits in event 137 = 0
# Number of layer 2 hits in event 137 = 0
#
# Number of true particles in event 138 = 2
# Number of layer 1 hits in event 138 = 2
# Number of layer 2 hits in event 138 = 2
#
# Number of true particles in event 139 = 2
# Number of layer 1 hits in event 139 = 2
# Number of layer 2 hits in event 139 = 2
#
# Number of true particles in event 140 = 2
# Number of layer 1 hits in event 140 = 2
# Number of layer 2 hits in event 140 = 14
#
# Number of true particles in event 141 = 2
# Number of layer 1 hits in event 141 = 0
# Number of layer 2 hits in event 141 = 0
#
# Number of true particles in event 142 = 2
# Number of layer 1 hits in event 142 = 2
# Number of layer 2 hits in event 142 = 2
#
# Number of true particles in event 143 = 2
# Number of layer 1 hits in event 143 = 2
# Number of layer 2 hits in event 143 = 2
#
# Number of true particles in event 144 = 2
# Number of layer 1 hits in event 144 = 3
# Number of layer 2 hits in event 144 = 2
#
# Number of true particles in event 145 = 2
# Number of layer 1 hits in event 145 = 2
# Number of layer 2 hits in event 145 = 2
#
# Number of true particles in event 146 = 2
# Number of layer 1 hits in event 146 = 0
# Number of layer 2 hits in event 146 = 0
#
# Number of true particles in event 147 = 2
# Number of layer 1 hits in event 147 = 39
# Number of layer 2 hits in event 147 = 2
#
# Number of true particles in event 148 = 2
# Number of layer 1 hits in event 148 = 2
# Number of layer 2 hits in event 148 = 19
#
# Number of true particles in event 149 = 2
# Number of layer 1 hits in event 149 = 0
# Number of layer 2 hits in event 149 = 0
#
# Number of true particles in event 150 = 2
# Number of layer 1 hits in event 150 = 2
# Number of layer 2 hits in event 150 = 2
#
# Number of true particles in event 151 = 2
# Number of layer 1 hits in event 151 = 0
# Number of layer 2 hits in event 151 = 1
#
# Number of true particles in event 152 = 2
# Number of layer 1 hits in event 152 = 2
# Number of layer 2 hits in event 152 = 2
#
# Number of true particles in event 153 = 2
# Number of layer 1 hits in event 153 = 2
# Number of layer 2 hits in event 153 = 2
#
# Number of true particles in event 154 = 2
# Number of layer 1 hits in event 154 = 0
# Number of layer 2 hits in event 154 = 0
#
# Number of true particles in event 155 = 2
# Number of layer 1 hits in event 155 = 0
# Number of layer 2 hits in event 155 = 0
#
# Number of true particles in event 156 = 2
# Number of layer 1 hits in event 156 = 0
# Number of layer 2 hits in event 156 = 0
#
# Number of true particles in event 157 = 2
# Number of layer 1 hits in event 157 = 0
# Number of layer 2 hits in event 157 = 0
#
# Number of true particles in event 158 = 2
# Number of layer 1 hits in event 158 = 2
# Number of layer 2 hits in event 158 = 2
#
# Number of true particles in event 159 = 2
# Number of layer 1 hits in event 159 = 0
# Number of layer 2 hits in event 159 = 0
#
# Number of true particles in event 160 = 2
# Number of layer 1 hits in event 160 = 0
# Number of layer 2 hits in event 160 = 0
#
# Number of true particles in event 161 = 2
# Number of layer 1 hits in event 161 = 0
# Number of layer 2 hits in event 161 = 0
#
# Number of true particles in event 162 = 2
# Number of layer 1 hits in event 162 = 2
# Number of layer 2 hits in event 162 = 2
#
# Number of true particles in event 163 = 2
# Number of layer 1 hits in event 163 = 0
# Number of layer 2 hits in event 163 = 0
#
# Number of true particles in event 164 = 2
# Number of layer 1 hits in event 164 = 0
# Number of layer 2 hits in event 164 = 0
#
# Number of true particles in event 165 = 2
# Number of layer 1 hits in event 165 = 2
# Number of layer 2 hits in event 165 = 6
#
# Number of true particles in event 166 = 2
# Number of layer 1 hits in event 166 = 2
# Number of layer 2 hits in event 166 = 2
#
# Number of true particles in event 167 = 2
# Number of layer 1 hits in event 167 = 2
# Number of layer 2 hits in event 167 = 3
#
# Number of true particles in event 168 = 2
# Number of layer 1 hits in event 168 = 0
# Number of layer 2 hits in event 168 = 0
#
# Number of true particles in event 169 = 2
# Number of layer 1 hits in event 169 = 0
# Number of layer 2 hits in event 169 = 0
#
# Number of true particles in event 170 = 2
# Number of layer 1 hits in event 170 = 0
# Number of layer 2 hits in event 170 = 0
#
# Number of true particles in event 171 = 2
# Number of layer 1 hits in event 171 = 2
# Number of layer 2 hits in event 171 = 2
#
# Number of true particles in event 172 = 2
# Number of layer 1 hits in event 172 = 2
# Number of layer 2 hits in event 172 = 9
#
# Number of true particles in event 173 = 2
# Number of layer 1 hits in event 173 = 3
# Number of layer 2 hits in event 173 = 17
#
# Number of true particles in event 174 = 2
# Number of layer 1 hits in event 174 = 2
# Number of layer 2 hits in event 174 = 2
#
# Number of true particles in event 175 = 2
# Number of layer 1 hits in event 175 = 0
# Number of layer 2 hits in event 175 = 0
#
# Number of true particles in event 176 = 2
# Number of layer 1 hits in event 176 = 0
# Number of layer 2 hits in event 176 = 0
#
# Number of true particles in event 177 = 2
# Number of layer 1 hits in event 177 = 2
# Number of layer 2 hits in event 177 = 2
#
# Number of true particles in event 178 = 2
# Number of layer 1 hits in event 178 = 2
# Number of layer 2 hits in event 178 = 2
#
# Number of true particles in event 179 = 2
# Number of layer 1 hits in event 179 = 2
# Number of layer 2 hits in event 179 = 2
#
# Number of true particles in event 180 = 2
# Number of layer 1 hits in event 180 = 2
# Number of layer 2 hits in event 180 = 2
#
# Number of true particles in event 181 = 2
# Number of layer 1 hits in event 181 = 0
# Number of layer 2 hits in event 181 = 0
#
# Number of true particles in event 182 = 2
# Number of layer 1 hits in event 182 = 2
# Number of layer 2 hits in event 182 = 13
#
# Number of true particles in event 183 = 2
# Number of layer 1 hits in event 183 = 9
# Number of layer 2 hits in event 183 = 2
#
# Number of true particles in event 184 = 2
# Number of layer 1 hits in event 184 = 2
# Number of layer 2 hits in event 184 = 2
#
# Number of true particles in event 185 = 2
# Number of layer 1 hits in event 185 = 2
# Number of layer 2 hits in event 185 = 2
#
# Number of true particles in event 186 = 2
# Number of layer 1 hits in event 186 = 2
# Number of layer 2 hits in event 186 = 2
#
# Number of true particles in event 187 = 2
# Number of layer 1 hits in event 187 = 0
# Number of layer 2 hits in event 187 = 0
#
# Number of true particles in event 188 = 2
# Number of layer 1 hits in event 188 = 2
# Number of layer 2 hits in event 188 = 2
#
# Number of true particles in event 189 = 2
# Number of layer 1 hits in event 189 = 0
# Number of layer 2 hits in event 189 = 0
#
# Number of true particles in event 190 = 2
# Number of layer 1 hits in event 190 = 18
# Number of layer 2 hits in event 190 = 2
#
# Number of true particles in event 191 = 2
# Number of layer 1 hits in event 191 = 0
# Number of layer 2 hits in event 191 = 0
#
# Number of true particles in event 192 = 2
# Number of layer 1 hits in event 192 = 2
# Number of layer 2 hits in event 192 = 2
#
# Number of true particles in event 193 = 2
# Number of layer 1 hits in event 193 = 18
# Number of layer 2 hits in event 193 = 2
#
# Number of true particles in event 194 = 2
# Number of layer 1 hits in event 194 = 0
# Number of layer 2 hits in event 194 = 0
#
# Number of true particles in event 195 = 2
# Number of layer 1 hits in event 195 = 8
# Number of layer 2 hits in event 195 = 2
#
# Number of true particles in event 196 = 2
# Number of layer 1 hits in event 196 = 0
# Number of layer 2 hits in event 196 = 0
#
# Number of true particles in event 197 = 2
# Number of layer 1 hits in event 197 = 0
# Number of layer 2 hits in event 197 = 0
#
# Number of true particles in event 198 = 2
# Number of layer 1 hits in event 198 = 0
# Number of layer 2 hits in event 198 = 0
#
# Number of true particles in event 199 = 2
# Number of layer 1 hits in event 199 = 0
# Number of layer 2 hits in event 199 = 0
#
# Number of true particles in event 200 = 2
# Number of layer 1 hits in event 200 = 0
# Number of layer 2 hits in event 200 = 0
#
# Number of true particles in event 201 = 2
# Number of layer 1 hits in event 201 = 0
# Number of layer 2 hits in event 201 = 0
#
# Number of true particles in event 202 = 2
# Number of layer 1 hits in event 202 = 0
# Number of layer 2 hits in event 202 = 0
#
# Number of true particles in event 203 = 2
# Number of layer 1 hits in event 203 = 2
# Number of layer 2 hits in event 203 = 2
#
# Number of true particles in event 204 = 2
# Number of layer 1 hits in event 204 = 2
# Number of layer 2 hits in event 204 = 2
#
# Number of true particles in event 205 = 2
# Number of layer 1 hits in event 205 = 2
# Number of layer 2 hits in event 205 = 2
#
# Number of true particles in event 206 = 2
# Number of layer 1 hits in event 206 = 2
# Number of layer 2 hits in event 206 = 2
#
# Number of true particles in event 207 = 2
# Number of layer 1 hits in event 207 = 0
# Number of layer 2 hits in event 207 = 0
#
# Number of true particles in event 208 = 2
# Number of layer 1 hits in event 208 = 2
# Number of layer 2 hits in event 208 = 2
#
# Number of true particles in event 209 = 2
# Number of layer 1 hits in event 209 = 2
# Number of layer 2 hits in event 209 = 2
#
# Number of true particles in event 210 = 2
# Number of layer 1 hits in event 210 = 38
# Number of layer 2 hits in event 210 = 2
#
# Number of true particles in event 211 = 2
# Number of layer 1 hits in event 211 = 0
# Number of layer 2 hits in event 211 = 0
#
# Number of true particles in event 212 = 2
# Number of layer 1 hits in event 212 = 2
# Number of layer 2 hits in event 212 = 2
#
# Number of true particles in event 213 = 2
# Number of layer 1 hits in event 213 = 25
# Number of layer 2 hits in event 213 = 2
#
# Number of true particles in event 214 = 2
# Number of layer 1 hits in event 214 = 2
# Number of layer 2 hits in event 214 = 2
#
# Number of true particles in event 215 = 2
# Number of layer 1 hits in event 215 = 2
# Number of layer 2 hits in event 215 = 2
#
# Number of true particles in event 216 = 2
# Number of layer 1 hits in event 216 = 0
# Number of layer 2 hits in event 216 = 0
#
# Number of true particles in event 217 = 2
# Number of layer 1 hits in event 217 = 0
# Number of layer 2 hits in event 217 = 0
#
# Number of true particles in event 218 = 2
# Number of layer 1 hits in event 218 = 2
# Number of layer 2 hits in event 218 = 2
#
# Number of true particles in event 219 = 2
# Number of layer 1 hits in event 219 = 2
# Number of layer 2 hits in event 219 = 13
#
# Number of true particles in event 220 = 2
# Number of layer 1 hits in event 220 = 0
# Number of layer 2 hits in event 220 = 0
#
# Number of true particles in event 221 = 2
# Number of layer 1 hits in event 221 = 7
# Number of layer 2 hits in event 221 = 2
#
# Number of true particles in event 222 = 2
# Number of layer 1 hits in event 222 = 0
# Number of layer 2 hits in event 222 = 0
#
# Number of true particles in event 223 = 2
# Number of layer 1 hits in event 223 = 2
# Number of layer 2 hits in event 223 = 2
#
# Number of true particles in event 224 = 2
# Number of layer 1 hits in event 224 = 0
# Number of layer 2 hits in event 224 = 0
#
# Number of true particles in event 225 = 2
# Number of layer 1 hits in event 225 = 2
# Number of layer 2 hits in event 225 = 2
#
# Number of true particles in event 226 = 2
# Number of layer 1 hits in event 226 = 2
# Number of layer 2 hits in event 226 = 4
#
# Number of true particles in event 227 = 2
# Number of layer 1 hits in event 227 = 0
# Number of layer 2 hits in event 227 = 0
#
# Number of true particles in event 228 = 2
# Number of layer 1 hits in event 228 = 2
# Number of layer 2 hits in event 228 = 2
#
# Number of true particles in event 229 = 2
# Number of layer 1 hits in event 229 = 2
# Number of layer 2 hits in event 229 = 2
#
# Number of true particles in event 230 = 2
# Number of layer 1 hits in event 230 = 2
# Number of layer 2 hits in event 230 = 8
#
# Number of true particles in event 231 = 2
# Number of layer 1 hits in event 231 = 2
# Number of layer 2 hits in event 231 = 3
#
# Number of true particles in event 232 = 2
# Number of layer 1 hits in event 232 = 2
# Number of layer 2 hits in event 232 = 2
#
# Number of true particles in event 233 = 2
# Number of layer 1 hits in event 233 = 2
# Number of layer 2 hits in event 233 = 2
#
# Number of true particles in event 234 = 2
# Number of layer 1 hits in event 234 = 0
# Number of layer 2 hits in event 234 = 0
#
# Number of true particles in event 235 = 2
# Number of layer 1 hits in event 235 = 2
# Number of layer 2 hits in event 235 = 57
#
# Number of true particles in event 236 = 2
# Number of layer 1 hits in event 236 = 2
# Number of layer 2 hits in event 236 = 2
#
# Number of true particles in event 237 = 2
# Number of layer 1 hits in event 237 = 2
# Number of layer 2 hits in event 237 = 2
#
# Number of true particles in event 238 = 2
# Number of layer 1 hits in event 238 = 0
# Number of layer 2 hits in event 238 = 0
#
# Number of true particles in event 239 = 2
# Number of layer 1 hits in event 239 = 0
# Number of layer 2 hits in event 239 = 0
#
# Number of true particles in event 240 = 2
# Number of layer 1 hits in event 240 = 0
# Number of layer 2 hits in event 240 = 0
#
# Number of true particles in event 241 = 2
# Number of layer 1 hits in event 241 = 2
# Number of layer 2 hits in event 241 = 2
#
# Number of true particles in event 242 = 2
# Number of layer 1 hits in event 242 = 0
# Number of layer 2 hits in event 242 = 0
#
# Number of true particles in event 243 = 2
# Number of layer 1 hits in event 243 = 0
# Number of layer 2 hits in event 243 = 0
#
# Number of true particles in event 244 = 2
# Number of layer 1 hits in event 244 = 0
# Number of layer 2 hits in event 244 = 0
#
# Number of true particles in event 245 = 2
# Number of layer 1 hits in event 245 = 0
# Number of layer 2 hits in event 245 = 0
#
# Number of true particles in event 246 = 2
# Number of layer 1 hits in event 246 = 0
# Number of layer 2 hits in event 246 = 0
#
# Number of true particles in event 247 = 2
# Number of layer 1 hits in event 247 = 2
# Number of layer 2 hits in event 247 = 2
#
# Number of true particles in event 248 = 2
# Number of layer 1 hits in event 248 = 2
# Number of layer 2 hits in event 248 = 2
#
# Number of true particles in event 249 = 2
# Number of layer 1 hits in event 249 = 0
# Number of layer 2 hits in event 249 = 0
#
# Number of true particles in event 250 = 2
# Number of layer 1 hits in event 250 = 0
# Number of layer 2 hits in event 250 = 0
#
# Number of true particles in event 251 = 2
# Number of layer 1 hits in event 251 = 2
# Number of layer 2 hits in event 251 = 2
#
# Number of true particles in event 252 = 2
# Number of layer 1 hits in event 252 = 2
# Number of layer 2 hits in event 252 = 2
#
# Number of true particles in event 253 = 2
# Number of layer 1 hits in event 253 = 49
# Number of layer 2 hits in event 253 = 30
#
# Number of true particles in event 254 = 2
# Number of layer 1 hits in event 254 = 0
# Number of layer 2 hits in event 254 = 0
#
# Number of true particles in event 255 = 2
# Number of layer 1 hits in event 255 = 8
# Number of layer 2 hits in event 255 = 2
#
# Number of true particles in event 256 = 2
# Number of layer 1 hits in event 256 = 2
# Number of layer 2 hits in event 256 = 2
#
# Number of true particles in event 257 = 2
# Number of layer 1 hits in event 257 = 0
# Number of layer 2 hits in event 257 = 0
#
# Number of true particles in event 258 = 2
# Number of layer 1 hits in event 258 = 0
# Number of layer 2 hits in event 258 = 0
#
# Number of true particles in event 259 = 2
# Number of layer 1 hits in event 259 = 2
# Number of layer 2 hits in event 259 = 28
#
# Number of true particles in event 260 = 2
# Number of layer 1 hits in event 260 = 5
# Number of layer 2 hits in event 260 = 9
#
# Number of true particles in event 261 = 2
# Number of layer 1 hits in event 261 = 2
# Number of layer 2 hits in event 261 = 2
#
# Number of true particles in event 262 = 2
# Number of layer 1 hits in event 262 = 0
# Number of layer 2 hits in event 262 = 0
#
# Number of true particles in event 263 = 2
# Number of layer 1 hits in event 263 = 2
# Number of layer 2 hits in event 263 = 2
#
# Number of true particles in event 264 = 2
# Number of layer 1 hits in event 264 = 0
# Number of layer 2 hits in event 264 = 0
#
# Number of true particles in event 265 = 2
# Number of layer 1 hits in event 265 = 2
# Number of layer 2 hits in event 265 = 2
#
# Number of true particles in event 266 = 2
# Number of layer 1 hits in event 266 = 0
# Number of layer 2 hits in event 266 = 0
#
# Number of true particles in event 267 = 2
# Number of layer 1 hits in event 267 = 2
# Number of layer 2 hits in event 267 = 2
#
# Number of true particles in event 268 = 2
# Number of layer 1 hits in event 268 = 0
# Number of layer 2 hits in event 268 = 0
#
# Number of true particles in event 269 = 2
# Number of layer 1 hits in event 269 = 2
# Number of layer 2 hits in event 269 = 3
#
# Number of true particles in event 270 = 2
# Number of layer 1 hits in event 270 = 0
# Number of layer 2 hits in event 270 = 0
#
# Number of true particles in event 271 = 2
# Number of layer 1 hits in event 271 = 2
# Number of layer 2 hits in event 271 = 2
#
# Number of true particles in event 272 = 2
# Number of layer 1 hits in event 272 = 2
# Number of layer 2 hits in event 272 = 16
#
# Number of true particles in event 273 = 2
# Number of layer 1 hits in event 273 = 2
# Number of layer 2 hits in event 273 = 2
#
# Number of true particles in event 274 = 2
# Number of layer 1 hits in event 274 = 0
# Number of layer 2 hits in event 274 = 0
#
# Number of true particles in event 275 = 2
# Number of layer 1 hits in event 275 = 0
# Number of layer 2 hits in event 275 = 0
#
# Number of true particles in event 276 = 2
# Number of layer 1 hits in event 276 = 2
# Number of layer 2 hits in event 276 = 18
#
# Number of true particles in event 277 = 2
# Number of layer 1 hits in event 277 = 0
# Number of layer 2 hits in event 277 = 0
#
# Number of true particles in event 278 = 2
# Number of layer 1 hits in event 278 = 0
# Number of layer 2 hits in event 278 = 0
#
# Number of true particles in event 279 = 2
# Number of layer 1 hits in event 279 = 2
# Number of layer 2 hits in event 279 = 2
#
# Number of true particles in event 280 = 2
# Number of layer 1 hits in event 280 = 2
# Number of layer 2 hits in event 280 = 31
#
# Number of true particles in event 281 = 2
# Number of layer 1 hits in event 281 = 2
# Number of layer 2 hits in event 281 = 5
#
# Number of true particles in event 282 = 2
# Number of layer 1 hits in event 282 = 2
# Number of layer 2 hits in event 282 = 2
#
# Number of true particles in event 283 = 2
# Number of layer 1 hits in event 283 = 2
# Number of layer 2 hits in event 283 = 2
#
# Number of true particles in event 284 = 2
# Number of layer 1 hits in event 284 = 12
# Number of layer 2 hits in event 284 = 2
#
# Number of true particles in event 285 = 2
# Number of layer 1 hits in event 285 = 0
# Number of layer 2 hits in event 285 = 0
#
# Number of true particles in event 286 = 2
# Number of layer 1 hits in event 286 = 2
# Number of layer 2 hits in event 286 = 2
#
# Number of true particles in event 287 = 2
# Number of layer 1 hits in event 287 = 2
# Number of layer 2 hits in event 287 = 2
#
# Number of true particles in event 288 = 2
# Number of layer 1 hits in event 288 = 2
# Number of layer 2 hits in event 288 = 2
#
# Number of true particles in event 289 = 2
# Number of layer 1 hits in event 289 = 0
# Number of layer 2 hits in event 289 = 0
#
# Number of true particles in event 290 = 2
# Number of layer 1 hits in event 290 = 2
# Number of layer 2 hits in event 290 = 2
#
# Number of true particles in event 291 = 2
# Number of layer 1 hits in event 291 = 17
# Number of layer 2 hits in event 291 = 2
#
# Number of true particles in event 292 = 2
# Number of layer 1 hits in event 292 = 0
# Number of layer 2 hits in event 292 = 0
#
# Number of true particles in event 293 = 2
# Number of layer 1 hits in event 293 = 2
# Number of layer 2 hits in event 293 = 2
#
# Number of true particles in event 294 = 2
# Number of layer 1 hits in event 294 = 2
# Number of layer 2 hits in event 294 = 2
#
# Number of true particles in event 295 = 2
# Number of layer 1 hits in event 295 = 2
# Number of layer 2 hits in event 295 = 2
#
# Number of true particles in event 296 = 2
# Number of layer 1 hits in event 296 = 2
# Number of layer 2 hits in event 296 = 18
#
# Number of true particles in event 297 = 2
# Number of layer 1 hits in event 297 = 2
# Number of layer 2 hits in event 297 = 2
#
# Number of true particles in event 298 = 2
# Number of layer 1 hits in event 298 = 16
# Number of layer 2 hits in event 298 = 2
#
# Number of true particles in event 299 = 2
# Number of layer 1 hits in event 299 = 0
# Number of layer 2 hits in event 299 = 0
#
# Number of true particles in event 300 = 2
# Number of layer 1 hits in event 300 = 2
# Number of layer 2 hits in event 300 = 2
#
# Number of true particles in event 301 = 2
# Number of layer 1 hits in event 301 = 0
# Number of layer 2 hits in event 301 = 0
#
# Number of true particles in event 302 = 2
# Number of layer 1 hits in event 302 = 2
# Number of layer 2 hits in event 302 = 2
#
# Number of true particles in event 303 = 2
# Number of layer 1 hits in event 303 = 2
# Number of layer 2 hits in event 303 = 2
#
# Number of true particles in event 304 = 2
# Number of layer 1 hits in event 304 = 2
# Number of layer 2 hits in event 304 = 2
#
# Number of true particles in event 305 = 2
# Number of layer 1 hits in event 305 = 0
# Number of layer 2 hits in event 305 = 0
#
# Number of true particles in event 306 = 2
# Number of layer 1 hits in event 306 = 0
# Number of layer 2 hits in event 306 = 0
#
# Number of true particles in event 307 = 2
# Number of layer 1 hits in event 307 = 2
# Number of layer 2 hits in event 307 = 2
#
# Number of true particles in event 308 = 2
# Number of layer 1 hits in event 308 = 0
# Number of layer 2 hits in event 308 = 0
#
# Number of true particles in event 309 = 2
# Number of layer 1 hits in event 309 = 2
# Number of layer 2 hits in event 309 = 2
#
# Number of true particles in event 310 = 2
# Number of layer 1 hits in event 310 = 0
# Number of layer 2 hits in event 310 = 0
#
# Number of true particles in event 311 = 2
# Number of layer 1 hits in event 311 = 14
# Number of layer 2 hits in event 311 = 2
#
# Number of true particles in event 312 = 2
# Number of layer 1 hits in event 312 = 2
# Number of layer 2 hits in event 312 = 2
#
# Number of true particles in event 313 = 2
# Number of layer 1 hits in event 313 = 1
# Number of layer 2 hits in event 313 = 1
#
# Number of true particles in event 314 = 2
# Number of layer 1 hits in event 314 = 2
# Number of layer 2 hits in event 314 = 2
#
# Number of true particles in event 315 = 2
# Number of layer 1 hits in event 315 = 0
# Number of layer 2 hits in event 315 = 0
#
# Number of true particles in event 316 = 2
# Number of layer 1 hits in event 316 = 2
# Number of layer 2 hits in event 316 = 2
#
# Number of true particles in event 317 = 2
# Number of layer 1 hits in event 317 = 2
# Number of layer 2 hits in event 317 = 2
#
# Number of true particles in event 318 = 2
# Number of layer 1 hits in event 318 = 2
# Number of layer 2 hits in event 318 = 2
#
# Number of true particles in event 319 = 2
# Number of layer 1 hits in event 319 = 2
# Number of layer 2 hits in event 319 = 2
#
# Number of true particles in event 320 = 2
# Number of layer 1 hits in event 320 = 2
# Number of layer 2 hits in event 320 = 2
#
# Number of true particles in event 321 = 2
# Number of layer 1 hits in event 321 = 0
# Number of layer 2 hits in event 321 = 0
#
# Number of true particles in event 322 = 2
# Number of layer 1 hits in event 322 = 0
# Number of layer 2 hits in event 322 = 2
#
# Number of true particles in event 323 = 2
# Number of layer 1 hits in event 323 = 2
# Number of layer 2 hits in event 323 = 2
# Number of true particles in event 324 = 2
# Number of layer 1 hits in event 324 = 0
# Number of layer 2 hits in event 324 = 0
#
# Number of true particles in event 325 = 2
# Number of layer 1 hits in event 325 = 0
# Number of layer 2 hits in event 325 = 0
#
# Number of true particles in event 326 = 2
# Number of layer 1 hits in event 326 = 2
# Number of layer 2 hits in event 326 = 2
#
# Number of true particles in event 327 = 2
# Number of layer 1 hits in event 327 = 2
# Number of layer 2 hits in event 327 = 14
#
# Number of true particles in event 328 = 2
# Number of layer 1 hits in event 328 = 0
# Number of layer 2 hits in event 328 = 0
#
# Number of true particles in event 329 = 2
# Number of layer 1 hits in event 329 = 0
# Number of layer 2 hits in event 329 = 1
#
# Number of true particles in event 330 = 2
# Number of layer 1 hits in event 330 = 2
# Number of layer 2 hits in event 330 = 2
#
# Number of true particles in event 331 = 2
# Number of layer 1 hits in event 331 = 0
# Number of layer 2 hits in event 331 = 0
#
# Number of true particles in event 332 = 2
# Number of layer 1 hits in event 332 = 2
# Number of layer 2 hits in event 332 = 3
#
# Number of true particles in event 333 = 2
# Number of layer 1 hits in event 333 = 2
# Number of layer 2 hits in event 333 = 2
#
# Number of true particles in event 334 = 2
# Number of layer 1 hits in event 334 = 2
# Number of layer 2 hits in event 334 = 2
#
# Number of true particles in event 335 = 2
# Number of layer 1 hits in event 335 = 0
# Number of layer 2 hits in event 335 = 0
#
# Number of true particles in event 336 = 2
# Number of layer 1 hits in event 336 = 2
# Number of layer 2 hits in event 336 = 2
#
# Number of true particles in event 337 = 2
# Number of layer 1 hits in event 337 = 2
# Number of layer 2 hits in event 337 = 2
#
# Number of true particles in event 338 = 2
# Number of layer 1 hits in event 338 = 0
# Number of layer 2 hits in event 338 = 0
#
# Number of true particles in event 339 = 2
# Number of layer 1 hits in event 339 = 2
# Number of layer 2 hits in event 339 = 16
#
# Number of true particles in event 340 = 2
# Number of layer 1 hits in event 340 = 2
# Number of layer 2 hits in event 340 = 2
#
# Number of true particles in event 341 = 2
# Number of layer 1 hits in event 341 = 0
# Number of layer 2 hits in event 341 = 0
#
# Number of true particles in event 342 = 2
# Number of layer 1 hits in event 342 = 0
# Number of layer 2 hits in event 342 = 0
#
# Number of true particles in event 343 = 2
# Number of layer 1 hits in event 343 = 69
# Number of layer 2 hits in event 343 = 2
#
# Number of true particles in event 344 = 2
# Number of layer 1 hits in event 344 = 2
# Number of layer 2 hits in event 344 = 30
#
# Number of true particles in event 345 = 2
# Number of layer 1 hits in event 345 = 0
# Number of layer 2 hits in event 345 = 0
#
# Number of true particles in event 346 = 2
# Number of layer 1 hits in event 346 = 2
# Number of layer 2 hits in event 346 = 2
#
# Number of true particles in event 347 = 2
# Number of layer 1 hits in event 347 = 0
# Number of layer 2 hits in event 347 = 0
#
# Number of true particles in event 348 = 2
# Number of layer 1 hits in event 348 = 13
# Number of layer 2 hits in event 348 = 2
#
# Number of true particles in event 349 = 2
# Number of layer 1 hits in event 349 = 0
# Number of layer 2 hits in event 349 = 0
#
# Number of true particles in event 350 = 2
# Number of layer 1 hits in event 350 = 2
# Number of layer 2 hits in event 350 = 2
#
# Number of true particles in event 351 = 2
# Number of layer 1 hits in event 351 = 2
# Number of layer 2 hits in event 351 = 2
#
# Number of true particles in event 352 = 2
# Number of layer 1 hits in event 352 = 0
# Number of layer 2 hits in event 352 = 0
#
# Number of true particles in event 353 = 2
# Number of layer 1 hits in event 353 = 2
# Number of layer 2 hits in event 353 = 2
#
# Number of true particles in event 354 = 2
# Number of layer 1 hits in event 354 = 0
# Number of layer 2 hits in event 354 = 0
#
# Number of true particles in event 355 = 2
# Number of layer 1 hits in event 355 = 2
# Number of layer 2 hits in event 355 = 2
#
# Number of true particles in event 356 = 2
# Number of layer 1 hits in event 356 = 0
# Number of layer 2 hits in event 356 = 0
#
# Number of true particles in event 357 = 2
# Number of layer 1 hits in event 357 = 2
# Number of layer 2 hits in event 357 = 7
#
# Number of true particles in event 358 = 2
# Number of layer 1 hits in event 358 = 0
# Number of layer 2 hits in event 358 = 0
#
# Number of true particles in event 359 = 2
# Number of layer 1 hits in event 359 = 0
# Number of layer 2 hits in event 359 = 0
#
# Number of true particles in event 360 = 2
# Number of layer 1 hits in event 360 = 0
# Number of layer 2 hits in event 360 = 0
#
# Number of true particles in event 361 = 2
# Number of layer 1 hits in event 361 = 2
# Number of layer 2 hits in event 361 = 3
#
# Number of true particles in event 362 = 2
# Number of layer 1 hits in event 362 = 2
# Number of layer 2 hits in event 362 = 2
#
# Number of true particles in event 363 = 2
# Number of layer 1 hits in event 363 = 2
# Number of layer 2 hits in event 363 = 2
#
# Number of true particles in event 364 = 2
# Number of layer 1 hits in event 364 = 29
# Number of layer 2 hits in event 364 = 2
#
# Number of true particles in event 365 = 2
# Number of layer 1 hits in event 365 = 2
# Number of layer 2 hits in event 365 = 2
#
# Number of true particles in event 366 = 2
# Number of layer 1 hits in event 366 = 0
# Number of layer 2 hits in event 366 = 0
#
# Number of true particles in event 367 = 2
# Number of layer 1 hits in event 367 = 0
# Number of layer 2 hits in event 367 = 0
#
# Number of true particles in event 368 = 2
# Number of layer 1 hits in event 368 = 0
# Number of layer 2 hits in event 368 = 0
#
# Number of true particles in event 369 = 2
# Number of layer 1 hits in event 369 = 0
# Number of layer 2 hits in event 369 = 0
#
# Number of true particles in event 370 = 2
# Number of layer 1 hits in event 370 = 0
# Number of layer 2 hits in event 370 = 0
#
# Number of true particles in event 371 = 2
# Number of layer 1 hits in event 371 = 38
# Number of layer 2 hits in event 371 = 2
#
# Number of true particles in event 372 = 2
# Number of layer 1 hits in event 372 = 53
# Number of layer 2 hits in event 372 = 2
#
# Number of true particles in event 373 = 2
# Number of layer 1 hits in event 373 = 0
# Number of layer 2 hits in event 373 = 0
#
# Number of true particles in event 374 = 2
# Number of layer 1 hits in event 374 = 2
# Number of layer 2 hits in event 374 = 2
#
# Number of true particles in event 375 = 2
# Number of layer 1 hits in event 375 = 27
# Number of layer 2 hits in event 375 = 2
#
# Number of true particles in event 376 = 2
# Number of layer 1 hits in event 376 = 2
# Number of layer 2 hits in event 376 = 2
#
# Number of true particles in event 377 = 2
# Number of layer 1 hits in event 377 = 2
# Number of layer 2 hits in event 377 = 2
#
# Number of true particles in event 378 = 2
# Number of layer 1 hits in event 378 = 0
# Number of layer 2 hits in event 378 = 0
#
# Number of true particles in event 379 = 2
# Number of layer 1 hits in event 379 = 2
# Number of layer 2 hits in event 379 = 2
#
# Number of true particles in event 380 = 2
# Number of layer 1 hits in event 380 = 2
# Number of layer 2 hits in event 380 = 2
#
# Number of true particles in event 381 = 2
# Number of layer 1 hits in event 381 = 2
# Number of layer 2 hits in event 381 = 2
#
# Number of true particles in event 382 = 2
# Number of layer 1 hits in event 382 = 2
# Number of layer 2 hits in event 382 = 2
#
# Number of true particles in event 383 = 2
# Number of layer 1 hits in event 383 = 0
# Number of layer 2 hits in event 383 = 0
#
# Number of true particles in event 384 = 2
# Number of layer 1 hits in event 384 = 2
# Number of layer 2 hits in event 384 = 2
#
# Number of true particles in event 385 = 2
# Number of layer 1 hits in event 385 = 0
# Number of layer 2 hits in event 385 = 0
#
# Number of true particles in event 386 = 2
# Number of layer 1 hits in event 386 = 0
# Number of layer 2 hits in event 386 = 0
#
# Number of true particles in event 387 = 2
# Number of layer 1 hits in event 387 = 0
# Number of layer 2 hits in event 387 = 0
#
# Number of true particles in event 388 = 2
# Number of layer 1 hits in event 388 = 2
# Number of layer 2 hits in event 388 = 2
#
# Number of true particles in event 389 = 2
# Number of layer 1 hits in event 389 = 2
# Number of layer 2 hits in event 389 = 2
#
# Number of true particles in event 390 = 2
# Number of layer 1 hits in event 390 = 2
# Number of layer 2 hits in event 390 = 2
#
# Number of true particles in event 391 = 2
# Number of layer 1 hits in event 391 = 2
# Number of layer 2 hits in event 391 = 2
#
# Number of true particles in event 392 = 2
# ...
# Number of layer 1 hits in event 870 = 2
# Number of layer 2 hits in event 870 = 2
#
# Number of true particles in event 871 = 2
# Number of layer 1 hits in event 871 = 8
# Number of layer 2 hits in event 871 = 2
#
# Number of true particles in event 872 = 2
# Number of layer 1 hits in event 872 = 0
# Number of layer 2 hits in event 872 = 0
#
# Number of true particles in event 873 = 2
# Number of layer 1 hits in event 873 = 0
# Number of layer 2 hits in event 873 = 0
#
# Number of true particles in event 874 = 2
# Number of layer 1 hits in event 874 = 0
# Number of layer 2 hits in event 874 = 0
#
# Number of true particles in event 875 = 2
# Number of layer 1 hits in event 875 = 0
# Number of layer 2 hits in event 875 = 0
#
# Number of true particles in event 876 = 2
# Number of layer 1 hits in event 876 = 2
# Number of layer 2 hits in event 876 = 5
#
# Number of true particles in event 877 = 2
# Number of layer 1 hits in event 877 = 1
# Number of layer 2 hits in event 877 = 0
#
# Number of true particles in event 878 = 2
# Number of layer 1 hits in event 878 = 2
# Number of layer 2 hits in event 878 = 19
#
# Number of true particles in event 879 = 2
# Number of layer 1 hits in event 879 = 0
# Number of layer 2 hits in event 879 = 0
#
# Number of true particles in event 880 = 2
# Number of layer 1 hits in event 880 = 0
# Number of layer 2 hits in event 880 = 0
#
# Number of true particles in event 881 = 2
# Number of layer 1 hits in event 881 = 119
# Number of layer 2 hits in event 881 = 26
#
# Number of true particles in event 882 = 2
# Number of layer 1 hits in event 882 = 2
# Number of layer 2 hits in event 882 = 20
#
# Number of true particles in event 883 = 2
# Number of layer 1 hits in event 883 = 2
# Number of layer 2 hits in event 883 = 52
#
# Number of true particles in event 884 = 2
# Number of layer 1 hits in event 884 = 0
# Number of layer 2 hits in event 884 = 0
#
# Number of true particles in event 885 = 2
# Number of layer 1 hits in event 885 = 0
# Number of layer 2 hits in event 885 = 0
#
# Number of true particles in event 886 = 2
# Number of layer 1 hits in event 886 = 7
# Number of layer 2 hits in event 886 = 2
#
# Number of true particles in event 887 = 2
# Number of layer 1 hits in event 887 = 2
# Number of layer 2 hits in event 887 = 27
#
# Number of true particles in event 888 = 2
# Number of layer 1 hits in event 888 = 2
# Number of layer 2 hits in event 888 = 2
#
# Number of true particles in event 889 = 2
# Number of layer 1 hits in event 889 = 2
# Number of layer 2 hits in event 889 = 2
#
# Number of true particles in event 890 = 2
# Number of layer 1 hits in event 890 = 0
# Number of layer 2 hits in event 890 = 0
#
# Number of true particles in event 891 = 2
# Number of layer 1 hits in event 891 = 2
# Number of layer 2 hits in event 891 = 2
#
# Number of true particles in event 892 = 2
# Number of layer 1 hits in event 892 = 0
# Number of layer 2 hits in event 892 = 0
#
# Number of true particles in event 893 = 2
# Number of layer 1 hits in event 893 = 2
# Number of layer 2 hits in event 893 = 2
#
# Number of true particles in event 894 = 2
# Number of layer 1 hits in event 894 = 0
# Number of layer 2 hits in event 894 = 0
#
# Number of true particles in event 895 = 2
# Number of layer 1 hits in event 895 = 2
# Number of layer 2 hits in event 895 = 2
#
# Number of true particles in event 896 = 2
# Number of layer 1 hits in event 896 = 2
# Number of layer 2 hits in event 896 = 2
#
# Number of true particles in event 897 = 2
# Number of layer 1 hits in event 897 = 2
# Number of layer 2 hits in event 897 = 2
#
# Number of true particles in event 898 = 2
# Number of layer 1 hits in event 898 = 0
# Number of layer 2 hits in event 898 = 0
#
# Number of true particles in event 899 = 2
# Number of layer 1 hits in event 899 = 2
# Number of layer 2 hits in event 899 = 2
#
# Number of true particles in event 900 = 2
# Number of layer 1 hits in event 900 = 0
# Number of layer 2 hits in event 900 = 0
#
# Number of true particles in event 901 = 2
# Number of layer 1 hits in event 901 = 2
# Number of layer 2 hits in event 901 = 2
#
# Number of true particles in event 902 = 2
# Number of layer 1 hits in event 902 = 0
# Number of layer 2 hits in event 902 = 0
#
# Number of true particles in event 903 = 2
# Number of layer 1 hits in event 903 = 2
# Number of layer 2 hits in event 903 = 2
#
# Number of true particles in event 904 = 2
# Number of layer 1 hits in event 904 = 0
# Number of layer 2 hits in event 904 = 0
#
# Number of true particles in event 905 = 2
# Number of layer 1 hits in event 905 = 2
# Number of layer 2 hits in event 905 = 2
#
# Number of true particles in event 906 = 2
# Number of layer 1 hits in event 906 = 2
# Number of layer 2 hits in event 906 = 6
#
# Number of true particles in event 907 = 2
# Number of layer 1 hits in event 907 = 2
# Number of layer 2 hits in event 907 = 2
#
# Number of true particles in event 908 = 2
# Number of layer 1 hits in event 908 = 0
# Number of layer 2 hits in event 908 = 0
#
# Number of true particles in event 909 = 2
# Number of layer 1 hits in event 909 = 2
# Number of layer 2 hits in event 909 = 2
#
# Number of true particles in event 910 = 2
# Number of layer 1 hits in event 910 = 2
# Number of layer 2 hits in event 910 = 2
#
# Number of true particles in event 911 = 2
# Number of layer 1 hits in event 911 = 2
# Number of layer 2 hits in event 911 = 2
#
# Number of true particles in event 912 = 2
# Number of layer 1 hits in event 912 = 2
# Number of layer 2 hits in event 912 = 2
#
# Number of true particles in event 913 = 2
# Number of layer 1 hits in event 913 = 7
# Number of layer 2 hits in event 913 = 2
#
# Number of true particles in event 914 = 2
# Number of layer 1 hits in event 914 = 2
# Number of layer 2 hits in event 914 = 2
#
# Number of true particles in event 915 = 2
# Number of layer 1 hits in event 915 = 2
# Number of layer 2 hits in event 915 = 2
#
# Number of true particles in event 916 = 2
# Number of layer 1 hits in event 916 = 0
# Number of layer 2 hits in event 916 = 0
#
# Number of true particles in event 917 = 2
# Number of layer 1 hits in event 917 = 2
# Number of layer 2 hits in event 917 = 25
#
# Number of true particles in event 918 = 2
# Number of layer 1 hits in event 918 = 2
# Number of layer 2 hits in event 918 = 2
#
# Number of true particles in event 919 = 2
# Number of layer 1 hits in event 919 = 4
# Number of layer 2 hits in event 919 = 4
#
# Number of true particles in event 920 = 2
# Number of layer 1 hits in event 920 = 0
# Number of layer 2 hits in event 920 = 0
#
# Number of true particles in event 921 = 2
# Number of layer 1 hits in event 921 = 0
# Number of layer 2 hits in event 921 = 0
#
# Number of true particles in event 922 = 2
# Number of layer 1 hits in event 922 = 0
# Number of layer 2 hits in event 922 = 0
#
# Number of true particles in event 923 = 2
# Number of layer 1 hits in event 923 = 2
# Number of layer 2 hits in event 923 = 6
#
# Number of true particles in event 924 = 2
# Number of layer 1 hits in event 924 = 2
# Number of layer 2 hits in event 924 = 2
#
# Number of true particles in event 925 = 2
# Number of layer 1 hits in event 925 = 0
# Number of layer 2 hits in event 925 = 0
#
# Number of true particles in event 926 = 2
# Number of layer 1 hits in event 926 = 2
# Number of layer 2 hits in event 926 = 5
#
# Number of true particles in event 927 = 2
# Number of layer 1 hits in event 927 = 2
# Number of layer 2 hits in event 927 = 2
#
# Number of true particles in event 928 = 2
# Number of layer 1 hits in event 928 = 2
# Number of layer 2 hits in event 928 = 2
#
# Number of true particles in event 929 = 2
# Number of layer 1 hits in event 929 = 0
# Number of layer 2 hits in event 929 = 0
#
# Number of true particles in event 930 = 2
# Number of layer 1 hits in event 930 = 2
# Number of layer 2 hits in event 930 = 2
#
# Number of true particles in event 931 = 2
# Number of layer 1 hits in event 931 = 2
# Number of layer 2 hits in event 931 = 2
#
# Number of true particles in event 932 = 2
# Number of layer 1 hits in event 932 = 5
# Number of layer 2 hits in event 932 = 2
#
# Number of true particles in event 933 = 2
# Number of layer 1 hits in event 933 = 2
# Number of layer 2 hits in event 933 = 2
#
# Number of true particles in event 934 = 2
# Number of layer 1 hits in event 934 = 2
# Number of layer 2 hits in event 934 = 2
#
# Number of true particles in event 935 = 2
# Number of layer 1 hits in event 935 = 2
# Number of layer 2 hits in event 935 = 10
#
# Number of true particles in event 936 = 2
# Number of layer 1 hits in event 936 = 2
# Number of layer 2 hits in event 936 = 2
#
# Number of true particles in event 937 = 2
# Number of layer 1 hits in event 937 = 0
# Number of layer 2 hits in event 937 = 0
#
# Number of true particles in event 938 = 2
# Number of layer 1 hits in event 938 = 0
# Number of layer 2 hits in event 938 = 0
#
# Number of true particles in event 939 = 2
# Number of layer 1 hits in event 939 = 2
# Number of layer 2 hits in event 939 = 2
#
# Number of true particles in event 940 = 2
# Number of layer 1 hits in event 940 = 0
# Number of layer 2 hits in event 940 = 0
#
# Number of true particles in event 941 = 2
# Number of layer 1 hits in event 941 = 2
# Number of layer 2 hits in event 941 = 2
#
# Number of true particles in event 942 = 2
# Number of layer 1 hits in event 942 = 3
# Number of layer 2 hits in event 942 = 2
#
# Number of true particles in event 943 = 2
# Number of layer 1 hits in event 943 = 2
# Number of layer 2 hits in event 943 = 2
#
# Number of true particles in event 944 = 2
# Number of layer 1 hits in event 944 = 2
# Number of layer 2 hits in event 944 = 2
#
# Number of true particles in event 945 = 2
# Number of layer 1 hits in event 945 = 0
# Number of layer 2 hits in event 945 = 0
#
# Number of true particles in event 946 = 2
# Number of layer 1 hits in event 946 = 2
# Number of layer 2 hits in event 946 = 2
#
# Number of true particles in event 947 = 2
# Number of layer 1 hits in event 947 = 2
# Number of layer 2 hits in event 947 = 2
#
# Number of true particles in event 948 = 2
# Number of layer 1 hits in event 948 = 2
# Number of layer 2 hits in event 948 = 3
#
# Number of true particles in event 949 = 2
# Number of layer 1 hits in event 949 = 2
# Number of layer 2 hits in event 949 = 2
#
# Number of true particles in event 950 = 2
# Number of layer 1 hits in event 950 = 0
# Number of layer 2 hits in event 950 = 0
#
# Number of true particles in event 951 = 2
# Number of layer 1 hits in event 951 = 66
# Number of layer 2 hits in event 951 = 4
#
# Number of true particles in event 952 = 2
# Number of layer 1 hits in event 952 = 0
# Number of layer 2 hits in event 952 = 0
#
# Number of true particles in event 953 = 2
# Number of layer 1 hits in event 953 = 0
# Number of layer 2 hits in event 953 = 0
#
# Number of true particles in event 954 = 2
# Number of layer 1 hits in event 954 = 2
# Number of layer 2 hits in event 954 = 2
#
# Number of true particles in event 955 = 2
# Number of layer 1 hits in event 955 = 22
# Number of layer 2 hits in event 955 = 2
#
# Number of true particles in event 956 = 2
# Number of layer 1 hits in event 956 = 0
# Number of layer 2 hits in event 956 = 0
#
# Number of true particles in event 957 = 2
# Number of layer 1 hits in event 957 = 0
# Number of layer 2 hits in event 957 = 0
#
# Number of true particles in event 958 = 2
# Number of layer 1 hits in event 958 = 0
# Number of layer 2 hits in event 958 = 0
#
# Number of true particles in event 959 = 2
# Number of layer 1 hits in event 959 = 2
# Number of layer 2 hits in event 959 = 28
#
# Number of true particles in event 960 = 2
# Number of layer 1 hits in event 960 = 32
# Number of layer 2 hits in event 960 = 2
#
# Number of true particles in event 961 = 2
# Number of layer 1 hits in event 961 = 40
# Number of layer 2 hits in event 961 = 7
#
# Number of true particles in event 962 = 2
# Number of layer 1 hits in event 962 = 2
# Number of layer 2 hits in event 962 = 2
#
# Number of true particles in event 963 = 2
# Number of layer 1 hits in event 963 = 0
# Number of layer 2 hits in event 963 = 0
#
# Number of true particles in event 964 = 2
# Number of layer 1 hits in event 964 = 2
# Number of layer 2 hits in event 964 = 2
#
# Number of true particles in event 965 = 2
# Number of layer 1 hits in event 965 = 2
# Number of layer 2 hits in event 965 = 2
#
# Number of true particles in event 966 = 2
# Number of layer 1 hits in event 966 = 0
# Number of layer 2 hits in event 966 = 0
#
# Number of true particles in event 967 = 2
# Number of layer 1 hits in event 967 = 2
# Number of layer 2 hits in event 967 = 2
#
# Number of true particles in event 968 = 2
# Number of layer 1 hits in event 968 = 0
# Number of layer 2 hits in event 968 = 0
#
# Number of true particles in event 969 = 2
# Number of layer 1 hits in event 969 = 2
# Number of layer 2 hits in event 969 = 2
#
# Number of true particles in event 970 = 2
# Number of layer 1 hits in event 970 = 0
# Number of layer 2 hits in event 970 = 0
#
# Number of true particles in event 971 = 2
# Number of layer 1 hits in event 971 = 2
# Number of layer 2 hits in event 971 = 2
#
# Number of true particles in event 972 = 2
# Number of layer 1 hits in event 972 = 0
# Number of layer 2 hits in event 972 = 1
#
# Number of true particles in event 973 = 2
# Number of layer 1 hits in event 973 = 9
# Number of layer 2 hits in event 973 = 2
#
# Number of true particles in event 974 = 2
# Number of layer 1 hits in event 974 = 2
# Number of layer 2 hits in event 974 = 8
#
# Number of true particles in event 975 = 2
# Number of layer 1 hits in event 975 = 0
# Number of layer 2 hits in event 975 = 0
#
# Number of true particles in event 976 = 2
# Number of layer 1 hits in event 976 = 2
# Number of layer 2 hits in event 976 = 2
#
# Number of true particles in event 977 = 2
# Number of layer 1 hits in event 977 = 0
# Number of layer 2 hits in event 977 = 0
#
# Number of true particles in event 978 = 2
# Number of layer 1 hits in event 978 = 0
# Number of layer 2 hits in event 978 = 0
#
# Number of true particles in event 979 = 2
# Number of layer 1 hits in event 979 = 2
# Number of layer 2 hits in event 979 = 2
#
# Number of true particles in event 980 = 2
# Number of layer 1 hits in event 980 = 2
# Number of layer 2 hits in event 980 = 2
#
# Number of true particles in event 981 = 2
# Number of layer 1 hits in event 981 = 0
# Number of layer 2 hits in event 981 = 0
#
# Number of true particles in event 982 = 2
# Number of layer 1 hits in event 982 = 0
# Number of layer 2 hits in event 982 = 0
#
# Number of true particles in event 983 = 2
# Number of layer 1 hits in event 983 = 2
# Number of layer 2 hits in event 983 = 2
#
# Number of true particles in event 984 = 2
# Number of layer 1 hits in event 984 = 0
# Number of layer 2 hits in event 984 = 0
#
# Number of true particles in event 985 = 2
# Number of layer 1 hits in event 985 = 2
# Number of layer 2 hits in event 985 = 2
#
# Number of true particles in event 986 = 2
# Number of layer 1 hits in event 986 = 2
# Number of layer 2 hits in event 986 = 2
#
# Number of true particles in event 987 = 2
# Number of layer 1 hits in event 987 = 0
# Number of layer 2 hits in event 987 = 0
#
# Number of true particles in event 988 = 2
# Number of layer 1 hits in event 988 = 0
# Number of layer 2 hits in event 988 = 0
#
# Number of true particles in event 989 = 2
# Number of layer 1 hits in event 989 = 2
# Number of layer 2 hits in event 989 = 48
#
# Number of true particles in event 990 = 2
# Number of layer 1 hits in event 990 = 0
# Number of layer 2 hits in event 990 = 0
#
# Number of true particles in event 991 = 2
# Number of layer 1 hits in event 991 = 0
# Number of layer 2 hits in event 991 = 0
#
# Number of true particles in event 992 = 2
# Number of layer 1 hits in event 992 = 2
# Number of layer 2 hits in event 992 = 3
#
# Number of true particles in event 993 = 2
# Number of layer 1 hits in event 993 = 2
# Number of layer 2 hits in event 993 = 2
#
# Number of true particles in event 994 = 2
# Number of layer 1 hits in event 994 = 2
# Number of layer 2 hits in event 994 = 2
#
# Number of true particles in event 995 = 2
# Number of layer 1 hits in event 995 = 19
# Number of layer 2 hits in event 995 = 2
#
# Number of true particles in event 996 = 2
# Number of layer 1 hits in event 996 = 0
# Number of layer 2 hits in event 996 = 0
#
# Number of true particles in event 997 = 2
# Number of layer 1 hits in event 997 = 2
# Number of layer 2 hits in event 997 = 2
#
# Number of true particles in event 998 = 2
# Number of layer 1 hits in event 998 = 12
# Number of layer 2 hits in event 998 = 2
#
# Number of true particles in event 999 = 2
# Number of layer 1 hits in event 999 = 2
# Number of layer 2 hits in event 999 = 2

# %% [markdown]
# # Part 2

# %%
no_of_pairs = [] # Initialise array

pair_values = [] # Makes a list of the pair values 


# Again, looping over the number of events
for i in range(1000):
    count = 0
    pair = []
    for j in np.array(tracker1Data.Theta[tracker1Data.EventID == i]): # Loop over values of theta in layer 1 corresponding to event i
        for k in np.array(tracker2Data.Theta[tracker2Data.EventID == i]): # Loop over values of theta in layer 2 corresponding to event i
            if math.fabs(j-k) < 0.0001: 
                count += 1 # Increase the count by 1 if a pair is found with theta close to each other
                pair.append([j,k]) # adds the pair values to the temporary list
    no_of_pairs.append(count) # Append the value to the list after looping over all layers
    pair_values.append(pair) # adds the pairs of event i to the main list of all events

for n in range(1000):
    print("Number of pairs in event {:} = {:}".format(n,no_of_pairs[n]))
    print("Pairs at theta values of: {:} ([layer1,layer2])".format(pair_values[n]))
    print("")
    
# There is quite a bit of double counting but that is due to the data. 
# E.g. for event 1 there are 4 hits with the same theta value (but slightly different phi values) 
# The code appears to work
# Out:
# Number of pairs in event 0 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 1 = 7
# Pairs at theta values of: [[0.928358, 0.928325], [2.21322, 2.21325], [2.21322, 2.21325], [2.21322, 2.21325], [2.21322, 2.21325], [2.21322, 2.21323], [2.21322, 2.21323]] ([layer1,layer2])
#
# Number of pairs in event 2 = 2
# Pairs at theta values of: [[2.21225, 2.21226], [0.92934, 0.929301]] ([layer1,layer2])
#
# Number of pairs in event 3 = 6
# Pairs at theta values of: [[2.18244, 2.18247], [0.959136, 0.959161], [0.959136, 0.959161], [0.959136, 0.959176], [0.959136, 0.95921], [0.959136, 0.959223]] ([layer1,layer2])
#
# Number of pairs in event 4 = 4
# Pairs at theta values of: [[2.04377, 2.04378], [1.09801, 1.09797], [1.09801, 1.09797], [1.09802, 1.09797]] ([layer1,layer2])
#
# Number of pairs in event 5 = 2
# Pairs at theta values of: [[1.99455, 1.99452], [1.14705, 1.14708]] ([layer1,layer2])
#
# Number of pairs in event 6 = 11
# Pairs at theta values of: [[1.62832, 1.62832], [1.62832, 1.62832], [1.62829, 1.62832], [1.62825, 1.62832], [1.51316, 1.51317], [1.51316, 1.51317], [1.51316, 1.51317], [1.51316, 1.51318], [1.51316, 1.51318], [1.51316, 1.5132], [1.51316, 1.5132]] ([layer1,layer2])
#
# Number of pairs in event 7 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 8 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 9 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 10 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 11 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 12 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 13 = 2
# Pairs at theta values of: [[1.46102, 1.46102], [1.67693, 1.67696]] ([layer1,layer2])
#
# Number of pairs in event 14 = 2
# Pairs at theta values of: [[0.880318, 0.880258], [2.26129, 2.2613]] ([layer1,layer2])
#
# Number of pairs in event 15 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 16 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 17 = 2
# Pairs at theta values of: [[1.29624, 1.2962], [1.84535, 1.84535]] ([layer1,layer2])
#
# Number of pairs in event 18 = 2
# Pairs at theta values of: [[2.29918, 2.29918], [0.842397, 0.842397]] ([layer1,layer2])
#
# Number of pairs in event 19 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 20 = 2
# Pairs at theta values of: [[1.82123, 1.82122], [1.3203, 1.32029]] ([layer1,layer2])
#
# Number of pairs in event 21 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 22 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 23 = 2
# Pairs at theta values of: [[1.41723, 1.41724], [1.72438, 1.72437]] ([layer1,layer2])
#
# Number of pairs in event 24 = 2
# Pairs at theta values of: [[1.34842, 1.34843], [1.7932, 1.79323]] ([layer1,layer2])
#
# Number of pairs in event 25 = 1
# Pairs at theta values of: [[0.933507, 0.933481]] ([layer1,layer2])
#
# Number of pairs in event 26 = 1
# Pairs at theta values of: [[0.821905, 0.821867]] ([layer1,layer2])
#
# Number of pairs in event 27 = 2
# Pairs at theta values of: [[1.88406, 1.8841], [1.25746, 1.25748]] ([layer1,layer2])
#
# Number of pairs in event 28 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 29 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 30 = 2
# Pairs at theta values of: [[1.74287, 1.74286], [1.39866, 1.39865]] ([layer1,layer2])
#
# Number of pairs in event 31 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 32 = 8
# Pairs at theta values of: [[1.89501, 1.89501], [1.24658, 1.24655], [1.24658, 1.24655], [1.24658, 1.24653], [1.24658, 1.24654], [1.24658, 1.24654], [1.24658, 1.24652], [1.24658, 1.24651]] ([layer1,layer2])
#
# Number of pairs in event 33 = 6
# Pairs at theta values of: [[1.07289, 1.07283], [1.07289, 1.07283], [1.07287, 1.07283], [1.07281, 1.07283], [1.0728, 1.07283], [2.05921, 2.05922]] ([layer1,layer2])
#
# Number of pairs in event 34 = 7
# Pairs at theta values of: [[1.78977, 1.78977], [1.78977, 1.78977], [1.78977, 1.78979], [1.78977, 1.78981], [1.78977, 1.78983], [1.78977, 1.7898], [1.35182, 1.35187]] ([layer1,layer2])
#
# Number of pairs in event 35 = 2
# Pairs at theta values of: [[1.9951, 1.99509], [1.14641, 1.14633]] ([layer1,layer2])
#
# Number of pairs in event 36 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 37 = 5
# Pairs at theta values of: [[0.866786, 0.86679], [2.27488, 2.2749], [2.27488, 2.2749], [2.27488, 2.27488], [2.27488, 2.27487]] ([layer1,layer2])
#
# Number of pairs in event 38 = 2
# Pairs at theta values of: [[1.67486, 1.67482], [1.46673, 1.46674]] ([layer1,layer2])
#
# Number of pairs in event 39 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 40 = 2
# Pairs at theta values of: [[1.25717, 1.25715], [1.88218, 1.88223]] ([layer1,layer2])
#
# Number of pairs in event 41 = 2
# Pairs at theta values of: [[1.79841, 1.79844], [1.34319, 1.34318]] ([layer1,layer2])
#
# Number of pairs in event 42 = 2
# Pairs at theta values of: [[1.37178, 1.37176], [1.76979, 1.7698]] ([layer1,layer2])
#
# Number of pairs in event 43 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 44 = 2
# Pairs at theta values of: [[1.25386, 1.25386], [1.88772, 1.88771]] ([layer1,layer2])
#
# Number of pairs in event 45 = 2
# Pairs at theta values of: [[1.99873, 1.99879], [1.14287, 1.14285]] ([layer1,layer2])
#
# Number of pairs in event 46 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 47 = 2
# Pairs at theta values of: [[1.99667, 1.99672], [1.14525, 1.14522]] ([layer1,layer2])
#
# Number of pairs in event 48 = 8
# Pairs at theta values of: [[1.10588, 1.10583], [2.03568, 2.03573], [2.03568, 2.03573], [2.03568, 2.0357], [2.03568, 2.03569], [2.03568, 2.03571], [2.03568, 2.03572], [2.03568, 2.03573]] ([layer1,layer2])
#
# Number of pairs in event 49 = 10
# Pairs at theta values of: [[1.69258, 1.69253], [1.44964, 1.44964], [1.44964, 1.44964], [1.44965, 1.44964], [1.44966, 1.44964], [1.44967, 1.44964], [1.44969, 1.44964], [1.44967, 1.44964], [1.44968, 1.44964], [1.44968, 1.44964]] ([layer1,layer2])
#
# Number of pairs in event 50 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 51 = 2
# Pairs at theta values of: [[0.996138, 0.996151], [2.14546, 2.14542]] ([layer1,layer2])
#
# Number of pairs in event 52 = 13
# Pairs at theta values of: [[2.19224, 2.19223], [2.19224, 2.19223], [2.19224, 2.19223], [2.19224, 2.19223], [2.19224, 2.19221], [2.19224, 2.19219], [2.19224, 2.19218], [2.19224, 2.19217], [2.19224, 2.19217], [2.19224, 2.19215], [2.19224, 2.19215], [2.19224, 2.19214], [0.949346, 0.949353]] ([layer1,layer2])
#
# Number of pairs in event 53 = 2
# Pairs at theta values of: [[1.48482, 1.48481], [1.65676, 1.65678]] ([layer1,layer2])
#
# Number of pairs in event 54 = 2
# Pairs at theta values of: [[2.15319, 2.15317], [0.988379, 0.988385]] ([layer1,layer2])
#
# Number of pairs in event 55 = 2
# Pairs at theta values of: [[1.0442, 1.04422], [2.09738, 2.09738]] ([layer1,layer2])
#
# Number of pairs in event 56 = 2
# Pairs at theta values of: [[1.80563, 1.80565], [1.33597, 1.33595]] ([layer1,layer2])
#
# Number of pairs in event 57 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 58 = 2
# Pairs at theta values of: [[2.0587, 2.05873], [1.08295, 1.08293]] ([layer1,layer2])
#
# Number of pairs in event 59 = 6
# Pairs at theta values of: [[2.14539, 2.14539], [2.14539, 2.14539], [2.14539, 2.14539], [2.14535, 2.14539], [2.14534, 2.14539], [0.996194, 0.996178]] ([layer1,layer2])
#
# Number of pairs in event 60 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 61 = 2
# Pairs at theta values of: [[1.89117, 1.89123], [1.25039, 1.25039]] ([layer1,layer2])
#
# Number of pairs in event 62 = 2
# Pairs at theta values of: [[1.29033, 1.29034], [1.85128, 1.85129]] ([layer1,layer2])
#
# Number of pairs in event 63 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 64 = 5
# Pairs at theta values of: [[1.45661, 1.45665], [1.45661, 1.45665], [1.45661, 1.45667], [1.45661, 1.45669], [2.099, 2.0991]] ([layer1,layer2])
#
# Number of pairs in event 65 = 2
# Pairs at theta values of: [[1.57341, 1.57339], [1.56819, 1.56821]] ([layer1,layer2])
#
# Number of pairs in event 66 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 67 = 2
# Pairs at theta values of: [[1.3562, 1.35617], [1.78539, 1.78535]] ([layer1,layer2])
#
# Number of pairs in event 68 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 69 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 70 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 71 = 2
# Pairs at theta values of: [[2.01586, 2.01587], [1.12574, 1.12568]] ([layer1,layer2])
#
# Number of pairs in event 72 = 8
# Pairs at theta values of: [[1.33073, 1.33069], [1.33073, 1.33069], [1.33073, 1.33068], [1.33073, 1.33066], [1.33073, 1.33065], [1.33073, 1.33066], [1.33073, 1.33067], [1.81086, 1.81085]] ([layer1,layer2])
#
# Number of pairs in event 73 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 74 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 75 = 2
# Pairs at theta values of: [[1.0201, 1.02009], [2.13931, 2.13934]] ([layer1,layer2])
#
# Number of pairs in event 76 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 77 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 78 = 2
# Pairs at theta values of: [[2.33395, 2.33386], [0.797877, 0.797887]] ([layer1,layer2])
#
# Number of pairs in event 79 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 80 = 2
# Pairs at theta values of: [[1.98948, 1.9895], [1.15209, 1.15205]] ([layer1,layer2])
#
# Number of pairs in event 81 = 2
# Pairs at theta values of: [[1.55043, 1.55041], [1.59121, 1.59127]] ([layer1,layer2])
#
# Number of pairs in event 82 = 11
# Pairs at theta values of: [[2.31794, 2.31795], [2.31794, 2.31795], [2.31794, 2.31793], [2.31794, 2.31791], [2.31794, 2.3179], [2.31794, 2.3179], [2.31794, 2.3179], [2.31794, 2.3179], [2.31794, 2.3179], [2.31794, 2.3179], [0.824327, 0.824299]] ([layer1,layer2])
#
# Number of pairs in event 83 = 40
# Pairs at theta values of: [[1.45356, 1.45352], [1.45356, 1.45352], [1.45356, 1.45351], [1.45356, 1.45349], [1.45356, 1.45347], [1.45356, 1.45352], [1.45356, 1.45352], [1.45356, 1.45351], [1.45356, 1.45349], [1.45356, 1.45347], [1.45357, 1.45352], [1.45357, 1.45352], [1.45357, 1.45351], [1.45357, 1.45349], [1.45357, 1.45347], [1.45354, 1.45352], [1.45354, 1.45352], [1.45354, 1.45351], [1.45354, 1.45349], [1.45354, 1.45347], [1.45354, 1.45345], [1.45353, 1.45352], [1.45353, 1.45352], [1.45353, 1.45351], [1.45353, 1.45349], [1.45353, 1.45347], [1.45353, 1.45345], [1.45353, 1.45352], [1.45353, 1.45352], [1.45353, 1.45351], [1.45353, 1.45349], [1.45353, 1.45347], [1.45353, 1.45345], [1.45354, 1.45352], [1.45354, 1.45352], [1.45354, 1.45351], [1.45354, 1.45349], [1.45354, 1.45347], [1.45354, 1.45345], [1.68802, 1.68804]] ([layer1,layer2])
#
# Number of pairs in event 84 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 85 = 2
# Pairs at theta values of: [[1.6585, 1.65851], [1.48308, 1.48304]] ([layer1,layer2])
#
# Number of pairs in event 86 = 9
# Pairs at theta values of: [[1.18114, 1.18113], [1.96047, 1.96051], [1.96047, 1.96051], [1.96047, 1.9605], [1.96047, 1.96046], [1.96047, 1.96044], [1.96047, 1.96042], [1.96047, 1.96041], [1.96047, 1.9604]] ([layer1,layer2])
#
# Number of pairs in event 87 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 88 = 2
# Pairs at theta values of: [[1.7785, 1.77851], [1.36212, 1.3621]] ([layer1,layer2])
#
# Number of pairs in event 89 = 2
# Pairs at theta values of: [[2.05739, 2.05742], [1.08418, 1.08418]] ([layer1,layer2])
#
# Number of pairs in event 90 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 91 = 2
# Pairs at theta values of: [[1.99763, 1.99764], [1.14395, 1.14393]] ([layer1,layer2])
#
# Number of pairs in event 92 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 93 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 94 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 95 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 96 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 97 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 98 = 4
# Pairs at theta values of: [[1.97304, 1.97308], [1.97304, 1.97308], [1.97304, 1.97304], [1.16857, 1.16859]] ([layer1,layer2])
#
# Number of pairs in event 99 = 2
# Pairs at theta values of: [[2.27288, 2.27291], [0.873416, 0.87338]] ([layer1,layer2])
#
# Number of pairs in event 100 = 7
# Pairs at theta values of: [[1.30198, 1.30198], [1.8396, 1.83956], [1.8396, 1.83956], [1.8396, 1.83957], [1.8396, 1.83953], [1.8396, 1.83953], [1.8396, 1.83952]] ([layer1,layer2])
#
# Number of pairs in event 101 = 2
# Pairs at theta values of: [[1.1451, 1.14508], [1.99656, 1.99657]] ([layer1,layer2])
#
# Number of pairs in event 102 = 2
# Pairs at theta values of: [[2.26565, 2.26564], [0.899959, 0.899942]] ([layer1,layer2])
#
# Number of pairs in event 103 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 104 = 2
# Pairs at theta values of: [[1.05723, 1.0572], [2.0844, 2.08444]] ([layer1,layer2])
#
# Number of pairs in event 105 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 106 = 2
# Pairs at theta values of: [[1.75859, 1.75858], [1.38305, 1.38303]] ([layer1,layer2])
#
# Number of pairs in event 107 = 2
# Pairs at theta values of: [[2.3193, 2.31939], [0.822443, 0.822463]] ([layer1,layer2])
#
# Number of pairs in event 108 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 109 = 2
# Pairs at theta values of: [[1.23896, 1.23897], [1.90264, 1.90269]] ([layer1,layer2])
#
# Number of pairs in event 110 = 2
# Pairs at theta values of: [[2.31355, 2.31355], [0.828044, 0.828037]] ([layer1,layer2])
#
# Number of pairs in event 111 = 6
# Pairs at theta values of: [[0.915912, 0.915881], [2.22569, 2.2257], [2.22569, 2.2257], [2.22569, 2.22569], [2.22569, 2.22568], [2.22569, 2.22568]] ([layer1,layer2])
#
# Number of pairs in event 112 = 2
# Pairs at theta values of: [[1.68057, 1.68055], [1.46103, 1.46103]] ([layer1,layer2])
#
# Number of pairs in event 113 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 114 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 115 = 2
# Pairs at theta values of: [[0.947063, 0.947074], [2.20218, 2.20223]] ([layer1,layer2])
#
# Number of pairs in event 116 = 2
# Pairs at theta values of: [[0.8235, 0.823494], [2.31807, 2.31808]] ([layer1,layer2])
#
# Number of pairs in event 117 = 12
# Pairs at theta values of: [[1.17738, 1.17731], [1.96702, 1.96702], [1.96702, 1.96702], [1.96702, 1.96702], [1.96702, 1.96701], [1.96702, 1.96701], [1.96702, 1.96701], [1.96702, 1.96701], [1.96702, 1.967], [1.96702, 1.967], [1.96702, 1.96699], [1.96702, 1.96699]] ([layer1,layer2])
#
# Number of pairs in event 118 = 2
# Pairs at theta values of: [[0.80318, 0.803188], [2.33845, 2.33842]] ([layer1,layer2])
#
# Number of pairs in event 119 = 2
# Pairs at theta values of: [[1.01495, 1.01494], [2.12665, 2.12666]] ([layer1,layer2])
#
# Number of pairs in event 120 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 121 = 17
# Pairs at theta values of: [[1.32309, 1.32309], [1.32309, 1.32309], [1.32309, 1.32309], [1.32309, 1.32309], [1.32308, 1.32309], [1.32307, 1.32309], [1.32306, 1.32309], [1.32305, 1.32309], [1.32305, 1.32309], [1.32304, 1.32309], [1.32304, 1.32309], [1.32304, 1.32309], [1.32304, 1.32309], [1.32303, 1.32309], [1.32303, 1.32309], [1.32302, 1.32309], [1.81852, 1.81852]] ([layer1,layer2])
#
# Number of pairs in event 122 = 6
# Pairs at theta values of: [[1.58535, 1.58537], [1.55627, 1.55625], [1.55627, 1.55625], [1.55627, 1.55627], [1.55627, 1.55629], [1.55627, 1.55631]] ([layer1,layer2])
#
# Number of pairs in event 123 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 124 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 125 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 126 = 5
# Pairs at theta values of: [[1.11098, 1.11102], [2.03093, 2.03093], [2.03093, 2.03093], [2.03099, 2.03093], [2.031, 2.03093]] ([layer1,layer2])
#
# Number of pairs in event 127 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 128 = 13
# Pairs at theta values of: [[1.08965, 1.08959], [2.04897, 2.049], [2.04897, 2.049], [2.04897, 2.049], [2.04897, 2.049], [2.04899, 2.049], [2.04899, 2.049], [2.04899, 2.049], [2.04898, 2.049], [2.04896, 2.049], [2.04894, 2.049], [2.04893, 2.049], [2.04891, 2.049]] ([layer1,layer2])
#
# Number of pairs in event 129 = 2
# Pairs at theta values of: [[1.46804, 1.46807], [1.67348, 1.67344]] ([layer1,layer2])
#
# Number of pairs in event 130 = 2
# Pairs at theta values of: [[2.19893, 2.19892], [0.950562, 0.95056]] ([layer1,layer2])
#
# Number of pairs in event 131 = 2
# Pairs at theta values of: [[0.836413, 0.836362], [2.3051, 2.3051]] ([layer1,layer2])
#
# Number of pairs in event 132 = 2
# Pairs at theta values of: [[2.16946, 2.16945], [1.15262, 1.15257]] ([layer1,layer2])
#
# Number of pairs in event 133 = 2
# Pairs at theta values of: [[1.92246, 1.92246], [1.21915, 1.21917]] ([layer1,layer2])
#
# Number of pairs in event 134 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 135 = 12
# Pairs at theta values of: [[1.68047, 1.68046], [1.46113, 1.46112], [1.46113, 1.46112], [1.46111, 1.46112], [1.4611, 1.46112], [1.46108, 1.46112], [1.46107, 1.46112], [1.46106, 1.46112], [1.46105, 1.46112], [1.46105, 1.46112], [1.46103, 1.46112], [1.46102, 1.46112]] ([layer1,layer2])
#
# Number of pairs in event 136 = 10
# Pairs at theta values of: [[1.75514, 1.75517], [1.3865, 1.38648], [1.3865, 1.38648], [1.3865, 1.38646], [1.3865, 1.38643], [1.3865, 1.38642], [1.3865, 1.38641], [1.3865, 1.38641], [1.3865, 1.38641], [1.3865, 1.38641]] ([layer1,layer2])
#
# Number of pairs in event 137 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 138 = 2
# Pairs at theta values of: [[0.799853, 0.799862], [2.34172, 2.34177]] ([layer1,layer2])
#
# Number of pairs in event 139 = 2
# Pairs at theta values of: [[1.51617, 1.51617], [1.62541, 1.62542]] ([layer1,layer2])
#
# Number of pairs in event 140 = 5
# Pairs at theta values of: [[0.965833, 0.96583], [2.17572, 2.17579], [2.17572, 2.17579], [2.17572, 2.17579], [2.17572, 2.17578]] ([layer1,layer2])
#
# Number of pairs in event 141 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 142 = 2
# Pairs at theta values of: [[1.89815, 1.89814], [1.24346, 1.24347]] ([layer1,layer2])
#
# Number of pairs in event 143 = 2
# Pairs at theta values of: [[1.39209, 1.39211], [1.74912, 1.74912]] ([layer1,layer2])
#
# Number of pairs in event 144 = 2
# Pairs at theta values of: [[2.13905, 2.13905], [1.34314, 1.34304]] ([layer1,layer2])
#
# Number of pairs in event 145 = 2
# Pairs at theta values of: [[0.87883, 0.878816], [2.26276, 2.26279]] ([layer1,layer2])
#
# Number of pairs in event 146 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 147 = 15
# Pairs at theta values of: [[1.06405, 1.06401], [2.07771, 2.07778], [2.07771, 2.07778], [2.07771, 2.07778], [2.07771, 2.07778], [2.07771, 2.07778], [2.07771, 2.07778], [2.07771, 2.07778], [2.07771, 2.07778], [2.07771, 2.07778], [2.07771, 2.07778], [2.07771, 2.07778], [2.07771, 2.07778], [2.07771, 2.07778], [2.07771, 2.07778]] ([layer1,layer2])
#
# Number of pairs in event 148 = 10
# Pairs at theta values of: [[1.70571, 1.70573], [1.43585, 1.43585], [1.43585, 1.43585], [1.43585, 1.43585], [1.43585, 1.43583], [1.43585, 1.43584], [1.43585, 1.43586], [1.43585, 1.43587], [1.43585, 1.43588], [1.43585, 1.43589]] ([layer1,layer2])
#
# Number of pairs in event 149 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 150 = 2
# Pairs at theta values of: [[1.7715, 1.77151], [1.3702, 1.37019]] ([layer1,layer2])
#
# Number of pairs in event 151 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 152 = 2
# Pairs at theta values of: [[0.838136, 0.838132], [2.30343, 2.30345]] ([layer1,layer2])
#
# Number of pairs in event 153 = 2
# Pairs at theta values of: [[2.03401, 2.03401], [1.10755, 1.10749]] ([layer1,layer2])
#
# Number of pairs in event 154 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 155 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 156 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 157 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 158 = 1
# Pairs at theta values of: [[1.65869, 1.65868]] ([layer1,layer2])
#
# Number of pairs in event 159 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 160 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 161 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 162 = 2
# Pairs at theta values of: [[1.26146, 1.26145], [1.88012, 1.88009]] ([layer1,layer2])
#
# Number of pairs in event 163 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 164 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 165 = 6
# Pairs at theta values of: [[1.39514, 1.39516], [1.74703, 1.74701], [1.74703, 1.74701], [1.74703, 1.74699], [1.74703, 1.74703], [1.74703, 1.74704]] ([layer1,layer2])
#
# Number of pairs in event 166 = 2
# Pairs at theta values of: [[1.05527, 1.05523], [2.08648, 2.08649]] ([layer1,layer2])
#
# Number of pairs in event 167 = 2
# Pairs at theta values of: [[0.930992, 0.930918], [2.21025, 2.21028]] ([layer1,layer2])
#
# Number of pairs in event 168 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 169 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 170 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 171 = 2
# Pairs at theta values of: [[2.1082, 2.10823], [1.03347, 1.03345]] ([layer1,layer2])
#
# Number of pairs in event 172 = 9
# Pairs at theta values of: [[1.3149, 1.3149], [1.82668, 1.82673], [1.82668, 1.82673], [1.82668, 1.82675], [1.82668, 1.82675], [1.82668, 1.82676], [1.82668, 1.82676], [1.82668, 1.82676], [1.82668, 1.82676]] ([layer1,layer2])
#
# Number of pairs in event 173 = 5
# Pairs at theta values of: [[1.71834, 1.71834], [1.71834, 1.71834], [1.42326, 1.42326], [1.42326, 1.42326], [1.42326, 1.4233]] ([layer1,layer2])
#
# Number of pairs in event 174 = 2
# Pairs at theta values of: [[2.31015, 2.31013], [0.830325, 0.830287]] ([layer1,layer2])
#
# Number of pairs in event 175 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 176 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 177 = 2
# Pairs at theta values of: [[2.31798, 2.31801], [0.823637, 0.823584]] ([layer1,layer2])
#
# Number of pairs in event 178 = 1
# Pairs at theta values of: [[0.82544, 0.825444]] ([layer1,layer2])
#
# Number of pairs in event 179 = 2
# Pairs at theta values of: [[1.05478, 1.0548], [2.08681, 2.08683]] ([layer1,layer2])
#
# Number of pairs in event 180 = 2
# Pairs at theta values of: [[0.878883, 0.878841], [2.26271, 2.26275]] ([layer1,layer2])
#
# Number of pairs in event 181 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 182 = 2
# Pairs at theta values of: [[1.37024, 1.37023], [1.77109, 1.77109]] ([layer1,layer2])
#
# Number of pairs in event 183 = 9
# Pairs at theta values of: [[2.33772, 2.33774], [0.803893, 0.803856], [0.803893, 0.803856], [0.803882, 0.803856], [0.803862, 0.803856], [0.803858, 0.803856], [0.803873, 0.803856], [0.80388, 0.803856], [0.803883, 0.803856]] ([layer1,layer2])
#
# Number of pairs in event 184 = 1
# Pairs at theta values of: [[1.51457, 1.51449]] ([layer1,layer2])
#
# Number of pairs in event 185 = 2
# Pairs at theta values of: [[2.18018, 2.18019], [0.961529, 0.961555]] ([layer1,layer2])
#
# Number of pairs in event 186 = 2
# Pairs at theta values of: [[1.98682, 1.98677], [1.1542, 1.15421]] ([layer1,layer2])
#
# Number of pairs in event 187 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 188 = 2
# Pairs at theta values of: [[1.35249, 1.35251], [1.78914, 1.78914]] ([layer1,layer2])
#
# Number of pairs in event 189 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 190 = 4
# Pairs at theta values of: [[1.59805, 1.59806], [1.54065, 1.54065], [1.54065, 1.54065], [1.54073, 1.54065]] ([layer1,layer2])
#
# Number of pairs in event 191 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 192 = 2
# Pairs at theta values of: [[1.26233, 1.26227], [1.87926, 1.87924]] ([layer1,layer2])
#
# Number of pairs in event 193 = 12
# Pairs at theta values of: [[1.92823, 1.92822], [1.92823, 1.92822], [1.92821, 1.92822], [1.9282, 1.92822], [1.92822, 1.92822], [1.92826, 1.92822], [1.92831, 1.92822], [1.9282, 1.92822], [1.92822, 1.92822], [1.92821, 1.92822], [1.9282, 1.92822], [1.2137, 1.21365]] ([layer1,layer2])
#
# Number of pairs in event 194 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 195 = 4
# Pairs at theta values of: [[1.86085, 1.8609], [1.86085, 1.8609], [1.86084, 1.8609], [1.28077, 1.28075]] ([layer1,layer2])
#
# Number of pairs in event 196 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 197 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 198 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 199 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 200 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 201 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 202 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 203 = 2
# Pairs at theta values of: [[2.21449, 2.2145], [0.927073, 0.927067]] ([layer1,layer2])
#
# Number of pairs in event 204 = 2
# Pairs at theta values of: [[1.18244, 1.18248], [1.95915, 1.95916]] ([layer1,layer2])
#
# Number of pairs in event 205 = 2
# Pairs at theta values of: [[1.1056, 1.10558], [2.03599, 2.03605]] ([layer1,layer2])
#
# Number of pairs in event 206 = 2
# Pairs at theta values of: [[1.4337, 1.43373], [1.70792, 1.70794]] ([layer1,layer2])
#
# Number of pairs in event 207 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 208 = 2
# Pairs at theta values of: [[0.986828, 0.986803], [2.15477, 2.15479]] ([layer1,layer2])
#
# Number of pairs in event 209 = 2
# Pairs at theta values of: [[1.01734, 1.01731], [2.12427, 2.12434]] ([layer1,layer2])
#
# Number of pairs in event 210 = 8
# Pairs at theta values of: [[2.28372, 2.28372], [2.28372, 2.28372], [2.28369, 2.28372], [2.28371, 2.28372], [2.28371, 2.28372], [2.28371, 2.28372], [2.28372, 2.28372], [0.858311, 0.858339]] ([layer1,layer2])
#
# Number of pairs in event 211 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 212 = 2
# Pairs at theta values of: [[0.808062, 0.808039], [2.33354, 2.33354]] ([layer1,layer2])
#
# Number of pairs in event 213 = 6
# Pairs at theta values of: [[1.07164, 1.07163], [1.07164, 1.07163], [1.07161, 1.07163], [1.07158, 1.07163], [1.07153, 1.07163], [2.07, 2.06999]] ([layer1,layer2])
#
# Number of pairs in event 214 = 2
# Pairs at theta values of: [[1.62591, 1.62595], [1.50819, 1.50821]] ([layer1,layer2])
#
# Number of pairs in event 215 = 2
# Pairs at theta values of: [[0.998224, 0.998192], [2.14335, 2.14336]] ([layer1,layer2])
#
# Number of pairs in event 216 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 217 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 218 = 2
# Pairs at theta values of: [[1.68863, 1.68866], [1.45292, 1.45293]] ([layer1,layer2])
#
# Number of pairs in event 219 = 2
# Pairs at theta values of: [[1.74746, 1.74742], [1.4009, 1.40091]] ([layer1,layer2])
#
# Number of pairs in event 220 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 221 = 5
# Pairs at theta values of: [[2.30904, 2.30905], [2.30904, 2.30905], [2.30908, 2.30905], [2.30914, 2.30905], [0.832548, 0.832515]] ([layer1,layer2])
#
# Number of pairs in event 222 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 223 = 2
# Pairs at theta values of: [[1.83598, 1.83598], [1.30563, 1.30562]] ([layer1,layer2])
#
# Number of pairs in event 224 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 225 = 2
# Pairs at theta values of: [[1.06121, 1.06121], [2.08038, 2.08039]] ([layer1,layer2])
#
# Number of pairs in event 226 = 2
# Pairs at theta values of: [[2.30849, 2.30851], [0.83339, 0.833386]] ([layer1,layer2])
#
# Number of pairs in event 227 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 228 = 2
# Pairs at theta values of: [[1.73533, 1.73532], [1.38742, 1.38741]] ([layer1,layer2])
#
# Number of pairs in event 229 = 2
# Pairs at theta values of: [[1.84828, 1.84828], [1.29333, 1.29336]] ([layer1,layer2])
#
# Number of pairs in event 230 = 8
# Pairs at theta values of: [[1.23745, 1.23745], [1.23745, 1.23745], [1.23745, 1.23745], [1.23745, 1.23743], [1.23745, 1.23742], [1.23745, 1.23741], [1.23745, 1.2374], [1.90414, 1.90409]] ([layer1,layer2])
#
# Number of pairs in event 231 = 2
# Pairs at theta values of: [[1.66354, 1.66352], [1.47809, 1.47808]] ([layer1,layer2])
#
# Number of pairs in event 232 = 2
# Pairs at theta values of: [[2.31133, 2.31135], [0.830225, 0.830196]] ([layer1,layer2])
#
# Number of pairs in event 233 = 2
# Pairs at theta values of: [[1.58813, 1.58813], [1.55347, 1.55349]] ([layer1,layer2])
#
# Number of pairs in event 234 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 235 = 6
# Pairs at theta values of: [[1.04225, 1.04224], [1.04225, 1.04224], [1.04225, 1.04224], [1.04225, 1.04228], [1.04225, 1.04228], [2.09935, 2.09937]] ([layer1,layer2])
#
# Number of pairs in event 236 = 2
# Pairs at theta values of: [[2.17192, 2.17194], [0.969651, 0.96965]] ([layer1,layer2])
#
# Number of pairs in event 237 = 2
# Pairs at theta values of: [[1.79966, 1.79967], [1.34197, 1.34195]] ([layer1,layer2])
#
# Number of pairs in event 238 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 239 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 240 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 241 = 2
# Pairs at theta values of: [[1.42547, 1.42547], [1.71611, 1.71608]] ([layer1,layer2])
#
# Number of pairs in event 242 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 243 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 244 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 245 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 246 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 247 = 2
# Pairs at theta values of: [[2.29806, 2.29808], [0.850144, 0.850063]] ([layer1,layer2])
#
# Number of pairs in event 248 = 2
# Pairs at theta values of: [[1.35976, 1.35976], [1.78183, 1.7818]] ([layer1,layer2])
#
# Number of pairs in event 249 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 250 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 251 = 2
# Pairs at theta values of: [[1.60291, 1.60288], [1.53872, 1.53874]] ([layer1,layer2])
#
# Number of pairs in event 252 = 2
# Pairs at theta values of: [[1.05249, 1.05246], [2.0887, 2.08876]] ([layer1,layer2])
#
# Number of pairs in event 253 = 26
# Pairs at theta values of: [[1.08066, 1.0806], [1.08066, 1.0806], [1.08066, 1.08064], [1.08066, 1.08066], [1.08066, 1.08064], [1.08066, 1.08062], [1.08066, 1.08059], [1.08066, 1.08056], [1.08066, 1.0806], [1.08066, 1.0806], [1.08066, 1.08064], [1.08066, 1.08066], [1.08066, 1.08064], [1.08066, 1.08062], [1.08066, 1.08059], [1.08066, 1.08056], [1.08075, 1.08066], [2.0609, 2.06093], [2.0609, 2.06093], [2.0609, 2.06093], [2.0609, 2.06093], [2.0609, 2.06094], [2.0609, 2.06094], [2.0609, 2.06094], [2.0609, 2.06095], [2.0609, 2.06095]] ([layer1,layer2])
#
# Number of pairs in event 254 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 255 = 7
# Pairs at theta values of: [[1.99619, 1.99621], [1.14539, 1.14539], [1.14539, 1.14539], [1.1454, 1.14539], [1.14546, 1.14539], [1.14546, 1.14539], [1.14545, 1.14539]] ([layer1,layer2])
#
# Number of pairs in event 256 = 1
# Pairs at theta values of: [[1.77987, 1.77988]] ([layer1,layer2])
#
# Number of pairs in event 257 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 258 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 259 = 25
# Pairs at theta values of: [[0.78949, 0.789482], [2.35212, 2.35215], [2.35212, 2.35215], [2.35212, 2.35211], [2.35212, 2.35209], [2.35212, 2.35209], [2.35212, 2.35203], [2.35212, 2.35203], [2.35212, 2.35204], [2.35212, 2.35205], [2.35212, 2.35205], [2.35212, 2.35206], [2.35212, 2.35206], [2.35212, 2.35205], [2.35212, 2.35205], [2.35212, 2.35203], [2.35212, 2.35204], [2.35212, 2.35205], [2.35212, 2.35206], [2.35212, 2.35207], [2.35212, 2.35208], [2.35212, 2.35209], [2.35212, 2.3521], [2.35212, 2.35211], [2.35212, 2.35211]] ([layer1,layer2])
#
# Number of pairs in event 260 = 24
# Pairs at theta values of: [[1.53297, 1.53298], [1.53297, 1.53298], [1.53297, 1.53299], [1.53297, 1.53298], [1.53297, 1.53298], [1.53297, 1.53297], [1.53297, 1.53294], [1.53297, 1.53292], [1.53297, 1.53298], [1.53297, 1.53298], [1.53297, 1.53299], [1.53297, 1.53298], [1.53297, 1.53298], [1.53297, 1.53297], [1.53297, 1.53294], [1.53297, 1.53292], [1.53305, 1.53298], [1.53305, 1.53298], [1.53305, 1.53299], [1.53305, 1.53298], [1.53305, 1.53298], [1.53305, 1.53297], [1.53309, 1.53299], [1.6017, 1.60168]] ([layer1,layer2])
#
# Number of pairs in event 261 = 2
# Pairs at theta values of: [[1.02825, 1.02822], [2.11336, 2.1134]] ([layer1,layer2])
#
# Number of pairs in event 262 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 263 = 2
# Pairs at theta values of: [[1.60675, 1.60677], [1.53484, 1.53478]] ([layer1,layer2])
#
# Number of pairs in event 264 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 265 = 2
# Pairs at theta values of: [[0.900936, 0.900859], [2.24067, 2.24063]] ([layer1,layer2])
#
# Number of pairs in event 266 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 267 = 2
# Pairs at theta values of: [[1.08034, 1.08036], [2.06126, 2.06135]] ([layer1,layer2])
#
# Number of pairs in event 268 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 269 = 2
# Pairs at theta values of: [[1.42321, 1.42325], [1.71838, 1.7184]] ([layer1,layer2])
#
# Number of pairs in event 270 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 271 = 2
# Pairs at theta values of: [[1.82022, 1.82022], [1.32135, 1.32135]] ([layer1,layer2])
#
# Number of pairs in event 272 = 2
# Pairs at theta values of: [[0.947671, 0.947662], [2.19396, 2.19395]] ([layer1,layer2])
#
# Number of pairs in event 273 = 2
# Pairs at theta values of: [[2.07068, 2.07071], [1.07084, 1.07086]] ([layer1,layer2])
#
# Number of pairs in event 274 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 275 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 276 = 10
# Pairs at theta values of: [[1.01541, 1.0154], [1.01541, 1.0154], [1.01541, 1.0154], [1.01541, 1.01541], [1.01541, 1.01542], [1.01541, 1.0154], [1.01541, 1.01539], [1.01541, 1.01538], [1.01541, 1.01539], [2.12629, 2.12629]] ([layer1,layer2])
#
# Number of pairs in event 277 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 278 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 279 = 2
# Pairs at theta values of: [[1.5521, 1.55211], [1.61639, 1.61636]] ([layer1,layer2])
#
# Number of pairs in event 280 = 2
# Pairs at theta values of: [[1.49992, 1.49996], [1.64166, 1.64167]] ([layer1,layer2])
#
# Number of pairs in event 281 = 5
# Pairs at theta values of: [[0.888338, 0.888321], [2.25328, 2.2533], [2.25328, 2.2533], [2.25328, 2.25327], [2.25328, 2.25326]] ([layer1,layer2])
#
# Number of pairs in event 282 = 2
# Pairs at theta values of: [[1.8634, 1.86341], [1.29124, 1.29128]] ([layer1,layer2])
#
# Number of pairs in event 283 = 2
# Pairs at theta values of: [[2.21348, 2.2135], [0.928162, 0.92815]] ([layer1,layer2])
#
# Number of pairs in event 284 = 4
# Pairs at theta values of: [[1.12937, 1.12936], [1.12937, 1.12936], [1.12936, 1.12936], [2.01221, 2.01224]] ([layer1,layer2])
#
# Number of pairs in event 285 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 286 = 2
# Pairs at theta values of: [[1.23872, 1.23876], [1.90289, 1.90292]] ([layer1,layer2])
#
# Number of pairs in event 287 = 2
# Pairs at theta values of: [[1.19229, 1.19229], [1.94929, 1.94929]] ([layer1,layer2])
#
# Number of pairs in event 288 = 2
# Pairs at theta values of: [[1.81956, 1.81954], [1.32205, 1.32205]] ([layer1,layer2])
#
# Number of pairs in event 289 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 290 = 2
# Pairs at theta values of: [[1.31237, 1.31241], [1.82923, 1.82922]] ([layer1,layer2])
#
# Number of pairs in event 291 = 2
# Pairs at theta values of: [[2.30441, 2.3044], [0.837156, 0.837169]] ([layer1,layer2])
#
# Number of pairs in event 292 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 293 = 2
# Pairs at theta values of: [[1.24998, 1.24998], [1.89116, 1.89117]] ([layer1,layer2])
#
# Number of pairs in event 294 = 2
# Pairs at theta values of: [[0.950325, 0.950318], [2.19124, 2.19126]] ([layer1,layer2])
#
# Number of pairs in event 295 = 2
# Pairs at theta values of: [[0.890995, 0.890972], [2.25061, 2.25059]] ([layer1,layer2])
#
# Number of pairs in event 296 = 7
# Pairs at theta values of: [[1.94988, 1.94993], [1.94988, 1.94993], [1.94988, 1.94991], [1.94988, 1.9499], [1.94988, 1.94989], [1.94988, 1.94989], [1.19169, 1.19169]] ([layer1,layer2])
#
# Number of pairs in event 297 = 2
# Pairs at theta values of: [[2.19466, 2.19467], [0.946907, 0.946883]] ([layer1,layer2])
#
# Number of pairs in event 298 = 7
# Pairs at theta values of: [[1.00315, 1.00311], [1.00315, 1.00311], [1.00318, 1.00311], [2.13842, 2.13845], [2.13842, 2.13845], [2.13838, 2.13845], [2.13838, 2.13845]] ([layer1,layer2])
#
# Number of pairs in event 299 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 300 = 2
# Pairs at theta values of: [[1.5945, 1.59453], [1.5471, 1.54705]] ([layer1,layer2])
#
# Number of pairs in event 301 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 302 = 2
# Pairs at theta values of: [[1.46112, 1.46112], [1.68052, 1.68052]] ([layer1,layer2])
#
# Number of pairs in event 303 = 2
# Pairs at theta values of: [[1.86441, 1.86439], [1.27734, 1.2773]] ([layer1,layer2])
#
# Number of pairs in event 304 = 2
# Pairs at theta values of: [[2.28239, 2.28239], [0.859173, 0.859125]] ([layer1,layer2])
#
# Number of pairs in event 305 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 306 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 307 = 2
# Pairs at theta values of: [[1.75692, 1.75694], [1.38467, 1.38469]] ([layer1,layer2])
#
# Number of pairs in event 308 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 309 = 2
# Pairs at theta values of: [[1.09289, 1.09292], [2.0488, 2.04883]] ([layer1,layer2])
#
# Number of pairs in event 310 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 311 = 2
# Pairs at theta values of: [[0.798183, 0.798148], [2.34365, 2.34366]] ([layer1,layer2])
#
# Number of pairs in event 312 = 2
# Pairs at theta values of: [[1.28969, 1.28967], [1.85186, 1.85187]] ([layer1,layer2])
#
# Number of pairs in event 313 = 1
# Pairs at theta values of: [[2.30269, 2.30271]] ([layer1,layer2])
#
# Number of pairs in event 314 = 2
# Pairs at theta values of: [[0.883104, 0.883118], [2.25851, 2.25854]] ([layer1,layer2])
#
# Number of pairs in event 315 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 316 = 2
# Pairs at theta values of: [[1.24739, 1.2474], [1.89422, 1.89422]] ([layer1,layer2])
#
# Number of pairs in event 317 = 2
# Pairs at theta values of: [[2.19989, 2.19994], [0.962109, 0.962017]] ([layer1,layer2])
#
# Number of pairs in event 318 = 2
# Pairs at theta values of: [[1.34697, 1.34697], [1.79464, 1.79467]] ([layer1,layer2])
#
# Number of pairs in event 319 = 2
# Pairs at theta values of: [[1.94853, 1.94851], [1.19332, 1.1933]] ([layer1,layer2])
#
# Number of pairs in event 320 = 2
# Pairs at theta values of: [[1.27975, 1.27975], [1.86189, 1.86189]] ([layer1,layer2])
#
# Number of pairs in event 321 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 322 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 323 = 2
# Pairs at theta values of: [[1.24781, 1.24777], [1.89379, 1.89381]] ([layer1,layer2])
#
# Number of pairs in event 324 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 325 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 326 = 2
# Pairs at theta values of: [[2.13165, 2.13169], [1.00995, 1.00996]] ([layer1,layer2])
#
# Number of pairs in event 327 = 13
# Pairs at theta values of: [[1.88759, 1.88759], [1.88759, 1.88759], [1.88759, 1.88759], [1.88759, 1.88758], [1.88759, 1.88756], [1.88759, 1.88755], [1.88759, 1.88755], [1.88759, 1.88754], [1.88759, 1.88754], [1.88759, 1.88757], [1.88759, 1.88754], [1.88759, 1.88751], [1.25395, 1.25396]] ([layer1,layer2])
#
# Number of pairs in event 328 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 329 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 330 = 2
# Pairs at theta values of: [[1.98838, 1.9884], [1.15317, 1.15316]] ([layer1,layer2])
#
# Number of pairs in event 331 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 332 = 2
# Pairs at theta values of: [[1.24179, 1.24178], [1.89984, 1.89986]] ([layer1,layer2])
#
# Number of pairs in event 333 = 2
# Pairs at theta values of: [[1.16146, 1.16148], [1.98016, 1.98021]] ([layer1,layer2])
#
# Number of pairs in event 334 = 2
# Pairs at theta values of: [[1.38882, 1.3888], [1.75177, 1.75173]] ([layer1,layer2])
#
# Number of pairs in event 335 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 336 = 2
# Pairs at theta values of: [[1.88965, 1.88965], [1.2521, 1.25208]] ([layer1,layer2])
#
# Number of pairs in event 337 = 2
# Pairs at theta values of: [[1.38965, 1.38964], [1.75189, 1.75187]] ([layer1,layer2])
#
# Number of pairs in event 338 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 339 = 5
# Pairs at theta values of: [[0.940006, 0.939979], [2.20155, 2.20155], [2.20155, 2.20155], [2.20155, 2.20157], [2.20155, 2.20158]] ([layer1,layer2])
#
# Number of pairs in event 340 = 2
# Pairs at theta values of: [[1.21482, 1.21482], [1.92677, 1.92677]] ([layer1,layer2])
#
# Number of pairs in event 341 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 342 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 343 = 4
# Pairs at theta values of: [[1.20639, 1.20638], [1.93522, 1.93522], [1.93522, 1.93522], [1.93521, 1.93522]] ([layer1,layer2])
#
# Number of pairs in event 344 = 7
# Pairs at theta values of: [[2.08125, 2.08128], [2.08125, 2.08128], [2.08125, 2.08129], [2.08125, 2.0813], [1.06032, 1.06031], [1.06032, 1.06031], [1.06032, 1.06032]] ([layer1,layer2])
#
# Number of pairs in event 345 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 346 = 2
# Pairs at theta values of: [[0.886265, 0.88624], [2.25143, 2.25149]] ([layer1,layer2])
#
# Number of pairs in event 347 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 348 = 6
# Pairs at theta values of: [[1.86559, 1.8656], [1.27597, 1.27598], [1.27597, 1.27598], [1.27597, 1.27598], [1.27594, 1.27598], [1.27588, 1.27598]] ([layer1,layer2])
#
# Number of pairs in event 349 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 350 = 2
# Pairs at theta values of: [[1.11859, 1.11857], [2.02298, 2.02298]] ([layer1,layer2])
#
# Number of pairs in event 351 = 2
# Pairs at theta values of: [[1.61045, 1.61046], [1.53111, 1.5311]] ([layer1,layer2])
#
# Number of pairs in event 352 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 353 = 2
# Pairs at theta values of: [[0.803978, 0.803964], [2.33761, 2.33763]] ([layer1,layer2])
#
# Number of pairs in event 354 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 355 = 2
# Pairs at theta values of: [[1.91863, 1.91869], [1.22296, 1.22294]] ([layer1,layer2])
#
# Number of pairs in event 356 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 357 = 6
# Pairs at theta values of: [[2.08345, 2.08345], [2.08345, 2.08345], [2.08345, 2.08347], [2.08345, 2.0835], [2.08345, 2.08354], [2.08345, 2.08354]] ([layer1,layer2])
#
# Number of pairs in event 358 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 359 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 360 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 361 = 2
# Pairs at theta values of: [[2.30996, 2.31], [0.832009, 0.832003]] ([layer1,layer2])
#
# Number of pairs in event 362 = 2
# Pairs at theta values of: [[1.72771, 1.72774], [1.41388, 1.41388]] ([layer1,layer2])
#
# Number of pairs in event 363 = 2
# Pairs at theta values of: [[1.48527, 1.48528], [1.65633, 1.65636]] ([layer1,layer2])
#
# Number of pairs in event 364 = 5
# Pairs at theta values of: [[2.05079, 2.05081], [1.09077, 1.09081], [1.09077, 1.09081], [1.09075, 1.09081], [1.09073, 1.09081]] ([layer1,layer2])
#
# Number of pairs in event 365 = 2
# Pairs at theta values of: [[1.76424, 1.76426], [1.37741, 1.37741]] ([layer1,layer2])
#
# Number of pairs in event 366 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 367 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 368 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 369 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 370 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 371 = 3
# Pairs at theta values of: [[1.30336, 1.30337], [1.30336, 1.30337], [1.30336, 1.30337]] ([layer1,layer2])
#
# Number of pairs in event 372 = 7
# Pairs at theta values of: [[1.99021, 1.99026], [1.15139, 1.15141], [1.15139, 1.15141], [1.15136, 1.15141], [1.15138, 1.15141], [1.15141, 1.15141], [1.15147, 1.15141]] ([layer1,layer2])
#
# Number of pairs in event 373 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 374 = 2
# Pairs at theta values of: [[1.10927, 1.10928], [2.03235, 2.03234]] ([layer1,layer2])
#
# Number of pairs in event 375 = 10
# Pairs at theta values of: [[1.59804, 1.59806], [1.54357, 1.54358], [1.54357, 1.54358], [1.54358, 1.54358], [1.54357, 1.54358], [1.54355, 1.54358], [1.54354, 1.54358], [1.54352, 1.54358], [1.5435, 1.54358], [1.54348, 1.54358]] ([layer1,layer2])
#
# Number of pairs in event 376 = 2
# Pairs at theta values of: [[1.76265, 1.76265], [1.37895, 1.37891]] ([layer1,layer2])
#
# Number of pairs in event 377 = 2
# Pairs at theta values of: [[1.38331, 1.38331], [1.75827, 1.75828]] ([layer1,layer2])
#
# Number of pairs in event 378 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 379 = 2
# Pairs at theta values of: [[2.01367, 2.01374], [1.12793, 1.12792]] ([layer1,layer2])
#
# Number of pairs in event 380 = 2
# Pairs at theta values of: [[1.66822, 1.6682], [1.43066, 1.43066]] ([layer1,layer2])
#
# Number of pairs in event 381 = 2
# Pairs at theta values of: [[0.967659, 0.967589], [2.1739, 2.17391]] ([layer1,layer2])
#
# ...
#
# Number of pairs in event 869 = 2
# Pairs at theta values of: [[0.964874, 0.964877], [2.17674, 2.17678]] ([layer1,layer2])
#
# Number of pairs in event 870 = 2
# Pairs at theta values of: [[1.15707, 1.15707], [1.98474, 1.98476]] ([layer1,layer2])
#
# Number of pairs in event 871 = 8
# Pairs at theta values of: [[2.07621, 2.07619], [1.06536, 1.06531], [1.06536, 1.06531], [1.06537, 1.06531], [1.06535, 1.06531], [1.06532, 1.06531], [1.06529, 1.06531], [1.06528, 1.06531]] ([layer1,layer2])
#
# Number of pairs in event 872 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 873 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 874 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 875 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 876 = 5
# Pairs at theta values of: [[2.03528, 2.0353], [1.10632, 1.10631], [1.10632, 1.10631], [1.10632, 1.10628], [1.10632, 1.10626]] ([layer1,layer2])
#
# Number of pairs in event 877 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 878 = 2
# Pairs at theta values of: [[1.94308, 1.94306], [1.19844, 1.19839]] ([layer1,layer2])
#
# Number of pairs in event 879 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 880 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 881 = 8
# Pairs at theta values of: [[1.18167, 1.18165], [1.9613, 1.96136], [1.9613, 1.96136], [1.9613, 1.96136], [1.9613, 1.96135], [1.9613, 1.96135], [1.9613, 1.96135], [1.9613, 1.96135]] ([layer1,layer2])
#
# Number of pairs in event 882 = 3
# Pairs at theta values of: [[1.81096, 1.81097], [1.33063, 1.33068], [1.33063, 1.33068]] ([layer1,layer2])
#
# Number of pairs in event 883 = 2
# Pairs at theta values of: [[1.78549, 1.7855], [1.36194, 1.36193]] ([layer1,layer2])
#
# Number of pairs in event 884 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 885 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 886 = 5
# Pairs at theta values of: [[1.65633, 1.65632], [1.65633, 1.65632], [1.65638, 1.65632], [1.65642, 1.65632], [1.48454, 1.48452]] ([layer1,layer2])
#
# Number of pairs in event 887 = 6
# Pairs at theta values of: [[1.6685, 1.66851], [1.4729, 1.4729], [1.4729, 1.4729], [1.4729, 1.47289], [1.4729, 1.47289], [1.4729, 1.47288]] ([layer1,layer2])
#
# Number of pairs in event 888 = 2
# Pairs at theta values of: [[1.50208, 1.50209], [1.63952, 1.63949]] ([layer1,layer2])
#
# Number of pairs in event 889 = 2
# Pairs at theta values of: [[1.57133, 1.57138], [1.61255, 1.61258]] ([layer1,layer2])
#
# Number of pairs in event 890 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 891 = 2
# Pairs at theta values of: [[1.73231, 1.73234], [1.4093, 1.40931]] ([layer1,layer2])
#
# Number of pairs in event 892 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 893 = 2
# Pairs at theta values of: [[1.69276, 1.69272], [1.46712, 1.46711]] ([layer1,layer2])
#
# Number of pairs in event 894 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 895 = 2
# Pairs at theta values of: [[0.9572, 0.957186], [2.18435, 2.18438]] ([layer1,layer2])
#
# Number of pairs in event 896 = 2
# Pairs at theta values of: [[0.970872, 0.970849], [2.17072, 2.17073]] ([layer1,layer2])
#
# Number of pairs in event 897 = 2
# Pairs at theta values of: [[1.95121, 1.95124], [1.18967, 1.18965]] ([layer1,layer2])
#
# Number of pairs in event 898 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 899 = 2
# Pairs at theta values of: [[1.33536, 1.33537], [1.80624, 1.80624]] ([layer1,layer2])
#
# Number of pairs in event 900 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 901 = 2
# Pairs at theta values of: [[2.17222, 2.1722], [0.965869, 0.965875]] ([layer1,layer2])
#
# Number of pairs in event 902 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 903 = 2
# Pairs at theta values of: [[1.53747, 1.53748], [1.60413, 1.60413]] ([layer1,layer2])
#
# Number of pairs in event 904 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 905 = 2
# Pairs at theta values of: [[1.92328, 1.92326], [1.21832, 1.21832]] ([layer1,layer2])
#
# Number of pairs in event 906 = 6
# Pairs at theta values of: [[1.53846, 1.53844], [1.53846, 1.53844], [1.53846, 1.5384], [1.53846, 1.53841], [1.53846, 1.53841], [1.60313, 1.60313]] ([layer1,layer2])
#
# Number of pairs in event 907 = 2
# Pairs at theta values of: [[1.6994, 1.69941], [1.44702, 1.44699]] ([layer1,layer2])
#
# Number of pairs in event 908 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 909 = 2
# Pairs at theta values of: [[1.40229, 1.40228], [1.73929, 1.73927]] ([layer1,layer2])
#
# Number of pairs in event 910 = 2
# Pairs at theta values of: [[0.801536, 0.801549], [2.34006, 2.34008]] ([layer1,layer2])
#
# Number of pairs in event 911 = 1
# Pairs at theta values of: [[1.72472, 1.72473]] ([layer1,layer2])
#
# Number of pairs in event 912 = 2
# Pairs at theta values of: [[1.15967, 1.15966], [1.98193, 1.98193]] ([layer1,layer2])
#
# Number of pairs in event 913 = 7
# Pairs at theta values of: [[1.33607, 1.33608], [1.80554, 1.80553], [1.80554, 1.80553], [1.8055, 1.80553], [1.80548, 1.80553], [1.8055, 1.80553], [1.80553, 1.80553]] ([layer1,layer2])
#
# Number of pairs in event 914 = 2
# Pairs at theta values of: [[1.6575, 1.6575], [1.48409, 1.48408]] ([layer1,layer2])
#
# Number of pairs in event 915 = 2
# Pairs at theta values of: [[1.9145, 1.91449], [1.22943, 1.22942]] ([layer1,layer2])
#
# Number of pairs in event 916 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 917 = 11
# Pairs at theta values of: [[1.34002, 1.33998], [1.80156, 1.80159], [1.80156, 1.80159], [1.80156, 1.8016], [1.80156, 1.8016], [1.80156, 1.8016], [1.80156, 1.8016], [1.80156, 1.8016], [1.80156, 1.8016], [1.80156, 1.80159], [1.80156, 1.8016]] ([layer1,layer2])
#
# Number of pairs in event 918 = 2
# Pairs at theta values of: [[2.16306, 2.16313], [0.97851, 0.978511]] ([layer1,layer2])
#
# Number of pairs in event 919 = 2
# Pairs at theta values of: [[2.07797, 2.07802], [1.06381, 1.06377]] ([layer1,layer2])
#
# Number of pairs in event 920 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 921 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 922 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 923 = 6
# Pairs at theta values of: [[1.42569, 1.42572], [1.42569, 1.42572], [1.42569, 1.42571], [1.42569, 1.42571], [1.42569, 1.42571], [1.73485, 1.73485]] ([layer1,layer2])
#
# Number of pairs in event 924 = 2
# Pairs at theta values of: [[2.04572, 2.04572], [1.09588, 1.09584]] ([layer1,layer2])
#
# Number of pairs in event 925 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 926 = 2
# Pairs at theta values of: [[1.19241, 1.19243], [1.94914, 1.94916]] ([layer1,layer2])
#
# Number of pairs in event 927 = 2
# Pairs at theta values of: [[2.19268, 2.19269], [0.948912, 0.948895]] ([layer1,layer2])
#
# Number of pairs in event 928 = 2
# Pairs at theta values of: [[1.58224, 1.58224], [1.55937, 1.55937]] ([layer1,layer2])
#
# Number of pairs in event 929 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 930 = 2
# Pairs at theta values of: [[1.86541, 1.86545], [1.27621, 1.27623]] ([layer1,layer2])
#
# Number of pairs in event 931 = 1
# Pairs at theta values of: [[0.809143, 0.809161]] ([layer1,layer2])
#
# Number of pairs in event 932 = 5
# Pairs at theta values of: [[1.88488, 1.88487], [1.25672, 1.25671], [1.25672, 1.25671], [1.25667, 1.25671], [1.25666, 1.25671]] ([layer1,layer2])
#
# Number of pairs in event 933 = 2
# Pairs at theta values of: [[2.19127, 2.19127], [0.9503, 0.950301]] ([layer1,layer2])
#
# Number of pairs in event 934 = 2
# Pairs at theta values of: [[1.1375, 1.13751], [2.00405, 2.00405]] ([layer1,layer2])
#
# Number of pairs in event 935 = 10
# Pairs at theta values of: [[1.74803, 1.74803], [1.39356, 1.39357], [1.39356, 1.39357], [1.39356, 1.39356], [1.39356, 1.39355], [1.39356, 1.39354], [1.39356, 1.39353], [1.39356, 1.39352], [1.39356, 1.39354], [1.39356, 1.39355]] ([layer1,layer2])
#
# Number of pairs in event 936 = 2
# Pairs at theta values of: [[1.5657, 1.5657], [1.45423, 1.45422]] ([layer1,layer2])
#
# Number of pairs in event 937 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 938 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 939 = 2
# Pairs at theta values of: [[1.23758, 1.23757], [1.90401, 1.904]] ([layer1,layer2])
#
# Number of pairs in event 940 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 941 = 2
# Pairs at theta values of: [[1.93511, 1.93509], [1.20652, 1.20653]] ([layer1,layer2])
#
# Number of pairs in event 942 = 1
# Pairs at theta values of: [[2.32146, 2.3215]] ([layer1,layer2])
#
# Number of pairs in event 943 = 2
# Pairs at theta values of: [[2.17704, 2.17703], [0.964571, 0.96455]] ([layer1,layer2])
#
# Number of pairs in event 944 = 2
# Pairs at theta values of: [[2.24203, 2.24203], [0.899574, 0.899599]] ([layer1,layer2])
#
# Number of pairs in event 945 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 946 = 2
# Pairs at theta values of: [[1.4985, 1.4985], [1.64312, 1.64314]] ([layer1,layer2])
#
# Number of pairs in event 947 = 2
# Pairs at theta values of: [[1.69229, 1.69233], [1.44933, 1.44933]] ([layer1,layer2])
#
# Number of pairs in event 948 = 2
# Pairs at theta values of: [[1.48925, 1.48927], [1.65241, 1.65243]] ([layer1,layer2])
#
# Number of pairs in event 949 = 2
# Pairs at theta values of: [[2.35437, 2.35437], [0.787185, 0.78715]] ([layer1,layer2])
#
# Number of pairs in event 950 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 951 = 9
# Pairs at theta values of: [[1.04308, 1.04306], [1.04308, 1.04306], [1.04306, 1.04306], [1.04305, 1.04306], [1.04304, 1.04306], [2.09692, 2.09691], [2.09692, 2.09691], [2.09697, 2.09691], [2.09699, 2.09691]] ([layer1,layer2])
#
# Number of pairs in event 952 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 953 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 954 = 2
# Pairs at theta values of: [[1.65316, 1.65317], [1.48841, 1.48838]] ([layer1,layer2])
#
# Number of pairs in event 955 = 6
# Pairs at theta values of: [[1.32986, 1.32985], [1.32986, 1.32985], [1.32986, 1.32985], [1.32985, 1.32985], [1.32986, 1.32985], [1.81174, 1.81175]] ([layer1,layer2])
#
# Number of pairs in event 956 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 957 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 958 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 959 = 5
# Pairs at theta values of: [[1.28819, 1.28819], [1.85341, 1.8534], [1.85341, 1.8534], [1.85341, 1.85344], [1.85341, 1.85347]] ([layer1,layer2])
#
# Number of pairs in event 960 = 3
# Pairs at theta values of: [[0.978059, 0.978029], [2.16353, 2.16359], [2.16353, 2.16359]] ([layer1,layer2])
#
# Number of pairs in event 961 = 19
# Pairs at theta values of: [[1.69068, 1.6907], [1.44995, 1.44997], [1.44995, 1.44997], [1.44995, 1.44998], [1.44995, 1.44998], [1.44995, 1.44997], [1.44995, 1.44996], [1.44995, 1.44997], [1.44995, 1.44997], [1.44995, 1.44998], [1.44995, 1.44998], [1.44995, 1.44997], [1.44995, 1.44996], [1.44989, 1.44997], [1.44989, 1.44997], [1.44989, 1.44998], [1.44989, 1.44998], [1.44989, 1.44997], [1.44989, 1.44996]] ([layer1,layer2])
#
# Number of pairs in event 962 = 2
# Pairs at theta values of: [[2.05811, 2.05809], [1.08348, 1.0834]] ([layer1,layer2])
#
# Number of pairs in event 963 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 964 = 2
# Pairs at theta values of: [[1.26342, 1.26346], [1.87816, 1.87818]] ([layer1,layer2])
#
# Number of pairs in event 965 = 2
# Pairs at theta values of: [[0.97191, 0.971896], [2.16971, 2.16977]] ([layer1,layer2])
#
# Number of pairs in event 966 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 967 = 2
# Pairs at theta values of: [[1.38816, 1.38815], [1.58198, 1.582]] ([layer1,layer2])
#
# Number of pairs in event 968 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 969 = 2
# Pairs at theta values of: [[0.843872, 0.843854], [2.29769, 2.29773]] ([layer1,layer2])
#
# Number of pairs in event 970 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 971 = 2
# Pairs at theta values of: [[2.21236, 2.21238], [0.929236, 0.929263]] ([layer1,layer2])
#
# Number of pairs in event 972 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 973 = 9
# Pairs at theta values of: [[1.05986, 1.05983], [2.10664, 2.10662], [2.10664, 2.10662], [2.10664, 2.10662], [2.10663, 2.10662], [2.10662, 2.10662], [2.10664, 2.10662], [2.10665, 2.10662], [2.10665, 2.10662]] ([layer1,layer2])
#
# Number of pairs in event 974 = 8
# Pairs at theta values of: [[1.93807, 1.93811], [1.20351, 1.20353], [1.20351, 1.20353], [1.20351, 1.20351], [1.20351, 1.2035], [1.20351, 1.20348], [1.20351, 1.20346], [1.20351, 1.20346]] ([layer1,layer2])
#
# Number of pairs in event 975 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 976 = 2
# Pairs at theta values of: [[1.03785, 1.03785], [2.10388, 2.10391]] ([layer1,layer2])
#
# Number of pairs in event 977 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 978 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 979 = 2
# Pairs at theta values of: [[1.93159, 1.93162], [1.20998, 1.20998]] ([layer1,layer2])
#
# Number of pairs in event 980 = 2
# Pairs at theta values of: [[1.71249, 1.71249], [1.42914, 1.42913]] ([layer1,layer2])
#
# Number of pairs in event 981 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 982 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 983 = 2
# Pairs at theta values of: [[1.68457, 1.68454], [1.457, 1.45702]] ([layer1,layer2])
#
# Number of pairs in event 984 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 985 = 2
# Pairs at theta values of: [[1.74617, 1.74616], [1.39542, 1.39538]] ([layer1,layer2])
#
# Number of pairs in event 986 = 2
# Pairs at theta values of: [[1.77193, 1.77195], [1.36968, 1.36967]] ([layer1,layer2])
#
# Number of pairs in event 987 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 988 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 989 = 4
# Pairs at theta values of: [[1.1435, 1.14353], [1.9981, 1.99811], [1.9981, 1.99811], [1.9981, 1.99807]] ([layer1,layer2])
#
# Number of pairs in event 990 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 991 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 992 = 2
# Pairs at theta values of: [[1.53194, 1.53197], [1.60966, 1.60967]] ([layer1,layer2])
#
# Number of pairs in event 993 = 2
# Pairs at theta values of: [[0.902889, 0.902894], [2.2387, 2.2387]] ([layer1,layer2])
#
# Number of pairs in event 994 = 2
# Pairs at theta values of: [[1.25043, 1.25043], [1.89134, 1.89135]] ([layer1,layer2])
#
# Number of pairs in event 995 = 10
# Pairs at theta values of: [[2.2653, 2.26532], [2.2653, 2.26532], [2.26534, 2.26532], [2.26536, 2.26532], [2.26538, 2.26532], [2.26539, 2.26532], [2.2654, 2.26532], [2.2654, 2.26532], [2.26541, 2.26532], [0.876367, 0.876379]] ([layer1,layer2])
#
# Number of pairs in event 996 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 997 = 2
# Pairs at theta values of: [[1.14699, 1.14701], [2.02566, 2.02563]] ([layer1,layer2])
#
# Number of pairs in event 998 = 7
# Pairs at theta values of: [[1.35243, 1.35244], [1.80545, 1.80546], [1.80545, 1.80546], [1.80543, 1.80546], [1.80542, 1.80546], [1.80539, 1.80546], [1.80536, 1.80546]] ([layer1,layer2])
#
# Number of pairs in event 999 = 2
# Pairs at theta values of: [[1.77165, 1.77162], [1.44729, 1.44727]] ([layer1,layer2])

# %% [markdown]
# # Part 3
#
# ##### Note: technically, the code below also answers part 2, however it is almost unreadable so I replaced it with a cleaner version above. The only difference between this code here vs the one in the cell above is that rather than looping over the values themselves (in the loops j & k), I am looping over the indices of the values. This makes it look messier but is necessary to obtain both the $\theta$ and $\phi$ values.

# %%
no_of_pairs = [] # Initialise array
pair_theta_values = [] # Makes a list of the theta pair values
pair_phi_values = [] # Makes a list of the phi pair values


# Again, looping over the number of events
for i in range(1000):
    count = 0
    pair_t = []
    pair_p = []
    for j in range(len(np.array(tracker1Data.Theta[tracker1Data.EventID == i]))): # Loop over index of theta in layer 1 corresponding to event i
        for k in range(len(np.array(tracker2Data.Theta[tracker2Data.EventID == i]))): # Loop over index of theta in layer 2 corresponding to event i
            if math.fabs(np.array(tracker1Data.Theta[tracker1Data.EventID == i])[j]-np.array(tracker2Data.Theta[tracker2Data.EventID == i])[k]) < 0.0001: 
                count += 1 # Increase the count by 1 if a pair is found with theta close to each other
                pair_t.append([np.array(tracker1Data.Theta[tracker1Data.EventID == i])[j],np.array(tracker2Data.Theta[tracker2Data.EventID == i])[k]]) # adds the pair values to the temporary list
                pair_p.append([np.array(tracker1Data.Phi[tracker1Data.EventID == i])[j],np.array(tracker2Data.Phi[tracker2Data.EventID == i])[k]])
    no_of_pairs.append(count) # Append the value to the list after looping over all layers
    pair_theta_values.append(pair_t) # adds the theta pairs of event i to the main list of all events
    pair_phi_values.append(pair_p) # adds the phi pairs of event i to the main list of all events

for n in range(1000):
    print("Number of pairs in event {:} = {:}".format(n,no_of_pairs[n]))
    print("Pairs at theta values of: {:} ([layer1,layer2])".format(pair_values[n]))
    print("")
    
# This code gives the same result as above so we know it works
# Out:
# Number of pairs in event 0 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 1 = 7
# Pairs at theta values of: [[0.928358, 0.928325], [2.21322, 2.21325], [2.21322, 2.21325], [2.21322, 2.21325], [2.21322, 2.21325], [2.21322, 2.21323], [2.21322, 2.21323]] ([layer1,layer2])
#
# Number of pairs in event 2 = 2
# Pairs at theta values of: [[2.21225, 2.21226], [0.92934, 0.929301]] ([layer1,layer2])
#
# Number of pairs in event 3 = 6
# Pairs at theta values of: [[2.18244, 2.18247], [0.959136, 0.959161], [0.959136, 0.959161], [0.959136, 0.959176], [0.959136, 0.95921], [0.959136, 0.959223]] ([layer1,layer2])
#
# Number of pairs in event 4 = 4
# Pairs at theta values of: [[2.04377, 2.04378], [1.09801, 1.09797], [1.09801, 1.09797], [1.09802, 1.09797]] ([layer1,layer2])
#
# Number of pairs in event 5 = 2
# Pairs at theta values of: [[1.99455, 1.99452], [1.14705, 1.14708]] ([layer1,layer2])
#
# Number of pairs in event 6 = 11
# Pairs at theta values of: [[1.62832, 1.62832], [1.62832, 1.62832], [1.62829, 1.62832], [1.62825, 1.62832], [1.51316, 1.51317], [1.51316, 1.51317], [1.51316, 1.51317], [1.51316, 1.51318], [1.51316, 1.51318], [1.51316, 1.5132], [1.51316, 1.5132]] ([layer1,layer2])
#
# Number of pairs in event 7 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 8 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 9 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 10 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 11 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 12 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 13 = 2
# Pairs at theta values of: [[1.46102, 1.46102], [1.67693, 1.67696]] ([layer1,layer2])
#
# Number of pairs in event 14 = 2
# Pairs at theta values of: [[0.880318, 0.880258], [2.26129, 2.2613]] ([layer1,layer2])
#
# Number of pairs in event 15 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 16 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 17 = 2
# Pairs at theta values of: [[1.29624, 1.2962], [1.84535, 1.84535]] ([layer1,layer2])
#
# Number of pairs in event 18 = 2
# Pairs at theta values of: [[2.29918, 2.29918], [0.842397, 0.842397]] ([layer1,layer2])
#
# Number of pairs in event 19 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 20 = 2
# Pairs at theta values of: [[1.82123, 1.82122], [1.3203, 1.32029]] ([layer1,layer2])
#
# Number of pairs in event 21 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 22 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 23 = 2
# Pairs at theta values of: [[1.41723, 1.41724], [1.72438, 1.72437]] ([layer1,layer2])
#
# Number of pairs in event 24 = 2
# Pairs at theta values of: [[1.34842, 1.34843], [1.7932, 1.79323]] ([layer1,layer2])
#
# Number of pairs in event 25 = 1
# Pairs at theta values of: [[0.933507, 0.933481]] ([layer1,layer2])
#
# Number of pairs in event 26 = 1
# Pairs at theta values of: [[0.821905, 0.821867]] ([layer1,layer2])
#
# Number of pairs in event 27 = 2
# Pairs at theta values of: [[1.88406, 1.8841], [1.25746, 1.25748]] ([layer1,layer2])
#
# Number of pairs in event 28 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 29 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 30 = 2
# Pairs at theta values of: [[1.74287, 1.74286], [1.39866, 1.39865]] ([layer1,layer2])
#
# Number of pairs in event 31 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 32 = 8
# Pairs at theta values of: [[1.89501, 1.89501], [1.24658, 1.24655], [1.24658, 1.24655], [1.24658, 1.24653], [1.24658, 1.24654], [1.24658, 1.24654], [1.24658, 1.24652], [1.24658, 1.24651]] ([layer1,layer2])
#
# Number of pairs in event 33 = 6
# Pairs at theta values of: [[1.07289, 1.07283], [1.07289, 1.07283], [1.07287, 1.07283], [1.07281, 1.07283], [1.0728, 1.07283], [2.05921, 2.05922]] ([layer1,layer2])
#
# Number of pairs in event 34 = 7
# Pairs at theta values of: [[1.78977, 1.78977], [1.78977, 1.78977], [1.78977, 1.78979], [1.78977, 1.78981], [1.78977, 1.78983], [1.78977, 1.7898], [1.35182, 1.35187]] ([layer1,layer2])
#
# Number of pairs in event 35 = 2
# Pairs at theta values of: [[1.9951, 1.99509], [1.14641, 1.14633]] ([layer1,layer2])
#
# Number of pairs in event 36 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 37 = 5
# Pairs at theta values of: [[0.866786, 0.86679], [2.27488, 2.2749], [2.27488, 2.2749], [2.27488, 2.27488], [2.27488, 2.27487]] ([layer1,layer2])
#
# Number of pairs in event 38 = 2
# Pairs at theta values of: [[1.67486, 1.67482], [1.46673, 1.46674]] ([layer1,layer2])
#
# Number of pairs in event 39 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 40 = 2
# Pairs at theta values of: [[1.25717, 1.25715], [1.88218, 1.88223]] ([layer1,layer2])
#
# Number of pairs in event 41 = 2
# Pairs at theta values of: [[1.79841, 1.79844], [1.34319, 1.34318]] ([layer1,layer2])
#
# Number of pairs in event 42 = 2
# Pairs at theta values of: [[1.37178, 1.37176], [1.76979, 1.7698]] ([layer1,layer2])
#
# Number of pairs in event 43 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 44 = 2
# Pairs at theta values of: [[1.25386, 1.25386], [1.88772, 1.88771]] ([layer1,layer2])
#
# Number of pairs in event 45 = 2
# Pairs at theta values of: [[1.99873, 1.99879], [1.14287, 1.14285]] ([layer1,layer2])
#
# Number of pairs in event 46 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 47 = 2
# Pairs at theta values of: [[1.99667, 1.99672], [1.14525, 1.14522]] ([layer1,layer2])
#
# Number of pairs in event 48 = 8
# Pairs at theta values of: [[1.10588, 1.10583], [2.03568, 2.03573], [2.03568, 2.03573], [2.03568, 2.0357], [2.03568, 2.03569], [2.03568, 2.03571], [2.03568, 2.03572], [2.03568, 2.03573]] ([layer1,layer2])
#
# Number of pairs in event 49 = 10
# Pairs at theta values of: [[1.69258, 1.69253], [1.44964, 1.44964], [1.44964, 1.44964], [1.44965, 1.44964], [1.44966, 1.44964], [1.44967, 1.44964], [1.44969, 1.44964], [1.44967, 1.44964], [1.44968, 1.44964], [1.44968, 1.44964]] ([layer1,layer2])
#
# Number of pairs in event 50 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 51 = 2
# Pairs at theta values of: [[0.996138, 0.996151], [2.14546, 2.14542]] ([layer1,layer2])
#
# Number of pairs in event 52 = 13
# Pairs at theta values of: [[2.19224, 2.19223], [2.19224, 2.19223], [2.19224, 2.19223], [2.19224, 2.19223], [2.19224, 2.19221], [2.19224, 2.19219], [2.19224, 2.19218], [2.19224, 2.19217], [2.19224, 2.19217], [2.19224, 2.19215], [2.19224, 2.19215], [2.19224, 2.19214], [0.949346, 0.949353]] ([layer1,layer2])
#
# Number of pairs in event 53 = 2
# Pairs at theta values of: [[1.48482, 1.48481], [1.65676, 1.65678]] ([layer1,layer2])
#
# Number of pairs in event 54 = 2
# Pairs at theta values of: [[2.15319, 2.15317], [0.988379, 0.988385]] ([layer1,layer2])
#
# Number of pairs in event 55 = 2
# Pairs at theta values of: [[1.0442, 1.04422], [2.09738, 2.09738]] ([layer1,layer2])
#
# Number of pairs in event 56 = 2
# Pairs at theta values of: [[1.80563, 1.80565], [1.33597, 1.33595]] ([layer1,layer2])
#
# Number of pairs in event 57 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 58 = 2
# Pairs at theta values of: [[2.0587, 2.05873], [1.08295, 1.08293]] ([layer1,layer2])
#
# Number of pairs in event 59 = 6
# Pairs at theta values of: [[2.14539, 2.14539], [2.14539, 2.14539], [2.14539, 2.14539], [2.14535, 2.14539], [2.14534, 2.14539], [0.996194, 0.996178]] ([layer1,layer2])
#
# Number of pairs in event 60 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 61 = 2
# Pairs at theta values of: [[1.89117, 1.89123], [1.25039, 1.25039]] ([layer1,layer2])
#
# Number of pairs in event 62 = 2
# Pairs at theta values of: [[1.29033, 1.29034], [1.85128, 1.85129]] ([layer1,layer2])
#
# Number of pairs in event 63 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 64 = 5
# Pairs at theta values of: [[1.45661, 1.45665], [1.45661, 1.45665], [1.45661, 1.45667], [1.45661, 1.45669], [2.099, 2.0991]] ([layer1,layer2])
#
# Number of pairs in event 65 = 2
# Pairs at theta values of: [[1.57341, 1.57339], [1.56819, 1.56821]] ([layer1,layer2])
#
# Number of pairs in event 66 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 67 = 2
# Pairs at theta values of: [[1.3562, 1.35617], [1.78539, 1.78535]] ([layer1,layer2])
#
# Number of pairs in event 68 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 69 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 70 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 71 = 2
# Pairs at theta values of: [[2.01586, 2.01587], [1.12574, 1.12568]] ([layer1,layer2])
#
# Number of pairs in event 72 = 8
# Pairs at theta values of: [[1.33073, 1.33069], [1.33073, 1.33069], [1.33073, 1.33068], [1.33073, 1.33066], [1.33073, 1.33065], [1.33073, 1.33066], [1.33073, 1.33067], [1.81086, 1.81085]] ([layer1,layer2])
#
# Number of pairs in event 73 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 74 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 75 = 2
# Pairs at theta values of: [[1.0201, 1.02009], [2.13931, 2.13934]] ([layer1,layer2])
#
# Number of pairs in event 76 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 77 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 78 = 2
# Pairs at theta values of: [[2.33395, 2.33386], [0.797877, 0.797887]] ([layer1,layer2])
#
# Number of pairs in event 79 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 80 = 2
# Pairs at theta values of: [[1.98948, 1.9895], [1.15209, 1.15205]] ([layer1,layer2])
#
# Number of pairs in event 81 = 2
# Pairs at theta values of: [[1.55043, 1.55041], [1.59121, 1.59127]] ([layer1,layer2])
#
# Number of pairs in event 82 = 11
# Pairs at theta values of: [[2.31794, 2.31795], [2.31794, 2.31795], [2.31794, 2.31793], [2.31794, 2.31791], [2.31794, 2.3179], [2.31794, 2.3179], [2.31794, 2.3179], [2.31794, 2.3179], [2.31794, 2.3179], [2.31794, 2.3179], [0.824327, 0.824299]] ([layer1,layer2])
#
# Number of pairs in event 83 = 40
# Pairs at theta values of: [[1.45356, 1.45352], [1.45356, 1.45352], [1.45356, 1.45351], [1.45356, 1.45349], [1.45356, 1.45347], [1.45356, 1.45352], [1.45356, 1.45352], [1.45356, 1.45351], [1.45356, 1.45349], [1.45356, 1.45347], [1.45357, 1.45352], [1.45357, 1.45352], [1.45357, 1.45351], [1.45357, 1.45349], [1.45357, 1.45347], [1.45354, 1.45352], [1.45354, 1.45352], [1.45354, 1.45351], [1.45354, 1.45349], [1.45354, 1.45347], [1.45354, 1.45345], [1.45353, 1.45352], [1.45353, 1.45352], [1.45353, 1.45351], [1.45353, 1.45349], [1.45353, 1.45347], [1.45353, 1.45345], [1.45353, 1.45352], [1.45353, 1.45352], [1.45353, 1.45351], [1.45353, 1.45349], [1.45353, 1.45347], [1.45353, 1.45345], [1.45354, 1.45352], [1.45354, 1.45352], [1.45354, 1.45351], [1.45354, 1.45349], [1.45354, 1.45347], [1.45354, 1.45345], [1.68802, 1.68804]] ([layer1,layer2])
#
# Number of pairs in event 84 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 85 = 2
# Pairs at theta values of: [[1.6585, 1.65851], [1.48308, 1.48304]] ([layer1,layer2])
#
# Number of pairs in event 86 = 9
# Pairs at theta values of: [[1.18114, 1.18113], [1.96047, 1.96051], [1.96047, 1.96051], [1.96047, 1.9605], [1.96047, 1.96046], [1.96047, 1.96044], [1.96047, 1.96042], [1.96047, 1.96041], [1.96047, 1.9604]] ([layer1,layer2])
#
# Number of pairs in event 87 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 88 = 2
# Pairs at theta values of: [[1.7785, 1.77851], [1.36212, 1.3621]] ([layer1,layer2])
#
# Number of pairs in event 89 = 2
# Pairs at theta values of: [[2.05739, 2.05742], [1.08418, 1.08418]] ([layer1,layer2])
#
# Number of pairs in event 90 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 91 = 2
# Pairs at theta values of: [[1.99763, 1.99764], [1.14395, 1.14393]] ([layer1,layer2])
#
# Number of pairs in event 92 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 93 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 94 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 95 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 96 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 97 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 98 = 4
# Pairs at theta values of: [[1.97304, 1.97308], [1.97304, 1.97308], [1.97304, 1.97304], [1.16857, 1.16859]] ([layer1,layer2])
#
# Number of pairs in event 99 = 2
# Pairs at theta values of: [[2.27288, 2.27291], [0.873416, 0.87338]] ([layer1,layer2])
#
# Number of pairs in event 100 = 7
# Pairs at theta values of: [[1.30198, 1.30198], [1.8396, 1.83956], [1.8396, 1.83956], [1.8396, 1.83957], [1.8396, 1.83953], [1.8396, 1.83953], [1.8396, 1.83952]] ([layer1,layer2])
#
# Number of pairs in event 101 = 2
# Pairs at theta values of: [[1.1451, 1.14508], [1.99656, 1.99657]] ([layer1,layer2])
#
# Number of pairs in event 102 = 2
# Pairs at theta values of: [[2.26565, 2.26564], [0.899959, 0.899942]] ([layer1,layer2])
#
# Number of pairs in event 103 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 104 = 2
# Pairs at theta values of: [[1.05723, 1.0572], [2.0844, 2.08444]] ([layer1,layer2])
#
# Number of pairs in event 105 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 106 = 2
# Pairs at theta values of: [[1.75859, 1.75858], [1.38305, 1.38303]] ([layer1,layer2])
#
# Number of pairs in event 107 = 2
# Pairs at theta values of: [[2.3193, 2.31939], [0.822443, 0.822463]] ([layer1,layer2])
#
# Number of pairs in event 108 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 109 = 2
# Pairs at theta values of: [[1.23896, 1.23897], [1.90264, 1.90269]] ([layer1,layer2])
#
# Number of pairs in event 110 = 2
# Pairs at theta values of: [[2.31355, 2.31355], [0.828044, 0.828037]] ([layer1,layer2])
#
# Number of pairs in event 111 = 6
# Pairs at theta values of: [[0.915912, 0.915881], [2.22569, 2.2257], [2.22569, 2.2257], [2.22569, 2.22569], [2.22569, 2.22568], [2.22569, 2.22568]] ([layer1,layer2])
#
# Number of pairs in event 112 = 2
# Pairs at theta values of: [[1.68057, 1.68055], [1.46103, 1.46103]] ([layer1,layer2])
#
# Number of pairs in event 113 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 114 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 115 = 2
# Pairs at theta values of: [[0.947063, 0.947074], [2.20218, 2.20223]] ([layer1,layer2])
#
# Number of pairs in event 116 = 2
# Pairs at theta values of: [[0.8235, 0.823494], [2.31807, 2.31808]] ([layer1,layer2])
#
# Number of pairs in event 117 = 12
# Pairs at theta values of: [[1.17738, 1.17731], [1.96702, 1.96702], [1.96702, 1.96702], [1.96702, 1.96702], [1.96702, 1.96701], [1.96702, 1.96701], [1.96702, 1.96701], [1.96702, 1.96701], [1.96702, 1.967], [1.96702, 1.967], [1.96702, 1.96699], [1.96702, 1.96699]] ([layer1,layer2])
#
# Number of pairs in event 118 = 2
# Pairs at theta values of: [[0.80318, 0.803188], [2.33845, 2.33842]] ([layer1,layer2])
#
# Number of pairs in event 119 = 2
# Pairs at theta values of: [[1.01495, 1.01494], [2.12665, 2.12666]] ([layer1,layer2])
#
# Number of pairs in event 120 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 121 = 17
# Pairs at theta values of: [[1.32309, 1.32309], [1.32309, 1.32309], [1.32309, 1.32309], [1.32309, 1.32309], [1.32308, 1.32309], [1.32307, 1.32309], [1.32306, 1.32309], [1.32305, 1.32309], [1.32305, 1.32309], [1.32304, 1.32309], [1.32304, 1.32309], [1.32304, 1.32309], [1.32304, 1.32309], [1.32303, 1.32309], [1.32303, 1.32309], [1.32302, 1.32309], [1.81852, 1.81852]] ([layer1,layer2])
#
# Number of pairs in event 122 = 6
# Pairs at theta values of: [[1.58535, 1.58537], [1.55627, 1.55625], [1.55627, 1.55625], [1.55627, 1.55627], [1.55627, 1.55629], [1.55627, 1.55631]] ([layer1,layer2])
#
# Number of pairs in event 123 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 124 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 125 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 126 = 5
# Pairs at theta values of: [[1.11098, 1.11102], [2.03093, 2.03093], [2.03093, 2.03093], [2.03099, 2.03093], [2.031, 2.03093]] ([layer1,layer2])
#
# Number of pairs in event 127 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 128 = 13
# Pairs at theta values of: [[1.08965, 1.08959], [2.04897, 2.049], [2.04897, 2.049], [2.04897, 2.049], [2.04897, 2.049], [2.04899, 2.049], [2.04899, 2.049], [2.04899, 2.049], [2.04898, 2.049], [2.04896, 2.049], [2.04894, 2.049], [2.04893, 2.049], [2.04891, 2.049]] ([layer1,layer2])
#
# Number of pairs in event 129 = 2
# Pairs at theta values of: [[1.46804, 1.46807], [1.67348, 1.67344]] ([layer1,layer2])
#
# Number of pairs in event 130 = 2
# Pairs at theta values of: [[2.19893, 2.19892], [0.950562, 0.95056]] ([layer1,layer2])
#
# Number of pairs in event 131 = 2
# Pairs at theta values of: [[0.836413, 0.836362], [2.3051, 2.3051]] ([layer1,layer2])
#
# Number of pairs in event 132 = 2
# Pairs at theta values of: [[2.16946, 2.16945], [1.15262, 1.15257]] ([layer1,layer2])
#
# Number of pairs in event 133 = 2
# Pairs at theta values of: [[1.92246, 1.92246], [1.21915, 1.21917]] ([layer1,layer2])
#
# Number of pairs in event 134 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 135 = 12
# Pairs at theta values of: [[1.68047, 1.68046], [1.46113, 1.46112], [1.46113, 1.46112], [1.46111, 1.46112], [1.4611, 1.46112], [1.46108, 1.46112], [1.46107, 1.46112], [1.46106, 1.46112], [1.46105, 1.46112], [1.46105, 1.46112], [1.46103, 1.46112], [1.46102, 1.46112]] ([layer1,layer2])
#
# Number of pairs in event 136 = 10
# Pairs at theta values of: [[1.75514, 1.75517], [1.3865, 1.38648], [1.3865, 1.38648], [1.3865, 1.38646], [1.3865, 1.38643], [1.3865, 1.38642], [1.3865, 1.38641], [1.3865, 1.38641], [1.3865, 1.38641], [1.3865, 1.38641]] ([layer1,layer2])
#
# Number of pairs in event 137 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 138 = 2
# Pairs at theta values of: [[0.799853, 0.799862], [2.34172, 2.34177]] ([layer1,layer2])
#
# Number of pairs in event 139 = 2
# Pairs at theta values of: [[1.51617, 1.51617], [1.62541, 1.62542]] ([layer1,layer2])
#
# Number of pairs in event 140 = 5
# Pairs at theta values of: [[0.965833, 0.96583], [2.17572, 2.17579], [2.17572, 2.17579], [2.17572, 2.17579], [2.17572, 2.17578]] ([layer1,layer2])
#
# Number of pairs in event 141 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 142 = 2
# Pairs at theta values of: [[1.89815, 1.89814], [1.24346, 1.24347]] ([layer1,layer2])
#
# Number of pairs in event 143 = 2
# Pairs at theta values of: [[1.39209, 1.39211], [1.74912, 1.74912]] ([layer1,layer2])
#
# Number of pairs in event 144 = 2
# Pairs at theta values of: [[2.13905, 2.13905], [1.34314, 1.34304]] ([layer1,layer2])
#
# Number of pairs in event 145 = 2
# Pairs at theta values of: [[0.87883, 0.878816], [2.26276, 2.26279]] ([layer1,layer2])
#
# Number of pairs in event 146 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 147 = 15
# Pairs at theta values of: [[1.06405, 1.06401], [2.07771, 2.07778], [2.07771, 2.07778], [2.07771, 2.07778], [2.07771, 2.07778], [2.07771, 2.07778], [2.07771, 2.07778], [2.07771, 2.07778], [2.07771, 2.07778], [2.07771, 2.07778], [2.07771, 2.07778], [2.07771, 2.07778], [2.07771, 2.07778], [2.07771, 2.07778], [2.07771, 2.07778]] ([layer1,layer2])
#
# Number of pairs in event 148 = 10
# Pairs at theta values of: [[1.70571, 1.70573], [1.43585, 1.43585], [1.43585, 1.43585], [1.43585, 1.43585], [1.43585, 1.43583], [1.43585, 1.43584], [1.43585, 1.43586], [1.43585, 1.43587], [1.43585, 1.43588], [1.43585, 1.43589]] ([layer1,layer2])
#
# Number of pairs in event 149 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 150 = 2
# Pairs at theta values of: [[1.7715, 1.77151], [1.3702, 1.37019]] ([layer1,layer2])
#
# Number of pairs in event 151 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 152 = 2
# Pairs at theta values of: [[0.838136, 0.838132], [2.30343, 2.30345]] ([layer1,layer2])
#
# Number of pairs in event 153 = 2
# Pairs at theta values of: [[2.03401, 2.03401], [1.10755, 1.10749]] ([layer1,layer2])
#
# Number of pairs in event 154 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 155 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 156 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 157 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 158 = 1
# Pairs at theta values of: [[1.65869, 1.65868]] ([layer1,layer2])
#
# Number of pairs in event 159 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 160 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 161 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 162 = 2
# Pairs at theta values of: [[1.26146, 1.26145], [1.88012, 1.88009]] ([layer1,layer2])
#
# Number of pairs in event 163 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 164 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 165 = 6
# Pairs at theta values of: [[1.39514, 1.39516], [1.74703, 1.74701], [1.74703, 1.74701], [1.74703, 1.74699], [1.74703, 1.74703], [1.74703, 1.74704]] ([layer1,layer2])
#
# Number of pairs in event 166 = 2
# Pairs at theta values of: [[1.05527, 1.05523], [2.08648, 2.08649]] ([layer1,layer2])
#
# Number of pairs in event 167 = 2
# Pairs at theta values of: [[0.930992, 0.930918], [2.21025, 2.21028]] ([layer1,layer2])
#
# Number of pairs in event 168 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 169 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 170 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 171 = 2
# Pairs at theta values of: [[2.1082, 2.10823], [1.03347, 1.03345]] ([layer1,layer2])
#
# Number of pairs in event 172 = 9
# Pairs at theta values of: [[1.3149, 1.3149], [1.82668, 1.82673], [1.82668, 1.82673], [1.82668, 1.82675], [1.82668, 1.82675], [1.82668, 1.82676], [1.82668, 1.82676], [1.82668, 1.82676], [1.82668, 1.82676]] ([layer1,layer2])
#
# Number of pairs in event 173 = 5
# Pairs at theta values of: [[1.71834, 1.71834], [1.71834, 1.71834], [1.42326, 1.42326], [1.42326, 1.42326], [1.42326, 1.4233]] ([layer1,layer2])
#
# Number of pairs in event 174 = 2
# Pairs at theta values of: [[2.31015, 2.31013], [0.830325, 0.830287]] ([layer1,layer2])
#
# Number of pairs in event 175 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 176 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 177 = 2
# Pairs at theta values of: [[2.31798, 2.31801], [0.823637, 0.823584]] ([layer1,layer2])
#
# Number of pairs in event 178 = 1
# Pairs at theta values of: [[0.82544, 0.825444]] ([layer1,layer2])
#
# Number of pairs in event 179 = 2
# Pairs at theta values of: [[1.05478, 1.0548], [2.08681, 2.08683]] ([layer1,layer2])
#
# Number of pairs in event 180 = 2
# Pairs at theta values of: [[0.878883, 0.878841], [2.26271, 2.26275]] ([layer1,layer2])
#
# Number of pairs in event 181 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 182 = 2
# Pairs at theta values of: [[1.37024, 1.37023], [1.77109, 1.77109]] ([layer1,layer2])
#
# Number of pairs in event 183 = 9
# Pairs at theta values of: [[2.33772, 2.33774], [0.803893, 0.803856], [0.803893, 0.803856], [0.803882, 0.803856], [0.803862, 0.803856], [0.803858, 0.803856], [0.803873, 0.803856], [0.80388, 0.803856], [0.803883, 0.803856]] ([layer1,layer2])
#
# Number of pairs in event 184 = 1
# Pairs at theta values of: [[1.51457, 1.51449]] ([layer1,layer2])
#
# Number of pairs in event 185 = 2
# Pairs at theta values of: [[2.18018, 2.18019], [0.961529, 0.961555]] ([layer1,layer2])
#
# Number of pairs in event 186 = 2
# Pairs at theta values of: [[1.98682, 1.98677], [1.1542, 1.15421]] ([layer1,layer2])
#
# Number of pairs in event 187 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 188 = 2
# Pairs at theta values of: [[1.35249, 1.35251], [1.78914, 1.78914]] ([layer1,layer2])
#
# Number of pairs in event 189 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 190 = 4
# Pairs at theta values of: [[1.59805, 1.59806], [1.54065, 1.54065], [1.54065, 1.54065], [1.54073, 1.54065]] ([layer1,layer2])
#
# Number of pairs in event 191 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 192 = 2
# Pairs at theta values of: [[1.26233, 1.26227], [1.87926, 1.87924]] ([layer1,layer2])
#
# Number of pairs in event 193 = 12
# Pairs at theta values of: [[1.92823, 1.92822], [1.92823, 1.92822], [1.92821, 1.92822], [1.9282, 1.92822], [1.92822, 1.92822], [1.92826, 1.92822], [1.92831, 1.92822], [1.9282, 1.92822], [1.92822, 1.92822], [1.92821, 1.92822], [1.9282, 1.92822], [1.2137, 1.21365]] ([layer1,layer2])
#
# Number of pairs in event 194 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 195 = 4
# Pairs at theta values of: [[1.86085, 1.8609], [1.86085, 1.8609], [1.86084, 1.8609], [1.28077, 1.28075]] ([layer1,layer2])
#
# Number of pairs in event 196 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 197 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 198 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 199 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 200 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 201 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 202 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 203 = 2
# Pairs at theta values of: [[2.21449, 2.2145], [0.927073, 0.927067]] ([layer1,layer2])
#
# Number of pairs in event 204 = 2
# Pairs at theta values of: [[1.18244, 1.18248], [1.95915, 1.95916]] ([layer1,layer2])
#
# Number of pairs in event 205 = 2
# Pairs at theta values of: [[1.1056, 1.10558], [2.03599, 2.03605]] ([layer1,layer2])
#
# Number of pairs in event 206 = 2
# Pairs at theta values of: [[1.4337, 1.43373], [1.70792, 1.70794]] ([layer1,layer2])
#
# Number of pairs in event 207 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 208 = 2
# Pairs at theta values of: [[0.986828, 0.986803], [2.15477, 2.15479]] ([layer1,layer2])
#
# Number of pairs in event 209 = 2
# Pairs at theta values of: [[1.01734, 1.01731], [2.12427, 2.12434]] ([layer1,layer2])
#
# Number of pairs in event 210 = 8
# Pairs at theta values of: [[2.28372, 2.28372], [2.28372, 2.28372], [2.28369, 2.28372], [2.28371, 2.28372], [2.28371, 2.28372], [2.28371, 2.28372], [2.28372, 2.28372], [0.858311, 0.858339]] ([layer1,layer2])
#
# Number of pairs in event 211 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 212 = 2
# Pairs at theta values of: [[0.808062, 0.808039], [2.33354, 2.33354]] ([layer1,layer2])
#
# Number of pairs in event 213 = 6
# Pairs at theta values of: [[1.07164, 1.07163], [1.07164, 1.07163], [1.07161, 1.07163], [1.07158, 1.07163], [1.07153, 1.07163], [2.07, 2.06999]] ([layer1,layer2])
#
# Number of pairs in event 214 = 2
# Pairs at theta values of: [[1.62591, 1.62595], [1.50819, 1.50821]] ([layer1,layer2])
#
# Number of pairs in event 215 = 2
# Pairs at theta values of: [[0.998224, 0.998192], [2.14335, 2.14336]] ([layer1,layer2])
#
# Number of pairs in event 216 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 217 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 218 = 2
# Pairs at theta values of: [[1.68863, 1.68866], [1.45292, 1.45293]] ([layer1,layer2])
#
# Number of pairs in event 219 = 2
# Pairs at theta values of: [[1.74746, 1.74742], [1.4009, 1.40091]] ([layer1,layer2])
#
# Number of pairs in event 220 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 221 = 5
# Pairs at theta values of: [[2.30904, 2.30905], [2.30904, 2.30905], [2.30908, 2.30905], [2.30914, 2.30905], [0.832548, 0.832515]] ([layer1,layer2])
#
# Number of pairs in event 222 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 223 = 2
# Pairs at theta values of: [[1.83598, 1.83598], [1.30563, 1.30562]] ([layer1,layer2])
#
# Number of pairs in event 224 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 225 = 2
# Pairs at theta values of: [[1.06121, 1.06121], [2.08038, 2.08039]] ([layer1,layer2])
#
# Number of pairs in event 226 = 2
# Pairs at theta values of: [[2.30849, 2.30851], [0.83339, 0.833386]] ([layer1,layer2])
#
# Number of pairs in event 227 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 228 = 2
# Pairs at theta values of: [[1.73533, 1.73532], [1.38742, 1.38741]] ([layer1,layer2])
#
# Number of pairs in event 229 = 2
# Pairs at theta values of: [[1.84828, 1.84828], [1.29333, 1.29336]] ([layer1,layer2])
#
# Number of pairs in event 230 = 8
# Pairs at theta values of: [[1.23745, 1.23745], [1.23745, 1.23745], [1.23745, 1.23745], [1.23745, 1.23743], [1.23745, 1.23742], [1.23745, 1.23741], [1.23745, 1.2374], [1.90414, 1.90409]] ([layer1,layer2])
#
# Number of pairs in event 231 = 2
# Pairs at theta values of: [[1.66354, 1.66352], [1.47809, 1.47808]] ([layer1,layer2])
#
# Number of pairs in event 232 = 2
# Pairs at theta values of: [[2.31133, 2.31135], [0.830225, 0.830196]] ([layer1,layer2])
#
# Number of pairs in event 233 = 2
# Pairs at theta values of: [[1.58813, 1.58813], [1.55347, 1.55349]] ([layer1,layer2])
#
# Number of pairs in event 234 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 235 = 6
# Pairs at theta values of: [[1.04225, 1.04224], [1.04225, 1.04224], [1.04225, 1.04224], [1.04225, 1.04228], [1.04225, 1.04228], [2.09935, 2.09937]] ([layer1,layer2])
#
# Number of pairs in event 236 = 2
# Pairs at theta values of: [[2.17192, 2.17194], [0.969651, 0.96965]] ([layer1,layer2])
#
# Number of pairs in event 237 = 2
# Pairs at theta values of: [[1.79966, 1.79967], [1.34197, 1.34195]] ([layer1,layer2])
#
# Number of pairs in event 238 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 239 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 240 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 241 = 2
# Pairs at theta values of: [[1.42547, 1.42547], [1.71611, 1.71608]] ([layer1,layer2])
#
# Number of pairs in event 242 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 243 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 244 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 245 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 246 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 247 = 2
# Pairs at theta values of: [[2.29806, 2.29808], [0.850144, 0.850063]] ([layer1,layer2])
#
# Number of pairs in event 248 = 2
# Pairs at theta values of: [[1.35976, 1.35976], [1.78183, 1.7818]] ([layer1,layer2])
#
# Number of pairs in event 249 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 250 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 251 = 2
# Pairs at theta values of: [[1.60291, 1.60288], [1.53872, 1.53874]] ([layer1,layer2])
#
# Number of pairs in event 252 = 2
# Pairs at theta values of: [[1.05249, 1.05246], [2.0887, 2.08876]] ([layer1,layer2])
#
# Number of pairs in event 253 = 26
# Pairs at theta values of: [[1.08066, 1.0806], [1.08066, 1.0806], [1.08066, 1.08064], [1.08066, 1.08066], [1.08066, 1.08064], [1.08066, 1.08062], [1.08066, 1.08059], [1.08066, 1.08056], [1.08066, 1.0806], [1.08066, 1.0806], [1.08066, 1.08064], [1.08066, 1.08066], [1.08066, 1.08064], [1.08066, 1.08062], [1.08066, 1.08059], [1.08066, 1.08056], [1.08075, 1.08066], [2.0609, 2.06093], [2.0609, 2.06093], [2.0609, 2.06093], [2.0609, 2.06093], [2.0609, 2.06094], [2.0609, 2.06094], [2.0609, 2.06094], [2.0609, 2.06095], [2.0609, 2.06095]] ([layer1,layer2])
#
# Number of pairs in event 254 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 255 = 7
# Pairs at theta values of: [[1.99619, 1.99621], [1.14539, 1.14539], [1.14539, 1.14539], [1.1454, 1.14539], [1.14546, 1.14539], [1.14546, 1.14539], [1.14545, 1.14539]] ([layer1,layer2])
#
# Number of pairs in event 256 = 1
# Pairs at theta values of: [[1.77987, 1.77988]] ([layer1,layer2])
#
# Number of pairs in event 257 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 258 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 259 = 25
# Pairs at theta values of: [[0.78949, 0.789482], [2.35212, 2.35215], [2.35212, 2.35215], [2.35212, 2.35211], [2.35212, 2.35209], [2.35212, 2.35209], [2.35212, 2.35203], [2.35212, 2.35203], [2.35212, 2.35204], [2.35212, 2.35205], [2.35212, 2.35205], [2.35212, 2.35206], [2.35212, 2.35206], [2.35212, 2.35205], [2.35212, 2.35205], [2.35212, 2.35203], [2.35212, 2.35204], [2.35212, 2.35205], [2.35212, 2.35206], [2.35212, 2.35207], [2.35212, 2.35208], [2.35212, 2.35209], [2.35212, 2.3521], [2.35212, 2.35211], [2.35212, 2.35211]] ([layer1,layer2])
#
# Number of pairs in event 260 = 24
# Pairs at theta values of: [[1.53297, 1.53298], [1.53297, 1.53298], [1.53297, 1.53299], [1.53297, 1.53298], [1.53297, 1.53298], [1.53297, 1.53297], [1.53297, 1.53294], [1.53297, 1.53292], [1.53297, 1.53298], [1.53297, 1.53298], [1.53297, 1.53299], [1.53297, 1.53298], [1.53297, 1.53298], [1.53297, 1.53297], [1.53297, 1.53294], [1.53297, 1.53292], [1.53305, 1.53298], [1.53305, 1.53298], [1.53305, 1.53299], [1.53305, 1.53298], [1.53305, 1.53298], [1.53305, 1.53297], [1.53309, 1.53299], [1.6017, 1.60168]] ([layer1,layer2])
#
# Number of pairs in event 261 = 2
# Pairs at theta values of: [[1.02825, 1.02822], [2.11336, 2.1134]] ([layer1,layer2])
#
# Number of pairs in event 262 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 263 = 2
# Pairs at theta values of: [[1.60675, 1.60677], [1.53484, 1.53478]] ([layer1,layer2])
#
# Number of pairs in event 264 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 265 = 2
# Pairs at theta values of: [[0.900936, 0.900859], [2.24067, 2.24063]] ([layer1,layer2])
#
# Number of pairs in event 266 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 267 = 2
# Pairs at theta values of: [[1.08034, 1.08036], [2.06126, 2.06135]] ([layer1,layer2])
#
# Number of pairs in event 268 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 269 = 2
# Pairs at theta values of: [[1.42321, 1.42325], [1.71838, 1.7184]] ([layer1,layer2])
#
# Number of pairs in event 270 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 271 = 2
# Pairs at theta values of: [[1.82022, 1.82022], [1.32135, 1.32135]] ([layer1,layer2])
#
# Number of pairs in event 272 = 2
# Pairs at theta values of: [[0.947671, 0.947662], [2.19396, 2.19395]] ([layer1,layer2])
#
# Number of pairs in event 273 = 2
# Pairs at theta values of: [[2.07068, 2.07071], [1.07084, 1.07086]] ([layer1,layer2])
#
# Number of pairs in event 274 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 275 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 276 = 10
# Pairs at theta values of: [[1.01541, 1.0154], [1.01541, 1.0154], [1.01541, 1.0154], [1.01541, 1.01541], [1.01541, 1.01542], [1.01541, 1.0154], [1.01541, 1.01539], [1.01541, 1.01538], [1.01541, 1.01539], [2.12629, 2.12629]] ([layer1,layer2])
#
# Number of pairs in event 277 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 278 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 279 = 2
# Pairs at theta values of: [[1.5521, 1.55211], [1.61639, 1.61636]] ([layer1,layer2])
#
# Number of pairs in event 280 = 2
# Pairs at theta values of: [[1.49992, 1.49996], [1.64166, 1.64167]] ([layer1,layer2])
#
# Number of pairs in event 281 = 5
# Pairs at theta values of: [[0.888338, 0.888321], [2.25328, 2.2533], [2.25328, 2.2533], [2.25328, 2.25327], [2.25328, 2.25326]] ([layer1,layer2])
#
# Number of pairs in event 282 = 2
# Pairs at theta values of: [[1.8634, 1.86341], [1.29124, 1.29128]] ([layer1,layer2])
#
# Number of pairs in event 283 = 2
# Pairs at theta values of: [[2.21348, 2.2135], [0.928162, 0.92815]] ([layer1,layer2])
#
# Number of pairs in event 284 = 4
# Pairs at theta values of: [[1.12937, 1.12936], [1.12937, 1.12936], [1.12936, 1.12936], [2.01221, 2.01224]] ([layer1,layer2])
#
# Number of pairs in event 285 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 286 = 2
# Pairs at theta values of: [[1.23872, 1.23876], [1.90289, 1.90292]] ([layer1,layer2])
#
# Number of pairs in event 287 = 2
# Pairs at theta values of: [[1.19229, 1.19229], [1.94929, 1.94929]] ([layer1,layer2])
#
# Number of pairs in event 288 = 2
# Pairs at theta values of: [[1.81956, 1.81954], [1.32205, 1.32205]] ([layer1,layer2])
#
# Number of pairs in event 289 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 290 = 2
# Pairs at theta values of: [[1.31237, 1.31241], [1.82923, 1.82922]] ([layer1,layer2])
#
# Number of pairs in event 291 = 2
# Pairs at theta values of: [[2.30441, 2.3044], [0.837156, 0.837169]] ([layer1,layer2])
#
# Number of pairs in event 292 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 293 = 2
# Pairs at theta values of: [[1.24998, 1.24998], [1.89116, 1.89117]] ([layer1,layer2])
#
# Number of pairs in event 294 = 2
# Pairs at theta values of: [[0.950325, 0.950318], [2.19124, 2.19126]] ([layer1,layer2])
#
# Number of pairs in event 295 = 2
# Pairs at theta values of: [[0.890995, 0.890972], [2.25061, 2.25059]] ([layer1,layer2])
#
# Number of pairs in event 296 = 7
# Pairs at theta values of: [[1.94988, 1.94993], [1.94988, 1.94993], [1.94988, 1.94991], [1.94988, 1.9499], [1.94988, 1.94989], [1.94988, 1.94989], [1.19169, 1.19169]] ([layer1,layer2])
#
# Number of pairs in event 297 = 2
# Pairs at theta values of: [[2.19466, 2.19467], [0.946907, 0.946883]] ([layer1,layer2])
#
# Number of pairs in event 298 = 7
# Pairs at theta values of: [[1.00315, 1.00311], [1.00315, 1.00311], [1.00318, 1.00311], [2.13842, 2.13845], [2.13842, 2.13845], [2.13838, 2.13845], [2.13838, 2.13845]] ([layer1,layer2])
#
# Number of pairs in event 299 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 300 = 2
# Pairs at theta values of: [[1.5945, 1.59453], [1.5471, 1.54705]] ([layer1,layer2])
#
# Number of pairs in event 301 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 302 = 2
# Pairs at theta values of: [[1.46112, 1.46112], [1.68052, 1.68052]] ([layer1,layer2])
#
# Number of pairs in event 303 = 2
# Pairs at theta values of: [[1.86441, 1.86439], [1.27734, 1.2773]] ([layer1,layer2])
#
# Number of pairs in event 304 = 2
# Pairs at theta values of: [[2.28239, 2.28239], [0.859173, 0.859125]] ([layer1,layer2])
#
# Number of pairs in event 305 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 306 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 307 = 2
# Pairs at theta values of: [[1.75692, 1.75694], [1.38467, 1.38469]] ([layer1,layer2])
#
# Number of pairs in event 308 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 309 = 2
# Pairs at theta values of: [[1.09289, 1.09292], [2.0488, 2.04883]] ([layer1,layer2])
#
# Number of pairs in event 310 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 311 = 2
# Pairs at theta values of: [[0.798183, 0.798148], [2.34365, 2.34366]] ([layer1,layer2])
#
# Number of pairs in event 312 = 2
# Pairs at theta values of: [[1.28969, 1.28967], [1.85186, 1.85187]] ([layer1,layer2])
#
# Number of pairs in event 313 = 1
# Pairs at theta values of: [[2.30269, 2.30271]] ([layer1,layer2])
#
# Number of pairs in event 314 = 2
# Pairs at theta values of: [[0.883104, 0.883118], [2.25851, 2.25854]] ([layer1,layer2])
#
# Number of pairs in event 315 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 316 = 2
# Pairs at theta values of: [[1.24739, 1.2474], [1.89422, 1.89422]] ([layer1,layer2])
#
# Number of pairs in event 317 = 2
# Pairs at theta values of: [[2.19989, 2.19994], [0.962109, 0.962017]] ([layer1,layer2])
#
# Number of pairs in event 318 = 2
# Pairs at theta values of: [[1.34697, 1.34697], [1.79464, 1.79467]] ([layer1,layer2])
#
# Number of pairs in event 319 = 2
# Pairs at theta values of: [[1.94853, 1.94851], [1.19332, 1.1933]] ([layer1,layer2])
#
# Number of pairs in event 320 = 2
# Pairs at theta values of: [[1.27975, 1.27975], [1.86189, 1.86189]] ([layer1,layer2])
#
# Number of pairs in event 321 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 322 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 323 = 2
# Pairs at theta values of: [[1.24781, 1.24777], [1.89379, 1.89381]] ([layer1,layer2])
#
# Number of pairs in event 324 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 325 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 326 = 2
# Pairs at theta values of: [[2.13165, 2.13169], [1.00995, 1.00996]] ([layer1,layer2])
#
# Number of pairs in event 327 = 13
# Pairs at theta values of: [[1.88759, 1.88759], [1.88759, 1.88759], [1.88759, 1.88759], [1.88759, 1.88758], [1.88759, 1.88756], [1.88759, 1.88755], [1.88759, 1.88755], [1.88759, 1.88754], [1.88759, 1.88754], [1.88759, 1.88757], [1.88759, 1.88754], [1.88759, 1.88751], [1.25395, 1.25396]] ([layer1,layer2])
#
# Number of pairs in event 328 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 329 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 330 = 2
# Pairs at theta values of: [[1.98838, 1.9884], [1.15317, 1.15316]] ([layer1,layer2])
#
# Number of pairs in event 331 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 332 = 2
# Pairs at theta values of: [[1.24179, 1.24178], [1.89984, 1.89986]] ([layer1,layer2])
#
# Number of pairs in event 333 = 2
# Pairs at theta values of: [[1.16146, 1.16148], [1.98016, 1.98021]] ([layer1,layer2])
#
# Number of pairs in event 334 = 2
# Pairs at theta values of: [[1.38882, 1.3888], [1.75177, 1.75173]] ([layer1,layer2])
#
# Number of pairs in event 335 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 336 = 2
# Pairs at theta values of: [[1.88965, 1.88965], [1.2521, 1.25208]] ([layer1,layer2])
#
# Number of pairs in event 337 = 2
# Pairs at theta values of: [[1.38965, 1.38964], [1.75189, 1.75187]] ([layer1,layer2])
#
# Number of pairs in event 338 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 339 = 5
# Pairs at theta values of: [[0.940006, 0.939979], [2.20155, 2.20155], [2.20155, 2.20155], [2.20155, 2.20157], [2.20155, 2.20158]] ([layer1,layer2])
#
# Number of pairs in event 340 = 2
# Pairs at theta values of: [[1.21482, 1.21482], [1.92677, 1.92677]] ([layer1,layer2])
#
# Number of pairs in event 341 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 342 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 343 = 4
# Pairs at theta values of: [[1.20639, 1.20638], [1.93522, 1.93522], [1.93522, 1.93522], [1.93521, 1.93522]] ([layer1,layer2])
#
# Number of pairs in event 344 = 7
# Pairs at theta values of: [[2.08125, 2.08128], [2.08125, 2.08128], [2.08125, 2.08129], [2.08125, 2.0813], [1.06032, 1.06031], [1.06032, 1.06031], [1.06032, 1.06032]] ([layer1,layer2])
#
# Number of pairs in event 345 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 346 = 2
# Pairs at theta values of: [[0.886265, 0.88624], [2.25143, 2.25149]] ([layer1,layer2])
#
# Number of pairs in event 347 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 348 = 6
# Pairs at theta values of: [[1.86559, 1.8656], [1.27597, 1.27598], [1.27597, 1.27598], [1.27597, 1.27598], [1.27594, 1.27598], [1.27588, 1.27598]] ([layer1,layer2])
#
# Number of pairs in event 349 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 350 = 2
# Pairs at theta values of: [[1.11859, 1.11857], [2.02298, 2.02298]] ([layer1,layer2])
#
# Number of pairs in event 351 = 2
# Pairs at theta values of: [[1.61045, 1.61046], [1.53111, 1.5311]] ([layer1,layer2])
#
# Number of pairs in event 352 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 353 = 2
# Pairs at theta values of: [[0.803978, 0.803964], [2.33761, 2.33763]] ([layer1,layer2])
#
# Number of pairs in event 354 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 355 = 2
# Pairs at theta values of: [[1.91863, 1.91869], [1.22296, 1.22294]] ([layer1,layer2])
#
# Number of pairs in event 356 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 357 = 6
# Pairs at theta values of: [[2.08345, 2.08345], [2.08345, 2.08345], [2.08345, 2.08347], [2.08345, 2.0835], [2.08345, 2.08354], [2.08345, 2.08354]] ([layer1,layer2])
#
# Number of pairs in event 358 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 359 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 360 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 361 = 2
# Pairs at theta values of: [[2.30996, 2.31], [0.832009, 0.832003]] ([layer1,layer2])
#
# Number of pairs in event 362 = 2
# Pairs at theta values of: [[1.72771, 1.72774], [1.41388, 1.41388]] ([layer1,layer2])
#
# Number of pairs in event 363 = 2
# Pairs at theta values of: [[1.48527, 1.48528], [1.65633, 1.65636]] ([layer1,layer2])
#
# Number of pairs in event 364 = 5
# Pairs at theta values of: [[2.05079, 2.05081], [1.09077, 1.09081], [1.09077, 1.09081], [1.09075, 1.09081], [1.09073, 1.09081]] ([layer1,layer2])
#
# Number of pairs in event 365 = 2
# Pairs at theta values of: [[1.76424, 1.76426], [1.37741, 1.37741]] ([layer1,layer2])
#
# Number of pairs in event 366 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 367 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 368 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 369 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 370 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 371 = 3
# Pairs at theta values of: [[1.30336, 1.30337], [1.30336, 1.30337], [1.30336, 1.30337]] ([layer1,layer2])
#
# Number of pairs in event 372 = 7
# Pairs at theta values of: [[1.99021, 1.99026], [1.15139, 1.15141], [1.15139, 1.15141], [1.15136, 1.15141], [1.15138, 1.15141], [1.15141, 1.15141], [1.15147, 1.15141]] ([layer1,layer2])
#
# Number of pairs in event 373 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 374 = 2
# Pairs at theta values of: [[1.10927, 1.10928], [2.03235, 2.03234]] ([layer1,layer2])
#
# Number of pairs in event 375 = 10
# Pairs at theta values of: [[1.59804, 1.59806], [1.54357, 1.54358], [1.54357, 1.54358], [1.54358, 1.54358], [1.54357, 1.54358], [1.54355, 1.54358], [1.54354, 1.54358], [1.54352, 1.54358], [1.5435, 1.54358], [1.54348, 1.54358]] ([layer1,layer2])
#
# Number of pairs in event 376 = 2
# Pairs at theta values of: [[1.76265, 1.76265], [1.37895, 1.37891]] ([layer1,layer2])
#
# Number of pairs in event 377 = 2
# Pairs at theta values of: [[1.38331, 1.38331], [1.75827, 1.75828]] ([layer1,layer2])
#
# Number of pairs in event 378 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 379 = 2
# Pairs at theta values of: [[2.01367, 2.01374], [1.12793, 1.12792]] ([layer1,layer2])
#
# Number of pairs in event 380 = 2
# Pairs at theta values of: [[1.66822, 1.6682], [1.43066, 1.43066]] ([layer1,layer2])
#
# Number of pairs in event 381 = 2
# Pairs at theta values of: [[0.967659, 0.967589], [2.1739, 2.17391]] ([layer1,layer2])
#
# ...
#
# Number of pairs in event 869 = 2
# Pairs at theta values of: [[0.964874, 0.964877], [2.17674, 2.17678]] ([layer1,layer2])
#
# Number of pairs in event 870 = 2
# Pairs at theta values of: [[1.15707, 1.15707], [1.98474, 1.98476]] ([layer1,layer2])
#
# Number of pairs in event 871 = 8
# Pairs at theta values of: [[2.07621, 2.07619], [1.06536, 1.06531], [1.06536, 1.06531], [1.06537, 1.06531], [1.06535, 1.06531], [1.06532, 1.06531], [1.06529, 1.06531], [1.06528, 1.06531]] ([layer1,layer2])
#
# Number of pairs in event 872 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 873 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 874 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 875 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 876 = 5
# Pairs at theta values of: [[2.03528, 2.0353], [1.10632, 1.10631], [1.10632, 1.10631], [1.10632, 1.10628], [1.10632, 1.10626]] ([layer1,layer2])
#
# Number of pairs in event 877 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 878 = 2
# Pairs at theta values of: [[1.94308, 1.94306], [1.19844, 1.19839]] ([layer1,layer2])
#
# Number of pairs in event 879 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 880 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 881 = 8
# Pairs at theta values of: [[1.18167, 1.18165], [1.9613, 1.96136], [1.9613, 1.96136], [1.9613, 1.96136], [1.9613, 1.96135], [1.9613, 1.96135], [1.9613, 1.96135], [1.9613, 1.96135]] ([layer1,layer2])
#
# Number of pairs in event 882 = 3
# Pairs at theta values of: [[1.81096, 1.81097], [1.33063, 1.33068], [1.33063, 1.33068]] ([layer1,layer2])
#
# Number of pairs in event 883 = 2
# Pairs at theta values of: [[1.78549, 1.7855], [1.36194, 1.36193]] ([layer1,layer2])
#
# Number of pairs in event 884 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 885 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 886 = 5
# Pairs at theta values of: [[1.65633, 1.65632], [1.65633, 1.65632], [1.65638, 1.65632], [1.65642, 1.65632], [1.48454, 1.48452]] ([layer1,layer2])
#
# Number of pairs in event 887 = 6
# Pairs at theta values of: [[1.6685, 1.66851], [1.4729, 1.4729], [1.4729, 1.4729], [1.4729, 1.47289], [1.4729, 1.47289], [1.4729, 1.47288]] ([layer1,layer2])
#
# Number of pairs in event 888 = 2
# Pairs at theta values of: [[1.50208, 1.50209], [1.63952, 1.63949]] ([layer1,layer2])
#
# Number of pairs in event 889 = 2
# Pairs at theta values of: [[1.57133, 1.57138], [1.61255, 1.61258]] ([layer1,layer2])
#
# Number of pairs in event 890 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 891 = 2
# Pairs at theta values of: [[1.73231, 1.73234], [1.4093, 1.40931]] ([layer1,layer2])
#
# Number of pairs in event 892 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 893 = 2
# Pairs at theta values of: [[1.69276, 1.69272], [1.46712, 1.46711]] ([layer1,layer2])
#
# Number of pairs in event 894 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 895 = 2
# Pairs at theta values of: [[0.9572, 0.957186], [2.18435, 2.18438]] ([layer1,layer2])
#
# Number of pairs in event 896 = 2
# Pairs at theta values of: [[0.970872, 0.970849], [2.17072, 2.17073]] ([layer1,layer2])
#
# Number of pairs in event 897 = 2
# Pairs at theta values of: [[1.95121, 1.95124], [1.18967, 1.18965]] ([layer1,layer2])
#
# Number of pairs in event 898 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 899 = 2
# Pairs at theta values of: [[1.33536, 1.33537], [1.80624, 1.80624]] ([layer1,layer2])
#
# Number of pairs in event 900 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 901 = 2
# Pairs at theta values of: [[2.17222, 2.1722], [0.965869, 0.965875]] ([layer1,layer2])
#
# Number of pairs in event 902 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 903 = 2
# Pairs at theta values of: [[1.53747, 1.53748], [1.60413, 1.60413]] ([layer1,layer2])
#
# Number of pairs in event 904 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 905 = 2
# Pairs at theta values of: [[1.92328, 1.92326], [1.21832, 1.21832]] ([layer1,layer2])
#
# Number of pairs in event 906 = 6
# Pairs at theta values of: [[1.53846, 1.53844], [1.53846, 1.53844], [1.53846, 1.5384], [1.53846, 1.53841], [1.53846, 1.53841], [1.60313, 1.60313]] ([layer1,layer2])
#
# Number of pairs in event 907 = 2
# Pairs at theta values of: [[1.6994, 1.69941], [1.44702, 1.44699]] ([layer1,layer2])
#
# Number of pairs in event 908 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 909 = 2
# Pairs at theta values of: [[1.40229, 1.40228], [1.73929, 1.73927]] ([layer1,layer2])
#
# Number of pairs in event 910 = 2
# Pairs at theta values of: [[0.801536, 0.801549], [2.34006, 2.34008]] ([layer1,layer2])
#
# Number of pairs in event 911 = 1
# Pairs at theta values of: [[1.72472, 1.72473]] ([layer1,layer2])
#
# Number of pairs in event 912 = 2
# Pairs at theta values of: [[1.15967, 1.15966], [1.98193, 1.98193]] ([layer1,layer2])
#
# Number of pairs in event 913 = 7
# Pairs at theta values of: [[1.33607, 1.33608], [1.80554, 1.80553], [1.80554, 1.80553], [1.8055, 1.80553], [1.80548, 1.80553], [1.8055, 1.80553], [1.80553, 1.80553]] ([layer1,layer2])
#
# Number of pairs in event 914 = 2
# Pairs at theta values of: [[1.6575, 1.6575], [1.48409, 1.48408]] ([layer1,layer2])
#
# Number of pairs in event 915 = 2
# Pairs at theta values of: [[1.9145, 1.91449], [1.22943, 1.22942]] ([layer1,layer2])
#
# Number of pairs in event 916 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 917 = 11
# Pairs at theta values of: [[1.34002, 1.33998], [1.80156, 1.80159], [1.80156, 1.80159], [1.80156, 1.8016], [1.80156, 1.8016], [1.80156, 1.8016], [1.80156, 1.8016], [1.80156, 1.8016], [1.80156, 1.8016], [1.80156, 1.80159], [1.80156, 1.8016]] ([layer1,layer2])
#
# Number of pairs in event 918 = 2
# Pairs at theta values of: [[2.16306, 2.16313], [0.97851, 0.978511]] ([layer1,layer2])
#
# Number of pairs in event 919 = 2
# Pairs at theta values of: [[2.07797, 2.07802], [1.06381, 1.06377]] ([layer1,layer2])
#
# Number of pairs in event 920 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 921 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 922 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 923 = 6
# Pairs at theta values of: [[1.42569, 1.42572], [1.42569, 1.42572], [1.42569, 1.42571], [1.42569, 1.42571], [1.42569, 1.42571], [1.73485, 1.73485]] ([layer1,layer2])
#
# Number of pairs in event 924 = 2
# Pairs at theta values of: [[2.04572, 2.04572], [1.09588, 1.09584]] ([layer1,layer2])
#
# Number of pairs in event 925 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 926 = 2
# Pairs at theta values of: [[1.19241, 1.19243], [1.94914, 1.94916]] ([layer1,layer2])
#
# Number of pairs in event 927 = 2
# Pairs at theta values of: [[2.19268, 2.19269], [0.948912, 0.948895]] ([layer1,layer2])
#
# Number of pairs in event 928 = 2
# Pairs at theta values of: [[1.58224, 1.58224], [1.55937, 1.55937]] ([layer1,layer2])
#
# Number of pairs in event 929 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 930 = 2
# Pairs at theta values of: [[1.86541, 1.86545], [1.27621, 1.27623]] ([layer1,layer2])
#
# Number of pairs in event 931 = 1
# Pairs at theta values of: [[0.809143, 0.809161]] ([layer1,layer2])
#
# Number of pairs in event 932 = 5
# Pairs at theta values of: [[1.88488, 1.88487], [1.25672, 1.25671], [1.25672, 1.25671], [1.25667, 1.25671], [1.25666, 1.25671]] ([layer1,layer2])
#
# Number of pairs in event 933 = 2
# Pairs at theta values of: [[2.19127, 2.19127], [0.9503, 0.950301]] ([layer1,layer2])
#
# Number of pairs in event 934 = 2
# Pairs at theta values of: [[1.1375, 1.13751], [2.00405, 2.00405]] ([layer1,layer2])
#
# Number of pairs in event 935 = 10
# Pairs at theta values of: [[1.74803, 1.74803], [1.39356, 1.39357], [1.39356, 1.39357], [1.39356, 1.39356], [1.39356, 1.39355], [1.39356, 1.39354], [1.39356, 1.39353], [1.39356, 1.39352], [1.39356, 1.39354], [1.39356, 1.39355]] ([layer1,layer2])
#
# Number of pairs in event 936 = 2
# Pairs at theta values of: [[1.5657, 1.5657], [1.45423, 1.45422]] ([layer1,layer2])
#
# Number of pairs in event 937 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 938 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 939 = 2
# Pairs at theta values of: [[1.23758, 1.23757], [1.90401, 1.904]] ([layer1,layer2])
#
# Number of pairs in event 940 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 941 = 2
# Pairs at theta values of: [[1.93511, 1.93509], [1.20652, 1.20653]] ([layer1,layer2])
#
# Number of pairs in event 942 = 1
# Pairs at theta values of: [[2.32146, 2.3215]] ([layer1,layer2])
#
# Number of pairs in event 943 = 2
# Pairs at theta values of: [[2.17704, 2.17703], [0.964571, 0.96455]] ([layer1,layer2])
#
# Number of pairs in event 944 = 2
# Pairs at theta values of: [[2.24203, 2.24203], [0.899574, 0.899599]] ([layer1,layer2])
#
# Number of pairs in event 945 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 946 = 2
# Pairs at theta values of: [[1.4985, 1.4985], [1.64312, 1.64314]] ([layer1,layer2])
#
# Number of pairs in event 947 = 2
# Pairs at theta values of: [[1.69229, 1.69233], [1.44933, 1.44933]] ([layer1,layer2])
#
# Number of pairs in event 948 = 2
# Pairs at theta values of: [[1.48925, 1.48927], [1.65241, 1.65243]] ([layer1,layer2])
#
# Number of pairs in event 949 = 2
# Pairs at theta values of: [[2.35437, 2.35437], [0.787185, 0.78715]] ([layer1,layer2])
#
# Number of pairs in event 950 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 951 = 9
# Pairs at theta values of: [[1.04308, 1.04306], [1.04308, 1.04306], [1.04306, 1.04306], [1.04305, 1.04306], [1.04304, 1.04306], [2.09692, 2.09691], [2.09692, 2.09691], [2.09697, 2.09691], [2.09699, 2.09691]] ([layer1,layer2])
#
# Number of pairs in event 952 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 953 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 954 = 2
# Pairs at theta values of: [[1.65316, 1.65317], [1.48841, 1.48838]] ([layer1,layer2])
#
# Number of pairs in event 955 = 6
# Pairs at theta values of: [[1.32986, 1.32985], [1.32986, 1.32985], [1.32986, 1.32985], [1.32985, 1.32985], [1.32986, 1.32985], [1.81174, 1.81175]] ([layer1,layer2])
#
# Number of pairs in event 956 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 957 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 958 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 959 = 5
# Pairs at theta values of: [[1.28819, 1.28819], [1.85341, 1.8534], [1.85341, 1.8534], [1.85341, 1.85344], [1.85341, 1.85347]] ([layer1,layer2])
#
# Number of pairs in event 960 = 3
# Pairs at theta values of: [[0.978059, 0.978029], [2.16353, 2.16359], [2.16353, 2.16359]] ([layer1,layer2])
#
# Number of pairs in event 961 = 19
# Pairs at theta values of: [[1.69068, 1.6907], [1.44995, 1.44997], [1.44995, 1.44997], [1.44995, 1.44998], [1.44995, 1.44998], [1.44995, 1.44997], [1.44995, 1.44996], [1.44995, 1.44997], [1.44995, 1.44997], [1.44995, 1.44998], [1.44995, 1.44998], [1.44995, 1.44997], [1.44995, 1.44996], [1.44989, 1.44997], [1.44989, 1.44997], [1.44989, 1.44998], [1.44989, 1.44998], [1.44989, 1.44997], [1.44989, 1.44996]] ([layer1,layer2])
#
# Number of pairs in event 962 = 2
# Pairs at theta values of: [[2.05811, 2.05809], [1.08348, 1.0834]] ([layer1,layer2])
#
# Number of pairs in event 963 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 964 = 2
# Pairs at theta values of: [[1.26342, 1.26346], [1.87816, 1.87818]] ([layer1,layer2])
#
# Number of pairs in event 965 = 2
# Pairs at theta values of: [[0.97191, 0.971896], [2.16971, 2.16977]] ([layer1,layer2])
#
# Number of pairs in event 966 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 967 = 2
# Pairs at theta values of: [[1.38816, 1.38815], [1.58198, 1.582]] ([layer1,layer2])
#
# Number of pairs in event 968 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 969 = 2
# Pairs at theta values of: [[0.843872, 0.843854], [2.29769, 2.29773]] ([layer1,layer2])
#
# Number of pairs in event 970 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 971 = 2
# Pairs at theta values of: [[2.21236, 2.21238], [0.929236, 0.929263]] ([layer1,layer2])
#
# Number of pairs in event 972 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 973 = 9
# Pairs at theta values of: [[1.05986, 1.05983], [2.10664, 2.10662], [2.10664, 2.10662], [2.10664, 2.10662], [2.10663, 2.10662], [2.10662, 2.10662], [2.10664, 2.10662], [2.10665, 2.10662], [2.10665, 2.10662]] ([layer1,layer2])
#
# Number of pairs in event 974 = 8
# Pairs at theta values of: [[1.93807, 1.93811], [1.20351, 1.20353], [1.20351, 1.20353], [1.20351, 1.20351], [1.20351, 1.2035], [1.20351, 1.20348], [1.20351, 1.20346], [1.20351, 1.20346]] ([layer1,layer2])
#
# Number of pairs in event 975 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 976 = 2
# Pairs at theta values of: [[1.03785, 1.03785], [2.10388, 2.10391]] ([layer1,layer2])
#
# Number of pairs in event 977 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 978 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 979 = 2
# Pairs at theta values of: [[1.93159, 1.93162], [1.20998, 1.20998]] ([layer1,layer2])
#
# Number of pairs in event 980 = 2
# Pairs at theta values of: [[1.71249, 1.71249], [1.42914, 1.42913]] ([layer1,layer2])
#
# Number of pairs in event 981 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 982 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 983 = 2
# Pairs at theta values of: [[1.68457, 1.68454], [1.457, 1.45702]] ([layer1,layer2])
#
# Number of pairs in event 984 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 985 = 2
# Pairs at theta values of: [[1.74617, 1.74616], [1.39542, 1.39538]] ([layer1,layer2])
#
# Number of pairs in event 986 = 2
# Pairs at theta values of: [[1.77193, 1.77195], [1.36968, 1.36967]] ([layer1,layer2])
#
# Number of pairs in event 987 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 988 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 989 = 4
# Pairs at theta values of: [[1.1435, 1.14353], [1.9981, 1.99811], [1.9981, 1.99811], [1.9981, 1.99807]] ([layer1,layer2])
#
# Number of pairs in event 990 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 991 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 992 = 2
# Pairs at theta values of: [[1.53194, 1.53197], [1.60966, 1.60967]] ([layer1,layer2])
#
# Number of pairs in event 993 = 2
# Pairs at theta values of: [[0.902889, 0.902894], [2.2387, 2.2387]] ([layer1,layer2])
#
# Number of pairs in event 994 = 2
# Pairs at theta values of: [[1.25043, 1.25043], [1.89134, 1.89135]] ([layer1,layer2])
#
# Number of pairs in event 995 = 10
# Pairs at theta values of: [[2.2653, 2.26532], [2.2653, 2.26532], [2.26534, 2.26532], [2.26536, 2.26532], [2.26538, 2.26532], [2.26539, 2.26532], [2.2654, 2.26532], [2.2654, 2.26532], [2.26541, 2.26532], [0.876367, 0.876379]] ([layer1,layer2])
#
# Number of pairs in event 996 = 0
# Pairs at theta values of: [] ([layer1,layer2])
#
# Number of pairs in event 997 = 2
# Pairs at theta values of: [[1.14699, 1.14701], [2.02566, 2.02563]] ([layer1,layer2])
#
# Number of pairs in event 998 = 7
# Pairs at theta values of: [[1.35243, 1.35244], [1.80545, 1.80546], [1.80545, 1.80546], [1.80543, 1.80546], [1.80542, 1.80546], [1.80539, 1.80546], [1.80536, 1.80546]] ([layer1,layer2])
#
# Number of pairs in event 999 = 2
# Pairs at theta values of: [[1.77165, 1.77162], [1.44729, 1.44727]] ([layer1,layer2])

# %%
# Part 3

delta_phi = []
theta_average = []

# Loop over all events
for i in range(1000):
    if len(np.array(pair_phi_values[i])>0): # remove all events without pairs
        # append the value of delta phi
        delta_phi.append(abs(np.array(pair_phi_values[i])[:,0]-np.array(pair_phi_values[i])[:,1]))
        # Find the mean of the theta value pairs at each layer (they are similar enough that this is effectively selecting one)
        theta_average.append(np.mean(pair_theta_values[i],axis=1)) 
        
delta_phi = np.hstack(delta_phi) # Convert to 1 dimensional array
theta_average = np.hstack(theta_average) # Convert to 1 dimensional array

sagitta = np.sin(delta_phi)*4 # m

b_radius = (8.**2)/(8*sagitta) #R = L^2/8s #m

p_t = 0.3*0.5*b_radius #p_t = 0.3*B*R #GeV

p = p_t/np.sin(theta_average) # Calculate momentum in GeV

# Treating each pair as an individual particle
print("The values for the particle momenta are:\n")
for i in range(len(p)):
    print("Momentum for particle {:} = {:.4f} GeV".format(i,p[i]))
# Out:
# The values for the particle momenta are:
#
# Momentum for particle 0 = 45.5298 GeV
# Momentum for particle 1 = 45.7014 GeV
# Momentum for particle 2 = 45.6958 GeV
# Momentum for particle 3 = 45.8300 GeV
# Momentum for particle 4 = 45.9255 GeV
# Momentum for particle 5 = 45.9364 GeV
# Momentum for particle 6 = 45.9082 GeV
# Momentum for particle 7 = 45.4959 GeV
# Momentum for particle 8 = 45.2218 GeV
# Momentum for particle 9 = 45.4471 GeV
# Momentum for particle 10 = 45.4637 GeV
# Momentum for particle 11 = 45.4637 GeV
# Momentum for particle 12 = 45.5765 GeV
# Momentum for particle 13 = 45.7467 GeV
# Momentum for particle 14 = 45.9184 GeV
# Momentum for particle 15 = 45.4484 GeV
# Momentum for particle 16 = 45.4751 GeV
# Momentum for particle 17 = 45.4751 GeV
# Momentum for particle 18 = 46.2870 GeV
# Momentum for particle 19 = 45.2696 GeV
# Momentum for particle 20 = 45.7095 GeV
# Momentum for particle 21 = 45.7381 GeV
# Momentum for particle 22 = 45.7381 GeV
# Momentum for particle 23 = 45.4613 GeV
# Momentum for particle 24 = 45.1878 GeV
# Momentum for particle 25 = 45.4066 GeV
# Momentum for particle 26 = 45.3861 GeV
# Momentum for particle 27 = 45.7314 GeV
# Momentum for particle 28 = 46.0326 GeV
# Momentum for particle 29 = 46.2451 GeV
# Momentum for particle 30 = 46.4165 GeV
# Momentum for particle 31 = 46.5099 GeV
# Momentum for particle 32 = 45.0476 GeV
# Momentum for particle 33 = 45.0568 GeV
# Momentum for particle 34 = 45.5678 GeV
# Momentum for particle 35 = 45.3022 GeV
# Momentum for particle 36 = 45.7005 GeV
# Momentum for particle 37 = 45.7674 GeV
# Momentum for particle 38 = 45.3230 GeV
# Momentum for particle 39 = 45.5805 GeV
# Momentum for particle 40 = 45.4650 GeV
# Momentum for particle 41 = 45.3393 GeV
# Momentum for particle 42 = 45.4657 GeV
# Momentum for particle 43 = 45.1749 GeV
# Momentum for particle 44 = 45.5668 GeV
# Momentum for particle 45 = 45.7707 GeV
# Momentum for particle 46 = 45.5215 GeV
# Momentum for particle 47 = 42.6224 GeV
# Momentum for particle 48 = 45.3743 GeV
# Momentum for particle 49 = 45.4665 GeV
# Momentum for particle 50 = 45.4090 GeV
# Momentum for particle 51 = 45.5842 GeV
# Momentum for particle 52 = 45.4076 GeV
# Momentum for particle 53 = 45.4079 GeV
# Momentum for particle 54 = 45.4079 GeV
# Momentum for particle 55 = 45.6043 GeV
# Momentum for particle 56 = 45.8022 GeV
# Momentum for particle 57 = 45.9352 GeV
# Momentum for particle 58 = 46.0021 GeV
# Momentum for particle 59 = 46.0022 GeV
# Momentum for particle 60 = 45.7118 GeV
# Momentum for particle 61 = 45.7118 GeV
# Momentum for particle 62 = 45.3478 GeV
# Momentum for particle 63 = 45.0494 GeV
# Momentum for particle 64 = 44.9902 GeV
# Momentum for particle 65 = 21.5842 GeV
# Momentum for particle 66 = 45.1973 GeV
# Momentum for particle 67 = 45.1973 GeV
# Momentum for particle 68 = 45.5321 GeV
# Momentum for particle 69 = 45.5322 GeV
# Momentum for particle 70 = 45.1976 GeV
# Momentum for particle 71 = 45.0649 GeV
# Momentum for particle 72 = 45.0645 GeV
# Momentum for particle 73 = 45.5946 GeV
# Momentum for particle 74 = 45.1656 GeV
# Momentum for particle 75 = 45.5000 GeV
# Momentum for particle 76 = 45.4402 GeV
# Momentum for particle 77 = 45.4350 GeV
# Momentum for particle 78 = 45.4136 GeV
# Momentum for particle 79 = 45.4187 GeV
# Momentum for particle 80 = 45.5639 GeV
# Momentum for particle 81 = 45.6330 GeV
# Momentum for particle 82 = 42.1248 GeV
# Momentum for particle 83 = 45.4777 GeV
# Momentum for particle 84 = 45.3529 GeV
# Momentum for particle 85 = 45.5540 GeV
# Momentum for particle 86 = 45.7464 GeV
# Momentum for particle 87 = 45.6098 GeV
# Momentum for particle 88 = 45.2980 GeV
# Momentum for particle 89 = 45.3629 GeV
# Momentum for particle 90 = 45.4189 GeV
# Momentum for particle 91 = 45.2935 GeV
# Momentum for particle 92 = 45.5645 GeV
# Momentum for particle 93 = 45.8556 GeV
# Momentum for particle 94 = 45.6640 GeV
# Momentum for particle 95 = 45.6012 GeV
# Momentum for particle 96 = 45.6012 GeV
# Momentum for particle 97 = 45.4158 GeV
# Momentum for particle 98 = 45.2931 GeV
# Momentum for particle 99 = 45.3545 GeV
# Momentum for particle 100 = 45.4160 GeV
# Momentum for particle 101 = 45.4161 GeV
# Momentum for particle 102 = 45.5180 GeV
# Momentum for particle 103 = 45.5833 GeV
# Momentum for particle 104 = 45.6109 GeV
# Momentum for particle 105 = 45.5352 GeV
# Momentum for particle 106 = 45.4872 GeV
# Momentum for particle 107 = 45.4052 GeV
# Momentum for particle 108 = 45.3302 GeV
# Momentum for particle 109 = 45.1947 GeV
# Momentum for particle 110 = 45.0398 GeV
# Momentum for particle 111 = 44.9728 GeV
# Momentum for particle 112 = 45.5880 GeV
# Momentum for particle 113 = 45.3563 GeV
# Momentum for particle 114 = 45.3861 GeV
# Momentum for particle 115 = 45.3861 GeV
# Momentum for particle 116 = 45.4980 GeV
# Momentum for particle 117 = 45.6669 GeV
# Momentum for particle 118 = 45.9509 GeV
# Momentum for particle 119 = 46.1807 GeV
# Momentum for particle 120 = 46.3545 GeV
# Momentum for particle 121 = 46.6474 GeV
# Momentum for particle 122 = 46.9441 GeV
# Momentum for particle 123 = 47.1839 GeV
# Momentum for particle 124 = 47.3656 GeV
# Momentum for particle 125 = 47.4873 GeV
# Momentum for particle 126 = 45.4646 GeV
# Momentum for particle 127 = 45.6027 GeV
# Momentum for particle 128 = 45.4169 GeV
# Momentum for particle 129 = 45.5284 GeV
# Momentum for particle 130 = 45.5235 GeV
# Momentum for particle 131 = 45.7198 GeV
# Momentum for particle 132 = 45.5996 GeV
# Momentum for particle 133 = 45.6316 GeV
# Momentum for particle 134 = 45.4969 GeV
# Momentum for particle 135 = 45.2243 GeV
# Momentum for particle 136 = 45.7898 GeV
# Momentum for particle 137 = 45.6958 GeV
# Momentum for particle 138 = 45.7034 GeV
# Momentum for particle 139 = 45.4229 GeV
# Momentum for particle 140 = 45.4061 GeV
# Momentum for particle 141 = 45.3962 GeV
# Momentum for particle 142 = 45.3553 GeV
# Momentum for particle 143 = 45.2784 GeV
# Momentum for particle 144 = 45.8100 GeV
# Momentum for particle 145 = 45.3122 GeV
# Momentum for particle 146 = 45.5107 GeV
# Momentum for particle 147 = 37.7934 GeV
# Momentum for particle 148 = 37.7934 GeV
# Momentum for particle 149 = 37.7461 GeV
# Momentum for particle 150 = 37.6519 GeV
# Momentum for particle 151 = 26.2791 GeV
# Momentum for particle 152 = 45.6417 GeV
# Momentum for particle 153 = 45.3177 GeV
# Momentum for particle 154 = 45.4883 GeV
# Momentum for particle 155 = 45.2733 GeV
# Momentum for particle 156 = 45.4634 GeV
# Momentum for particle 157 = 45.5948 GeV
# Momentum for particle 158 = 45.4208 GeV
# Momentum for particle 159 = 45.4208 GeV
# Momentum for particle 160 = 45.3541 GeV
# Momentum for particle 161 = 45.2214 GeV
# Momentum for particle 162 = 45.1554 GeV
# Momentum for particle 163 = 44.8928 GeV
# Momentum for particle 164 = 44.8927 GeV
# Momentum for particle 165 = 45.5142 GeV
# Momentum for particle 166 = 44.6709 GeV
# Momentum for particle 167 = 44.7805 GeV
# Momentum for particle 168 = 44.6559 GeV
# Momentum for particle 169 = 44.5347 GeV
# Momentum for particle 170 = 45.5875 GeV
# Momentum for particle 171 = 45.7980 GeV
# Momentum for particle 172 = 45.3270 GeV
# Momentum for particle 173 = 45.2587 GeV
# Momentum for particle 174 = 45.4975 GeV
# Momentum for particle 175 = 45.4874 GeV
# Momentum for particle 176 = 45.4819 GeV
# Momentum for particle 177 = 45.3855 GeV
# Momentum for particle 178 = 45.3451 GeV
# Momentum for particle 179 = 45.3250 GeV
# Momentum for particle 180 = 45.3149 GeV
# Momentum for particle 181 = 45.3149 GeV
# Momentum for particle 182 = 45.3149 GeV
# Momentum for particle 183 = 45.3099 GeV
# Momentum for particle 184 = 45.0088 GeV
# Momentum for particle 185 = 45.5621 GeV
# Momentum for particle 186 = 45.5415 GeV
# Momentum for particle 187 = 45.5483 GeV
# Momentum for particle 188 = 45.5621 GeV
# Momentum for particle 189 = 45.5279 GeV
# Momentum for particle 190 = 45.5689 GeV
# Momentum for particle 191 = 45.5483 GeV
# Momentum for particle 192 = 45.5552 GeV
# Momentum for particle 193 = 45.5690 GeV
# Momentum for particle 194 = 45.5347 GeV
# Momentum for particle 195 = 45.8804 GeV
# Momentum for particle 196 = 45.8595 GeV
# Momentum for particle 197 = 45.8664 GeV
# Momentum for particle 198 = 45.8804 GeV
# Momentum for particle 199 = 45.8457 GeV
# Momentum for particle 200 = 45.8039 GeV
# Momentum for particle 201 = 45.7831 GeV
# Momentum for particle 202 = 45.7901 GeV
# Momentum for particle 203 = 45.8040 GeV
# Momentum for particle 204 = 45.7693 GeV
# Momentum for particle 205 = 45.6932 GeV
# Momentum for particle 206 = 45.7138 GeV
# Momentum for particle 207 = 45.6931 GeV
# Momentum for particle 208 = 45.7000 GeV
# Momentum for particle 209 = 45.7139 GeV
# Momentum for particle 210 = 45.6794 GeV
# Momentum for particle 211 = 45.6036 GeV
# Momentum for particle 212 = 45.5896 GeV
# Momentum for particle 213 = 45.5690 GeV
# Momentum for particle 214 = 45.5759 GeV
# Momentum for particle 215 = 45.5897 GeV
# Momentum for particle 216 = 45.5554 GeV
# Momentum for particle 217 = 45.4800 GeV
# Momentum for particle 218 = 45.5346 GeV
# Momentum for particle 219 = 45.5141 GeV
# Momentum for particle 220 = 45.5209 GeV
# Momentum for particle 221 = 45.5347 GeV
# Momentum for particle 222 = 45.5005 GeV
# Momentum for particle 223 = 45.4253 GeV
# Momentum for particle 224 = 45.5619 GeV
# Momentum for particle 225 = 45.6995 GeV
# Momentum for particle 226 = 45.5338 GeV
# Momentum for particle 227 = 45.5497 GeV
# Momentum for particle 228 = 45.6786 GeV
# Momentum for particle 229 = 45.6786 GeV
# Momentum for particle 230 = 45.9373 GeV
# Momentum for particle 231 = 46.0674 GeV
# Momentum for particle 232 = 46.0019 GeV
# Momentum for particle 233 = 46.0017 GeV
# Momentum for particle 234 = 46.0016 GeV
# Momentum for particle 235 = 46.0015 GeV
# Momentum for particle 236 = 45.4211 GeV
# Momentum for particle 237 = 44.4428 GeV
# Momentum for particle 238 = 45.3136 GeV
# Momentum for particle 239 = 45.3986 GeV
# Momentum for particle 240 = 45.7739 GeV
# Momentum for particle 241 = 45.5843 GeV
# Momentum for particle 242 = 45.6301 GeV
# Momentum for particle 243 = 45.6109 GeV
# Momentum for particle 244 = 45.7771 GeV
# Momentum for particle 245 = 45.7252 GeV
# Momentum for particle 246 = 45.5316 GeV
# Momentum for particle 247 = 44.7401 GeV
# Momentum for particle 248 = 45.6943 GeV
# Momentum for particle 249 = 45.6737 GeV
# Momentum for particle 250 = 45.6603 GeV
# Momentum for particle 251 = 45.4669 GeV
# Momentum for particle 252 = 45.3408 GeV
# Momentum for particle 253 = 45.5532 GeV
# Momentum for particle 254 = 45.6199 GeV
# Momentum for particle 255 = 45.3723 GeV
# Momentum for particle 256 = 45.8791 GeV
# Momentum for particle 257 = 45.2553 GeV
# Momentum for particle 258 = 36.4072 GeV
# Momentum for particle 259 = 45.7422 GeV
# Momentum for particle 260 = 45.5016 GeV
# Momentum for particle 261 = 45.3746 GeV
# Momentum for particle 262 = 45.5911 GeV
# Momentum for particle 263 = 45.4959 GeV
# Momentum for particle 264 = 45.0368 GeV
# Momentum for particle 265 = 45.6368 GeV
# Momentum for particle 266 = 45.4609 GeV
# Momentum for particle 267 = 45.6589 GeV
# Momentum for particle 268 = 45.6538 GeV
# Momentum for particle 269 = 45.5190 GeV
# Momentum for particle 270 = 45.4642 GeV
# Momentum for particle 271 = 45.4096 GeV
# Momentum for particle 272 = 45.4095 GeV
# Momentum for particle 273 = 45.4639 GeV
# Momentum for particle 274 = 45.4639 GeV
# Momentum for particle 275 = 45.4683 GeV
# Momentum for particle 276 = 46.2203 GeV
# Momentum for particle 277 = 45.5167 GeV
# Momentum for particle 278 = 43.3677 GeV
# Momentum for particle 279 = 45.7481 GeV
# Momentum for particle 280 = 45.2913 GeV
# Momentum for particle 281 = 45.2398 GeV
# Momentum for particle 282 = 35.0808 GeV
# Momentum for particle 283 = 35.0430 GeV
# Momentum for particle 284 = 35.0430 GeV
# Momentum for particle 285 = 35.0807 GeV
# Momentum for particle 286 = 35.0807 GeV
# Momentum for particle 287 = 35.0807 GeV
# Momentum for particle 288 = 35.0807 GeV
# Momentum for particle 289 = 35.0807 GeV
# Momentum for particle 290 = 35.0807 GeV
# Momentum for particle 291 = 35.0806 GeV
# Momentum for particle 292 = 35.1185 GeV
# Momentum for particle 293 = 45.6150 GeV
# Momentum for particle 294 = 44.9765 GeV
# Momentum for particle 295 = 45.8666 GeV
# Momentum for particle 296 = 45.6888 GeV
# Momentum for particle 297 = 45.6412 GeV
# Momentum for particle 298 = 45.6412 GeV
# Momentum for particle 299 = 45.8441 GeV
# Momentum for particle 300 = 45.8441 GeV
# Momentum for particle 301 = 45.8441 GeV
# Momentum for particle 302 = 45.7764 GeV
# Momentum for particle 303 = 45.7764 GeV
# Momentum for particle 304 = 45.7765 GeV
# Momentum for particle 305 = 45.7765 GeV
# Momentum for particle 306 = 45.7765 GeV
# Momentum for particle 307 = 45.7089 GeV
# Momentum for particle 308 = 45.6415 GeV
# Momentum for particle 309 = 45.6415 GeV
# Momentum for particle 310 = 45.6416 GeV
# Momentum for particle 311 = 45.7090 GeV
# Momentum for particle 312 = 45.7767 GeV
# Momentum for particle 313 = 45.5005 GeV
# Momentum for particle 314 = 45.5287 GeV
# Momentum for particle 315 = 45.5287 GeV
# Momentum for particle 316 = 45.5287 GeV
# Momentum for particle 317 = 45.7369 GeV
# Momentum for particle 318 = 45.8067 GeV
# Momentum for particle 319 = 45.8767 GeV
# Momentum for particle 320 = 45.4852 GeV
# Momentum for particle 321 = 45.8040 GeV
# Momentum for particle 322 = 45.8040 GeV
# Momentum for particle 323 = 45.8674 GeV
# Momentum for particle 324 = 45.8675 GeV
# Momentum for particle 325 = 45.2448 GeV
# Momentum for particle 326 = 45.5398 GeV
# Momentum for particle 327 = 45.5583 GeV
# Momentum for particle 328 = 45.6259 GeV
# Momentum for particle 329 = 45.7123 GeV
# Momentum for particle 330 = 45.8553 GeV
# Momentum for particle 331 = 46.0490 GeV
# Momentum for particle 332 = 46.2190 GeV
# Momentum for particle 333 = 46.3648 GeV
# Momentum for particle 334 = 46.4985 GeV
# Momentum for particle 335 = 46.5623 GeV
# Momentum for particle 336 = 46.6587 GeV
# Momentum for particle 337 = 46.7423 GeV
# Momentum for particle 338 = 45.4891 GeV
# Momentum for particle 339 = 45.6955 GeV
# Momentum for particle 340 = 44.2768 GeV
# Momentum for particle 341 = 45.2358 GeV
# Momentum for particle 342 = 45.6201 GeV
# Momentum for particle 343 = 44.4128 GeV
# Momentum for particle 344 = 43.6595 GeV
# Momentum for particle 345 = 30.5110 GeV
# Momentum for particle 346 = 45.4565 GeV
# Momentum for particle 347 = 45.5403 GeV
# Momentum for particle 348 = 45.2497 GeV
# Momentum for particle 349 = 45.2769 GeV
# Momentum for particle 350 = 45.2769 GeV
# Momentum for particle 351 = 45.1820 GeV
# Momentum for particle 352 = 45.0808 GeV
# Momentum for particle 353 = 45.0136 GeV
# Momentum for particle 354 = 44.9533 GeV
# Momentum for particle 355 = 44.9399 GeV
# Momentum for particle 356 = 44.9534 GeV
# Momentum for particle 357 = 44.8932 GeV
# Momentum for particle 358 = 44.7800 GeV
# Momentum for particle 359 = 44.5421 GeV
# Momentum for particle 360 = 45.4737 GeV
# Momentum for particle 361 = 45.4123 GeV
# Momentum for particle 362 = 45.4123 GeV
# Momentum for particle 363 = 45.2776 GeV
# Momentum for particle 364 = 45.2778 GeV
# Momentum for particle 365 = 45.2778 GeV
# Momentum for particle 366 = 45.2108 GeV
# Momentum for particle 367 = 45.2108 GeV
# Momentum for particle 368 = 45.2108 GeV
# Momentum for particle 369 = 45.2779 GeV
# Momentum for particle 370 = 45.4143 GeV
# Momentum for particle 371 = 45.3783 GeV
# Momentum for particle 372 = 45.6611 GeV
# Momentum for particle 373 = 45.4539 GeV
# Momentum for particle 374 = 45.4783 GeV
# Momentum for particle 375 = 45.3650 GeV
# Momentum for particle 376 = 45.3650 GeV
# Momentum for particle 377 = 45.3650 GeV
# Momentum for particle 378 = 45.3648 GeV
# Momentum for particle 379 = 45.7181 GeV
# Momentum for particle 380 = 45.3903 GeV
# Momentum for particle 381 = 45.7056 GeV
# Momentum for particle 382 = 40.3757 GeV
# Momentum for particle 383 = 38.2324 GeV
# Momentum for particle 384 = 23.9563 GeV
# Momentum for particle 385 = 45.8286 GeV
# Momentum for particle 386 = 45.5167 GeV
# Momentum for particle 387 = 45.3273 GeV
# Momentum for particle 388 = 41.4048 GeV
# Momentum for particle 389 = 41.4048 GeV
# Momentum for particle 390 = 41.4098 GeV
# Momentum for particle 391 = 41.3998 GeV
# Momentum for particle 392 = 41.3898 GeV
# Momentum for particle 393 = 41.3749 GeV
# Momentum for particle 394 = 41.3449 GeV
# Momentum for particle 395 = 41.3499 GeV
# Momentum for particle 396 = 41.3699 GeV
# Momentum for particle 397 = 41.3848 GeV
# Momentum for particle 398 = 41.3948 GeV
# Momentum for particle 399 = 41.3948 GeV
# Momentum for particle 400 = 41.3898 GeV
# Momentum for particle 401 = 41.3898 GeV
# Momentum for particle 402 = 45.5680 GeV
# Momentum for particle 403 = 45.8025 GeV
# Momentum for particle 404 = 45.8025 GeV
# Momentum for particle 405 = 46.2221 GeV
# Momentum for particle 406 = 46.5777 GeV
# Momentum for particle 407 = 46.7936 GeV
# Momentum for particle 408 = 46.9387 GeV
# Momentum for particle 409 = 46.9386 GeV
# Momentum for particle 410 = 46.9386 GeV
# Momentum for particle 411 = 46.8659 GeV
# Momentum for particle 412 = 45.6256 GeV
# Momentum for particle 413 = 45.4216 GeV
# Momentum for particle 414 = 45.4458 GeV
# Momentum for particle 415 = 45.4092 GeV
# Momentum for particle 416 = 45.5007 GeV
# Momentum for particle 417 = 45.6322 GeV
# Momentum for particle 418 = 45.7558 GeV
# Momentum for particle 419 = 45.6452 GeV
# Momentum for particle 420 = 45.2512 GeV
# Momentum for particle 421 = 45.4762 GeV
# Momentum for particle 422 = 44.8120 GeV
# Momentum for particle 423 = 44.8120 GeV
# Momentum for particle 424 = 45.0105 GeV
# Momentum for particle 425 = 45.0107 GeV
# Momentum for particle 426 = 45.0773 GeV
# Momentum for particle 427 = 45.5932 GeV
# Momentum for particle 428 = 45.1374 GeV
# Momentum for particle 429 = 45.6073 GeV
# Momentum for particle 430 = 42.5731 GeV
# Momentum for particle 431 = 45.3432 GeV
# Momentum for particle 432 = 45.8289 GeV
# Momentum for particle 433 = 45.4692 GeV
# Momentum for particle 434 = 45.8052 GeV
# Momentum for particle 435 = 45.7376 GeV
# Momentum for particle 436 = 45.8731 GeV
# Momentum for particle 437 = 46.0092 GeV
# Momentum for particle 438 = 46.1462 GeV
# Momentum for particle 439 = 46.2150 GeV
# Momentum for particle 440 = 46.2839 GeV
# Momentum for particle 441 = 46.2839 GeV
# Momentum for particle 442 = 45.5060 GeV
# Momentum for particle 443 = 45.5197 GeV
# Momentum for particle 444 = 45.7462 GeV
# Momentum for particle 445 = 45.7462 GeV
# Momentum for particle 446 = 45.8845 GeV
# Momentum for particle 447 = 45.7732 GeV
# Momentum for particle 448 = 40.6435 GeV
# Momentum for particle 449 = 45.5401 GeV
# Momentum for particle 450 = 45.4384 GeV
# Momentum for particle 451 = 45.5640 GeV
# Momentum for particle 452 = 45.5629 GeV
# Momentum for particle 453 = 45.5634 GeV
# Momentum for particle 454 = 45.5682 GeV
# Momentum for particle 455 = 45.6750 GeV
# Momentum for particle 456 = 45.4212 GeV
# Momentum for particle 457 = 45.5403 GeV
# Momentum for particle 458 = 45.5154 GeV
# Momentum for particle 459 = 45.3366 GeV
# Momentum for particle 460 = 45.3366 GeV
# Momentum for particle 461 = 45.2384 GeV
# Momentum for particle 462 = 45.1898 GeV
# Momentum for particle 463 = 45.2389 GeV
# Momentum for particle 464 = 45.2878 GeV
# Momentum for particle 465 = 45.3369 GeV
# Momentum for particle 466 = 45.2876 GeV
# Momentum for particle 467 = 45.4993 GeV
# Momentum for particle 468 = 45.4765 GeV
# Momentum for particle 469 = 45.5572 GeV
# Momentum for particle 470 = 43.7300 GeV
# Momentum for particle 471 = 45.7546 GeV
# Momentum for particle 472 = 45.7284 GeV
# Momentum for particle 473 = 45.5257 GeV
# Momentum for particle 474 = 45.4030 GeV
# Momentum for particle 475 = 44.1380 GeV
# Momentum for particle 476 = 44.1380 GeV
# Momentum for particle 477 = 44.3336 GeV
# Momentum for particle 478 = 45.4157 GeV
# Momentum for particle 479 = 45.6985 GeV
# Momentum for particle 480 = 45.6836 GeV
# Momentum for particle 481 = 45.6836 GeV
# Momentum for particle 482 = 45.6834 GeV
# Momentum for particle 483 = 45.6833 GeV
# Momentum for particle 484 = 45.6184 GeV
# Momentum for particle 485 = 44.9150 GeV
# Momentum for particle 486 = 44.4787 GeV
# Momentum for particle 487 = 46.0115 GeV
# Momentum for particle 488 = 46.1443 GeV
# Momentum for particle 489 = 46.4117 GeV
# Momentum for particle 490 = 46.6822 GeV
# Momentum for particle 491 = 43.5298 GeV
# Momentum for particle 492 = 44.6623 GeV
# Momentum for particle 493 = 44.6623 GeV
# Momentum for particle 494 = 44.5352 GeV
# Momentum for particle 495 = 45.6383 GeV
# Momentum for particle 496 = 45.5734 GeV
# Momentum for particle 497 = 45.6842 GeV
# Momentum for particle 498 = 45.7822 GeV
# Momentum for particle 499 = 45.5574 GeV
# Momentum for particle 500 = 45.8635 GeV
# Momentum for particle 501 = 45.4233 GeV
# Momentum for particle 502 = 45.7467 GeV
# Momentum for particle 503 = 45.4928 GeV
# Momentum for particle 504 = 45.1472 GeV
# Momentum for particle 505 = 45.4612 GeV
# Momentum for particle 506 = 45.4449 GeV
# Momentum for particle 507 = 45.6164 GeV
# Momentum for particle 508 = 45.5330 GeV
# Momentum for particle 509 = 45.5435 GeV
# Momentum for particle 510 = 45.9226 GeV
# Momentum for particle 511 = 46.0510 GeV
# Momentum for particle 512 = 46.2012 GeV
# Momentum for particle 513 = 46.4012 GeV
# Momentum for particle 514 = 46.6141 GeV
# Momentum for particle 515 = 45.6726 GeV
# Momentum for particle 516 = 45.3824 GeV
# Momentum for particle 517 = 45.8031 GeV
# Momentum for particle 518 = 45.4987 GeV
# Momentum for particle 519 = 45.4987 GeV
# Momentum for particle 520 = 45.4385 GeV
# Momentum for particle 521 = 45.0792 GeV
# Momentum for particle 522 = 44.3773 GeV
# Momentum for particle 523 = 45.5603 GeV
# Momentum for particle 524 = 45.5931 GeV
# Momentum for particle 525 = 44.2697 GeV
# Momentum for particle 526 = 45.7607 GeV
# Momentum for particle 527 = 45.4394 GeV
# Momentum for particle 528 = 45.5652 GeV
# Momentum for particle 529 = 45.5929 GeV
# Momentum for particle 530 = 45.4842 GeV
# Momentum for particle 531 = 42.3993 GeV
# Momentum for particle 532 = 45.7276 GeV
# Momentum for particle 533 = 45.7792 GeV
# Momentum for particle 534 = 45.5231 GeV
# Momentum for particle 535 = 45.4733 GeV
# Momentum for particle 536 = 45.4719 GeV
# Momentum for particle 537 = 45.6710 GeV
# Momentum for particle 538 = 45.4485 GeV
# Momentum for particle 539 = 45.4586 GeV
# Momentum for particle 540 = 45.6398 GeV
# Momentum for particle 541 = 45.2964 GeV
# Momentum for particle 542 = 36.5791 GeV
# Momentum for particle 543 = 44.1122 GeV
# Momentum for particle 544 = 35.8122 GeV
# Momentum for particle 545 = 45.5113 GeV
# Momentum for particle 546 = 45.6040 GeV
# Momentum for particle 547 = 45.4841 GeV
# Momentum for particle 548 = 45.4841 GeV
# Momentum for particle 549 = 45.8122 GeV
# Momentum for particle 550 = 45.8124 GeV
# Momentum for particle 551 = 45.8125 GeV
# Momentum for particle 552 = 45.8125 GeV
# Momentum for particle 553 = 45.8126 GeV
# Momentum for particle 554 = 45.5489 GeV
# Momentum for particle 555 = 45.4445 GeV
# Momentum for particle 556 = 45.5130 GeV
# Momentum for particle 557 = 45.6330 GeV
# Momentum for particle 558 = 45.6707 GeV
# Momentum for particle 559 = 45.4686 GeV
# Momentum for particle 560 = 45.5999 GeV
# Momentum for particle 561 = 45.4132 GeV
# Momentum for particle 562 = 45.4132 GeV
# Momentum for particle 563 = 45.4370 GeV
# Momentum for particle 564 = 48.6768 GeV
# Momentum for particle 565 = 48.6768 GeV
# Momentum for particle 566 = 45.5923 GeV
# Momentum for particle 567 = 45.6430 GeV
# Momentum for particle 568 = 45.4609 GeV
# Momentum for particle 569 = 45.6348 GeV
# Momentum for particle 570 = 45.2989 GeV
# Momentum for particle 571 = 45.3211 GeV
# Momentum for particle 572 = 45.4024 GeV
# Momentum for particle 573 = 45.3564 GeV
# Momentum for particle 574 = 43.2598 GeV
# Momentum for particle 575 = 45.5206 GeV
# Momentum for particle 576 = 45.1853 GeV
# Momentum for particle 577 = 45.5473 GeV
# Momentum for particle 578 = 45.6651 GeV
# Momentum for particle 579 = 45.3951 GeV
# Momentum for particle 580 = 45.1950 GeV
# Momentum for particle 581 = 45.5941 GeV
# Momentum for particle 582 = 45.5819 GeV
# Momentum for particle 583 = 45.7408 GeV
# Momentum for particle 584 = 45.9570 GeV
# Momentum for particle 585 = 46.0070 GeV
# Momentum for particle 586 = 46.0072 GeV
# Momentum for particle 587 = 46.0449 GeV
# Momentum for particle 588 = 46.0328 GeV
# Momentum for particle 589 = 45.6064 GeV
# Momentum for particle 590 = 45.5941 GeV
# Momentum for particle 591 = 45.7532 GeV
# Momentum for particle 592 = 45.9694 GeV
# Momentum for particle 593 = 46.0194 GeV
# Momentum for particle 594 = 46.0196 GeV
# Momentum for particle 595 = 46.0574 GeV
# Momentum for particle 596 = 46.0453 GeV
# Momentum for particle 597 = 46.0867 GeV
# Momentum for particle 598 = 45.8883 GeV
# Momentum for particle 599 = 45.8883 GeV
# Momentum for particle 600 = 45.8883 GeV
# Momentum for particle 601 = 45.9503 GeV
# Momentum for particle 602 = 45.9504 GeV
# Momentum for particle 603 = 46.0126 GeV
# Momentum for particle 604 = 46.0750 GeV
# Momentum for particle 605 = 46.1376 GeV
# Momentum for particle 606 = 46.1376 GeV
# Momentum for particle 607 = 45.5543 GeV
# Momentum for particle 608 = 45.1794 GeV
# Momentum for particle 609 = 45.1794 GeV
# Momentum for particle 610 = 44.9942 GeV
# Momentum for particle 611 = 44.9322 GeV
# Momentum for particle 612 = 45.3030 GeV
# Momentum for particle 613 = 45.3031 GeV
# Momentum for particle 614 = 45.5692 GeV
# Momentum for particle 615 = 45.7301 GeV
# Momentum for particle 616 = 45.3885 GeV
# Momentum for particle 617 = 45.3778 GeV
# Momentum for particle 618 = 45.4633 GeV
# Momentum for particle 619 = 45.5055 GeV
# Momentum for particle 620 = 45.5315 GeV
# Momentum for particle 621 = 37.7241 GeV
# Momentum for particle 622 = 37.7966 GeV
# Momentum for particle 623 = 37.8791 GeV
# Momentum for particle 624 = 37.9491 GeV
# Momentum for particle 625 = 38.0119 GeV
# Momentum for particle 626 = 38.0854 GeV
# Momentum for particle 627 = 38.1583 GeV
# Momentum for particle 628 = 38.1995 GeV
# Momentum for particle 629 = 38.1947 GeV
# Momentum for particle 630 = 32.5145 GeV
# Momentum for particle 631 = 32.5154 GeV
# Momentum for particle 632 = 32.5211 GeV
# Momentum for particle 633 = 32.5320 GeV
# Momentum for particle 634 = 32.5512 GeV
# Momentum for particle 635 = 32.6039 GeV
# Momentum for particle 636 = 32.6640 GeV
# Momentum for particle 637 = 32.7018 GeV
# Momentum for particle 638 = 32.6967 GeV
# Momentum for particle 639 = 32.6823 GeV
# Momentum for particle 640 = 45.4530 GeV
# Momentum for particle 641 = 45.4323 GeV
# Momentum for particle 642 = 45.4048 GeV
# Momentum for particle 643 = 45.3158 GeV
# Momentum for particle 644 = 45.2066 GeV
# Momentum for particle 645 = 45.0979 GeV
# Momentum for particle 646 = 45.0168 GeV
# Momentum for particle 647 = 45.0168 GeV
# Momentum for particle 648 = 45.4736 GeV
# Momentum for particle 649 = 45.4530 GeV
# Momentum for particle 650 = 45.4255 GeV
# Momentum for particle 651 = 45.3363 GeV
# Momentum for particle 652 = 45.2270 GeV
# Momentum for particle 653 = 45.1183 GeV
# Momentum for particle 654 = 45.0371 GeV
# Momentum for particle 655 = 45.0371 GeV
# Momentum for particle 656 = 45.4048 GeV
# Momentum for particle 657 = 45.3842 GeV
# Momentum for particle 658 = 45.3568 GeV
# Momentum for particle 659 = 45.2679 GeV
# Momentum for particle 660 = 45.1589 GeV
# Momentum for particle 661 = 45.0505 GeV
# Momentum for particle 662 = 45.3362 GeV
# Momentum for particle 663 = 42.8168 GeV
# Momentum for particle 664 = 45.5305 GeV
# Momentum for particle 665 = 45.4366 GeV
# Momentum for particle 666 = 45.4843 GeV
# Momentum for particle 667 = 42.9958 GeV
# Momentum for particle 668 = 45.6699 GeV
# Momentum for particle 669 = 45.8653 GeV
# Momentum for particle 670 = 45.4668 GeV
# Momentum for particle 671 = 45.1664 GeV
# Momentum for particle 672 = 45.3497 GeV
# Momentum for particle 673 = 45.6090 GeV
# Momentum for particle 674 = 45.1945 GeV
# Momentum for particle 675 = 45.4136 GeV
# Momentum for particle 676 = 45.6095 GeV
# Momentum for particle 677 = 45.7800 GeV
# Momentum for particle 678 = 45.6690 GeV
# Momentum for particle 679 = 45.0978 GeV
# Momentum for particle 680 = 45.5576 GeV
# Momentum for particle 681 = 45.5576 GeV
# Momentum for particle 682 = 45.5576 GeV
# Momentum for particle 683 = 45.5575 GeV
# Momentum for particle 684 = 45.3817 GeV
# Momentum for particle 685 = 45.2656 GeV
# Momentum for particle 686 = 45.3239 GeV
# Momentum for particle 687 = 45.3240 GeV
# Momentum for particle 688 = 45.2658 GeV
# Momentum for particle 689 = 45.5547 GeV
# Momentum for particle 690 = 29.1092 GeV
# Momentum for particle 691 = 41.3087 GeV
# Momentum for particle 692 = 46.2774 GeV
# Momentum for particle 693 = 45.3631 GeV
# Momentum for particle 694 = 45.5351 GeV
# Momentum for particle 695 = 45.3758 GeV
# Momentum for particle 696 = 45.3758 GeV
# Momentum for particle 697 = 45.2689 GeV
# Momentum for particle 698 = 45.2158 GeV
# Momentum for particle 699 = 45.4614 GeV
# Momentum for particle 700 = 44.6520 GeV
# Momentum for particle 701 = 45.4827 GeV
# Momentum for particle 702 = 45.5417 GeV
# Momentum for particle 703 = 45.8934 GeV
# Momentum for particle 704 = 45.8934 GeV
# Momentum for particle 705 = 46.1489 GeV
# Momentum for particle 706 = 45.7100 GeV
# Momentum for particle 707 = 45.2692 GeV
# Momentum for particle 708 = 45.7267 GeV
# Momentum for particle 709 = 45.5559 GeV
# Momentum for particle 710 = 45.7299 GeV
# Momentum for particle 711 = 45.7546 GeV
# Momentum for particle 712 = 45.6533 GeV
# Momentum for particle 713 = 45.2340 GeV
# Momentum for particle 714 = 45.3665 GeV
# Momentum for particle 715 = 45.1793 GeV
# Momentum for particle 716 = 45.4140 GeV
# Momentum for particle 717 = 45.5522 GeV
# Momentum for particle 718 = 45.3298 GeV
# Momentum for particle 719 = 45.7487 GeV
# Momentum for particle 720 = 45.4772 GeV
# Momentum for particle 721 = 45.4373 GeV
# Momentum for particle 722 = 45.1550 GeV
# Momentum for particle 723 = 45.4195 GeV
# Momentum for particle 724 = 45.4195 GeV
# Momentum for particle 725 = 45.3555 GeV
# Momentum for particle 726 = 45.2918 GeV
# Momentum for particle 727 = 45.1650 GeV
# Momentum for particle 728 = 45.1019 GeV
# Momentum for particle 729 = 45.3556 GeV
# Momentum for particle 730 = 45.4095 GeV
# Momentum for particle 731 = 45.8613 GeV
# Momentum for particle 732 = 45.5581 GeV
# Momentum for particle 733 = 45.5639 GeV
# Momentum for particle 734 = 45.8158 GeV
# Momentum for particle 735 = 45.5573 GeV
# Momentum for particle 736 = 45.6157 GeV
# Momentum for particle 737 = 45.4985 GeV
# Momentum for particle 738 = 45.6151 GeV
# Momentum for particle 739 = 45.4952 GeV
# Momentum for particle 740 = 45.3989 GeV
# Momentum for particle 741 = 45.4542 GeV
# Momentum for particle 742 = 45.3860 GeV
# Momentum for particle 743 = 45.4883 GeV
# Momentum for particle 744 = 38.0806 GeV
# Momentum for particle 745 = 45.3247 GeV
# Momentum for particle 746 = 45.6401 GeV
# Momentum for particle 747 = 45.6316 GeV
# Momentum for particle 748 = 45.6110 GeV
# Momentum for particle 749 = 45.5943 GeV
# Momentum for particle 750 = 45.4746 GeV
# Momentum for particle 751 = 45.4892 GeV
# Momentum for particle 752 = 41.4901 GeV
# Momentum for particle 753 = 45.8531 GeV
# Momentum for particle 754 = 45.3860 GeV
# Momentum for particle 755 = 43.4573 GeV
# Momentum for particle 756 = 45.8918 GeV
# Momentum for particle 757 = 45.4104 GeV
# Momentum for particle 758 = 45.4605 GeV
# Momentum for particle 759 = 45.4543 GeV
# Momentum for particle 760 = 45.1959 GeV
# Momentum for particle 761 = 32.0785 GeV
# Momentum for particle 762 = 45.5818 GeV
# Momentum for particle 763 = 45.5821 GeV
# Momentum for particle 764 = 45.3945 GeV
# Momentum for particle 765 = 41.5931 GeV
# Momentum for particle 766 = 45.5856 GeV
# Momentum for particle 767 = 45.5863 GeV
# Momentum for particle 768 = 45.5854 GeV
# Momentum for particle 769 = 45.4544 GeV
# Momentum for particle 770 = 45.7729 GeV
# Momentum for particle 771 = 45.5953 GeV
# Momentum for particle 772 = 45.5574 GeV
# Momentum for particle 773 = 45.5574 GeV
# Momentum for particle 774 = 45.5574 GeV
# Momentum for particle 775 = 45.5573 GeV
# Momentum for particle 776 = 45.4915 GeV
# Momentum for particle 777 = 45.4260 GeV
# Momentum for particle 778 = 45.4260 GeV
# Momentum for particle 779 = 45.3606 GeV
# Momentum for particle 780 = 45.2955 GeV
# Momentum for particle 781 = 45.6891 GeV
# Momentum for particle 782 = 45.8215 GeV
# Momentum for particle 783 = 45.8212 GeV
# Momentum for particle 784 = 45.5318 GeV
# Momentum for particle 785 = 45.5210 GeV
# Momentum for particle 786 = 45.5407 GeV
# Momentum for particle 787 = 45.4815 GeV
# Momentum for particle 788 = 45.5868 GeV
# Momentum for particle 789 = 45.5190 GeV
# Momentum for particle 790 = 45.4204 GeV
# Momentum for particle 791 = 45.1911 GeV
# Momentum for particle 792 = 44.0725 GeV
# Momentum for particle 793 = 45.2617 GeV
# Momentum for particle 794 = 45.5466 GeV
# Momentum for particle 795 = 45.5894 GeV
# Momentum for particle 796 = 45.5208 GeV
# Momentum for particle 797 = 45.4819 GeV
# Momentum for particle 798 = 45.3581 GeV
# Momentum for particle 799 = 45.3581 GeV
# Momentum for particle 800 = 45.4139 GeV
# Momentum for particle 801 = 45.4696 GeV
# Momentum for particle 802 = 45.6589 GeV
# Momentum for particle 803 = 45.4643 GeV
# Momentum for particle 804 = 45.5443 GeV
# Momentum for particle 805 = 45.1601 GeV
# Momentum for particle 806 = 45.2238 GeV
# Momentum for particle 807 = 44.5956 GeV
# Momentum for particle 808 = 45.4210 GeV
# Momentum for particle 809 = 45.4210 GeV
# Momentum for particle 810 = 45.6624 GeV
# Momentum for particle 811 = 45.7232 GeV
# Momentum for particle 812 = 45.4213 GeV
# Momentum for particle 813 = 45.4213 GeV
# Momentum for particle 814 = 45.3612 GeV
# Momentum for particle 815 = 38.1903 GeV
# Momentum for particle 816 = 45.9010 GeV
# Momentum for particle 817 = 45.7511 GeV
# Momentum for particle 818 = 45.3734 GeV
# Momentum for particle 819 = 45.4391 GeV
# Momentum for particle 820 = 45.1122 GeV
# Momentum for particle 821 = 44.9830 GeV
# Momentum for particle 822 = 45.5718 GeV
# Momentum for particle 823 = 45.5640 GeV
# Momentum for particle 824 = 45.5011 GeV
# Momentum for particle 825 = 45.4700 GeV
# Momentum for particle 826 = 45.1487 GeV
# Momentum for particle 827 = 45.7656 GeV
# Momentum for particle 828 = 45.7304 GeV
# Momentum for particle 829 = 45.5230 GeV
# Momentum for particle 830 = 45.6530 GeV
# Momentum for particle 831 = 45.4167 GeV
# Momentum for particle 832 = 45.4167 GeV
# Momentum for particle 833 = 45.4770 GeV
# Momentum for particle 834 = 45.6583 GeV
# Momentum for particle 835 = 45.6588 GeV
# Momentum for particle 836 = 45.6588 GeV
# Momentum for particle 837 = 45.4234 GeV
# Momentum for particle 838 = 45.5447 GeV
# Momentum for particle 839 = 45.4420 GeV
# Momentum for particle 840 = 45.5373 GeV
# Momentum for particle 841 = 45.5526 GeV
# Momentum for particle 842 = 45.4839 GeV
# Momentum for particle 843 = 45.7060 GeV
# Momentum for particle 844 = 45.3993 GeV
# Momentum for particle 845 = 45.3993 GeV
# Momentum for particle 846 = 45.5831 GeV
# Momentum for particle 847 = 45.7065 GeV
# Momentum for particle 848 = 45.4918 GeV
# Momentum for particle 849 = 45.6406 GeV
# Momentum for particle 850 = 45.6099 GeV
# Momentum for particle 851 = 45.6099 GeV
# Momentum for particle 852 = 45.6099 GeV
# Momentum for particle 853 = 45.5583 GeV
# Momentum for particle 854 = 45.8116 GeV
# Momentum for particle 855 = 45.8756 GeV
# Momentum for particle 856 = 46.0689 GeV
# Momentum for particle 857 = 46.5915 GeV
# Momentum for particle 858 = 47.1936 GeV
# Momentum for particle 859 = 47.3290 GeV
# Momentum for particle 860 = 45.2170 GeV
# Momentum for particle 861 = 45.4014 GeV
# Momentum for particle 862 = 45.5408 GeV
# Momentum for particle 863 = 45.3343 GeV
# Momentum for particle 864 = 45.3343 GeV
# Momentum for particle 865 = 45.1978 GeV
# Momentum for particle 866 = 45.0621 GeV
# Momentum for particle 867 = 44.9945 GeV
# Momentum for particle 868 = 44.7931 GeV
# Momentum for particle 869 = 44.6598 GeV
# Momentum for particle 870 = 44.6598 GeV
# Momentum for particle 871 = 44.5934 GeV
# Momentum for particle 872 = 45.4708 GeV
# Momentum for particle 873 = 45.4101 GeV
# Momentum for particle 874 = 45.5819 GeV
# Momentum for particle 875 = 45.5751 GeV
# Momentum for particle 876 = 45.4852 GeV
# Momentum for particle 877 = 45.4906 GeV
# Momentum for particle 878 = 44.9897 GeV
# Momentum for particle 879 = 43.8455 GeV
# Momentum for particle 880 = 45.6383 GeV
# Momentum for particle 881 = 45.5906 GeV
# Momentum for particle 882 = 45.5928 GeV
# Momentum for particle 883 = 45.3674 GeV
# Momentum for particle 884 = 45.5454 GeV
# Momentum for particle 885 = 45.3998 GeV
# Momentum for particle 886 = 44.5008 GeV
# Momentum for particle 887 = 44.9869 GeV
# Momentum for particle 888 = 45.7343 GeV
# Momentum for particle 889 = 42.1991 GeV
# Momentum for particle 890 = 45.4427 GeV
# Momentum for particle 891 = 45.3855 GeV
# Momentum for particle 892 = 44.0868 GeV
# Momentum for particle 893 = 42.9988 GeV
# Momentum for particle 894 = 45.3589 GeV
# Momentum for particle 895 = 45.5122 GeV
# Momentum for particle 896 = 45.3955 GeV
# Momentum for particle 897 = 45.3955 GeV
# Momentum for particle 898 = 45.3954 GeV
# Momentum for particle 899 = 45.4491 GeV
# Momentum for particle 900 = 45.5574 GeV
# Momentum for particle 901 = 45.5574 GeV
# Momentum for particle 902 = 45.6664 GeV
# Momentum for particle 903 = 45.6669 GeV
# Momentum for particle 904 = 45.7767 GeV
# Momentum for particle 905 = 45.4944 GeV
# Momentum for particle 906 = 45.4944 GeV
# Momentum for particle 907 = 45.5544 GeV
# Momentum for particle 908 = 45.4237 GeV
# Momentum for particle 909 = 45.4237 GeV
# Momentum for particle 910 = 45.3694 GeV
# Momentum for particle 911 = 45.3695 GeV
# Momentum for particle 912 = 45.3152 GeV
# Momentum for particle 913 = 45.3153 GeV
# Momentum for particle 914 = 45.3701 GeV
# Momentum for particle 915 = 45.7370 GeV
# Momentum for particle 916 = 45.2505 GeV
# Momentum for particle 917 = 45.5557 GeV
# Momentum for particle 918 = 45.6526 GeV
# Momentum for particle 919 = 45.4909 GeV
# Momentum for particle 920 = 45.4909 GeV
# Momentum for particle 921 = 45.5598 GeV
# Momentum for particle 922 = 45.7670 GeV
# Momentum for particle 923 = 44.6117 GeV
# Momentum for particle 924 = 44.6117 GeV
# Momentum for particle 925 = 44.5455 GeV
# Momentum for particle 926 = 44.6116 GeV
# Momentum for particle 927 = 44.5454 GeV
# Momentum for particle 928 = 44.4794 GeV
# Momentum for particle 929 = 44.5454 GeV
# Momentum for particle 930 = 40.9788 GeV
# Momentum for particle 931 = 11.9297 GeV
# Momentum for particle 932 = 44.6697 GeV
# Momentum for particle 933 = 45.5223 GeV
# Momentum for particle 934 = 45.5872 GeV
# Momentum for particle 935 = 45.5125 GeV
# Momentum for particle 936 = 45.5225 GeV
# Momentum for particle 937 = 45.6567 GeV
# Momentum for particle 938 = 45.7779 GeV
# Momentum for particle 939 = 45.6949 GeV
# Momentum for particle 940 = 45.4186 GeV
# Momentum for particle 941 = 45.4186 GeV
# Momentum for particle 942 = 45.3638 GeV
# Momentum for particle 943 = 45.3640 GeV
# Momentum for particle 944 = 45.4740 GeV
# Momentum for particle 945 = 45.5292 GeV
# Momentum for particle 946 = 45.6399 GeV
# Momentum for particle 947 = 45.7513 GeV
# Momentum for particle 948 = 45.7517 GeV
# Momentum for particle 949 = 45.4693 GeV
# Momentum for particle 950 = 46.1655 GeV
# Momentum for particle 951 = 45.6275 GeV
# Momentum for particle 952 = 44.5846 GeV
# Momentum for particle 953 = 45.6059 GeV
# Momentum for particle 954 = 38.4175 GeV
# Momentum for particle 955 = 45.5622 GeV
# Momentum for particle 956 = 42.7321 GeV
# Momentum for particle 957 = 45.5655 GeV
# Momentum for particle 958 = 45.6314 GeV
# Momentum for particle 959 = 45.5656 GeV
# Momentum for particle 960 = 45.5656 GeV
# Momentum for particle 961 = 45.5657 GeV
# Momentum for particle 962 = 45.5657 GeV
# Momentum for particle 963 = 45.5657 GeV
# Momentum for particle 964 = 45.5658 GeV
# Momentum for particle 965 = 45.5001 GeV
# Momentum for particle 966 = 45.5001 GeV
# Momentum for particle 967 = 85.4490 GeV
# Momentum for particle 968 = 85.4490 GeV
# Momentum for particle 969 = 85.4490 GeV
# Momentum for particle 970 = 45.5527 GeV
# Momentum for particle 971 = 45.4180 GeV
# Momentum for particle 972 = 45.2527 GeV
# Momentum for particle 973 = 45.2334 GeV
# Momentum for particle 974 = 45.2047 GeV
# Momentum for particle 975 = 45.3312 GeV
# Momentum for particle 976 = 45.3124 GeV
# Momentum for particle 977 = 45.5354 GeV
# Momentum for particle 978 = 45.5354 GeV
# Momentum for particle 979 = 45.1967 GeV
# Momentum for particle 980 = 45.7410 GeV
# Momentum for particle 981 = 43.4717 GeV
# Momentum for particle 982 = 45.4975 GeV
# Momentum for particle 983 = 45.6898 GeV
# Momentum for particle 984 = 45.3850 GeV
# Momentum for particle 985 = 45.3850 GeV
# Momentum for particle 986 = 45.4449 GeV
# Momentum for particle 987 = 45.5661 GeV
# Momentum for particle 988 = 45.6267 GeV
# Momentum for particle 989 = 45.6267 GeV
# Momentum for particle 990 = 45.3850 GeV
# Momentum for particle 991 = 45.3850 GeV
# Momentum for particle 992 = 45.4449 GeV
# Momentum for particle 993 = 45.5661 GeV
# Momentum for particle 994 = 45.6267 GeV
# Momentum for particle 995 = 45.6267 GeV
# Momentum for particle 996 = 45.0269 GeV
# Momentum for particle 997 = 45.0269 GeV
# Momentum for particle 998 = 45.0858 GeV
# Momentum for particle 999 = 45.2051 GeV
# Momentum for particle 1000 = 45.2647 GeV
# Momentum for particle 1001 = 45.2647 GeV
# Momentum for particle 1002 = 46.0196 GeV
# Momentum for particle 1003 = 45.2748 GeV
# Momentum for particle 1004 = 44.3520 GeV
# Momentum for particle 1005 = 44.3520 GeV
# Momentum for particle 1006 = 44.1112 GeV
# Momentum for particle 1007 = 43.8136 GeV
# Momentum for particle 1008 = 43.6368 GeV
# Momentum for particle 1009 = 43.4036 GeV
# Momentum for particle 1010 = 43.2300 GeV
# Momentum for particle 1011 = 43.0579 GeV
# Momentum for particle 1012 = 43.0009 GeV
# Momentum for particle 1013 = 43.0010 GeV
# Momentum for particle 1014 = 45.7258 GeV
# Momentum for particle 1015 = 45.4997 GeV
# Momentum for particle 1016 = 45.7406 GeV
# Momentum for particle 1017 = 45.6166 GeV
# Momentum for particle 1018 = 45.6166 GeV
# Momentum for particle 1019 = 45.5964 GeV
# Momentum for particle 1020 = 45.6081 GeV
# Momentum for particle 1021 = 45.7396 GeV
# Momentum for particle 1022 = 45.6685 GeV
# Momentum for particle 1023 = 45.5766 GeV
# Momentum for particle 1024 = 45.5087 GeV
# Momentum for particle 1025 = 45.7994 GeV
# Momentum for particle 1026 = -45.6998 GeV
# Momentum for particle 1027 = 45.4257 GeV
# Momentum for particle 1028 = 44.9811 GeV
# Momentum for particle 1029 = 45.5004 GeV
# Momentum for particle 1030 = 45.4654 GeV
# Momentum for particle 1031 = 45.4929 GeV
# Momentum for particle 1032 = 45.5661 GeV
# Momentum for particle 1033 = 45.5677 GeV
# Momentum for particle 1034 = 45.2034 GeV
# Momentum for particle 1035 = 45.6117 GeV
# Momentum for particle 1036 = 45.4337 GeV
# Momentum for particle 1037 = 45.4142 GeV
# Momentum for particle 1038 = 44.2648 GeV
# Momentum for particle 1039 = 45.4917 GeV
# Momentum for particle 1040 = 45.4251 GeV
# Momentum for particle 1041 = 45.4251 GeV
# Momentum for particle 1042 = 45.6253 GeV
# Momentum for particle 1043 = 45.6254 GeV
# Momentum for particle 1044 = 45.1609 GeV
# Momentum for particle 1045 = 44.9875 GeV
# Momentum for particle 1046 = 45.6724 GeV
# Momentum for particle 1047 = 43.3184 GeV
# Momentum for particle 1048 = 45.5794 GeV
# Momentum for particle 1049 = 45.5796 GeV
# Momentum for particle 1050 = 45.2253 GeV
# Momentum for particle 1051 = 45.4737 GeV
# Momentum for particle 1052 = 45.4737 GeV
# Momentum for particle 1053 = 45.4063 GeV
# Momentum for particle 1054 = 45.7365 GeV
# Momentum for particle 1055 = 45.7365 GeV
# Momentum for particle 1056 = 45.7366 GeV
# Momentum for particle 1057 = 45.8046 GeV
# Momentum for particle 1058 = 45.6691 GeV
# Momentum for particle 1059 = 45.6018 GeV
# Momentum for particle 1060 = 45.4005 GeV
# Momentum for particle 1061 = 45.4977 GeV
# Momentum for particle 1062 = 45.5665 GeV
# Momentum for particle 1063 = 45.5666 GeV
# Momentum for particle 1064 = 45.5666 GeV
# Momentum for particle 1065 = 45.5666 GeV
# Momentum for particle 1066 = 45.6356 GeV
# Momentum for particle 1067 = 45.6356 GeV
# Momentum for particle 1068 = 45.6356 GeV
# Momentum for particle 1069 = 45.7049 GeV
# Momentum for particle 1070 = 45.6357 GeV
# Momentum for particle 1071 = 45.7745 GeV
# Momentum for particle 1072 = 45.4017 GeV
# Momentum for particle 1073 = 45.4414 GeV
# Momentum for particle 1074 = 45.3846 GeV
# Momentum for particle 1075 = 45.4554 GeV
# Momentum for particle 1076 = 45.6630 GeV
# Momentum for particle 1077 = 45.6854 GeV
# Momentum for particle 1078 = 45.5756 GeV
# Momentum for particle 1079 = 45.6183 GeV
# Momentum for particle 1080 = 45.7954 GeV
# Momentum for particle 1081 = 45.5226 GeV
# Momentum for particle 1082 = 45.4952 GeV
# Momentum for particle 1083 = 45.1676 GeV
# Momentum for particle 1084 = 45.5428 GeV
# Momentum for particle 1085 = 45.8959 GeV
# Momentum for particle 1086 = 45.5105 GeV
# Momentum for particle 1087 = 45.7059 GeV
# Momentum for particle 1088 = 45.5184 GeV
# Momentum for particle 1089 = 45.7793 GeV
# Momentum for particle 1090 = 45.3378 GeV
# Momentum for particle 1091 = 45.7551 GeV
# Momentum for particle 1092 = 45.7449 GeV
# Momentum for particle 1093 = 45.4192 GeV
# Momentum for particle 1094 = 45.2247 GeV
# Momentum for particle 1095 = 45.3346 GeV
# Momentum for particle 1096 = 45.3892 GeV
# Momentum for particle 1097 = 45.5160 GeV
# Momentum for particle 1098 = 45.5160 GeV
# Momentum for particle 1099 = 44.6777 GeV
# Momentum for particle 1100 = 44.3712 GeV
# Momentum for particle 1101 = 44.3712 GeV
# Momentum for particle 1102 = 32.7932 GeV
# Momentum for particle 1103 = 44.3712 GeV
# Momentum for particle 1104 = 45.2275 GeV
# Momentum for particle 1105 = 45.6626 GeV
# Momentum for particle 1106 = 45.4193 GeV
# Momentum for particle 1107 = 45.8230 GeV
# Momentum for particle 1108 = 45.4660 GeV
# Momentum for particle 1109 = 45.5349 GeV
# Momentum for particle 1110 = 45.5993 GeV
# Momentum for particle 1111 = 44.1932 GeV
# Momentum for particle 1112 = 45.6173 GeV
# Momentum for particle 1113 = 45.5153 GeV
# Momentum for particle 1114 = 45.3204 GeV
# Momentum for particle 1115 = 45.3204 GeV
# Momentum for particle 1116 = 45.3889 GeV
# Momentum for particle 1117 = 45.5334 GeV
# Momentum for particle 1118 = 45.5390 GeV
# Momentum for particle 1119 = 45.5252 GeV
# Momentum for particle 1120 = 42.4925 GeV
# Momentum for particle 1121 = 45.0904 GeV
# Momentum for particle 1122 = 45.6533 GeV
# Momentum for particle 1123 = 45.6533 GeV
# Momentum for particle 1124 = 45.7135 GeV
# Momentum for particle 1125 = 45.7737 GeV
# Momentum for particle 1126 = 45.7739 GeV
# Momentum for particle 1127 = 45.7132 GeV
# Momentum for particle 1128 = 45.7132 GeV
# Momentum for particle 1129 = 45.7735 GeV
# Momentum for particle 1130 = 45.8339 GeV
# Momentum for particle 1131 = 45.8342 GeV
# Momentum for particle 1132 = 45.7128 GeV
# Momentum for particle 1133 = 45.7128 GeV
# Momentum for particle 1134 = 45.7731 GeV
# Momentum for particle 1135 = 45.6532 GeV
# Momentum for particle 1136 = 45.6532 GeV
# Momentum for particle 1137 = 45.7133 GeV
# Momentum for particle 1138 = 45.7735 GeV
# Momentum for particle 1139 = 45.4152 GeV
# Momentum for particle 1140 = 45.4152 GeV
# Momentum for particle 1141 = 45.4748 GeV
# Momentum for particle 1142 = 45.5343 GeV
# Momentum for particle 1143 = 45.5346 GeV
# Momentum for particle 1144 = 45.4748 GeV
# Momentum for particle 1145 = 45.4748 GeV
# Momentum for particle 1146 = 45.5345 GeV
# Momentum for particle 1147 = 45.5942 GeV
# Momentum for particle 1148 = 45.5945 GeV
# Momentum for particle 1149 = 45.4757 GeV
# Momentum for particle 1150 = 45.5343 GeV
# Momentum for particle 1151 = 45.5343 GeV
# Momentum for particle 1152 = 45.5942 GeV
# Momentum for particle 1153 = 45.6541 GeV
# Momentum for particle 1154 = 45.6544 GeV
# Momentum for particle 1155 = 45.5353 GeV
# Momentum for particle 1156 = 45.5941 GeV
# Momentum for particle 1157 = 45.5941 GeV
# Momentum for particle 1158 = 45.6541 GeV
# Momentum for particle 1159 = 45.7141 GeV
# Momentum for particle 1160 = 45.7144 GeV
# Momentum for particle 1161 = 45.5950 GeV
# Momentum for particle 1162 = 45.5345 GeV
# Momentum for particle 1163 = 45.5345 GeV
# Momentum for particle 1164 = 45.5943 GeV
# Momentum for particle 1165 = 45.6542 GeV
# Momentum for particle 1166 = 45.6545 GeV
# Momentum for particle 1167 = 45.5354 GeV
# Momentum for particle 1168 = 45.5343 GeV
# Momentum for particle 1169 = 45.5343 GeV
# Momentum for particle 1170 = 45.5942 GeV
# Momentum for particle 1171 = 45.6541 GeV
# Momentum for particle 1172 = 45.6544 GeV
# Momentum for particle 1173 = 45.5353 GeV
# Momentum for particle 1174 = 45.4750 GeV
# Momentum for particle 1175 = 45.7717 GeV
# Momentum for particle 1176 = 45.7788 GeV
# Momentum for particle 1177 = 45.4386 GeV
# Momentum for particle 1178 = 45.4386 GeV
# Momentum for particle 1179 = 45.5984 GeV
# Momentum for particle 1180 = 45.4385 GeV
# Momentum for particle 1181 = 45.3325 GeV
# Momentum for particle 1182 = 45.2271 GeV
# Momentum for particle 1183 = 45.1224 GeV
# Momentum for particle 1184 = 45.1224 GeV
# Momentum for particle 1185 = 45.1229 GeV
# Momentum for particle 1186 = 45.1755 GeV
# Momentum for particle 1187 = 45.6105 GeV
# Momentum for particle 1188 = 45.2494 GeV
# Momentum for particle 1189 = 45.2494 GeV
# Momentum for particle 1190 = 45.3178 GeV
# Momentum for particle 1191 = 45.3178 GeV
# Momentum for particle 1192 = 45.2494 GeV
# Momentum for particle 1193 = 45.2495 GeV
# Momentum for particle 1194 = 45.3328 GeV
# Momentum for particle 1195 = 45.5045 GeV
# ...
# Momentum for particle 2302 = 45.2486 GeV
# Momentum for particle 2303 = 45.1442 GeV
# Momentum for particle 2304 = 45.6505 GeV
# Momentum for particle 2305 = 45.6305 GeV
# Momentum for particle 2306 = 45.5777 GeV
# Momentum for particle 2307 = 45.3732 GeV
# Momentum for particle 2308 = 45.2682 GeV
# Momentum for particle 2309 = 45.7773 GeV
# Momentum for particle 2310 = 45.7572 GeV
# Momentum for particle 2311 = 45.7041 GeV
# Momentum for particle 2312 = 45.4985 GeV
# Momentum for particle 2313 = 45.3929 GeV
# Momentum for particle 2314 = 45.9183 GeV
# Momentum for particle 2315 = 45.8981 GeV
# Momentum for particle 2316 = 45.8447 GeV
# Momentum for particle 2317 = 45.6378 GeV
# Momentum for particle 2318 = 45.5315 GeV
# Momentum for particle 2319 = 46.1418 GeV
# Momentum for particle 2320 = 46.1214 GeV
# Momentum for particle 2321 = 46.0675 GeV
# Momentum for particle 2322 = 45.8586 GeV
# Momentum for particle 2323 = 45.7513 GeV
# Momentum for particle 2324 = 46.0944 GeV
# Momentum for particle 2325 = 46.0740 GeV
# Momentum for particle 2326 = 46.0202 GeV
# Momentum for particle 2327 = 45.8117 GeV
# Momentum for particle 2328 = 45.7046 GeV
# Momentum for particle 2329 = 46.1554 GeV
# Momentum for particle 2330 = 46.1350 GeV
# Momentum for particle 2331 = 46.0811 GeV
# Momentum for particle 2332 = 45.8720 GeV
# Momentum for particle 2333 = 45.7647 GeV
# Momentum for particle 2334 = 46.1554 GeV
# Momentum for particle 2335 = 46.1350 GeV
# Momentum for particle 2336 = 46.0811 GeV
# Momentum for particle 2337 = 45.8720 GeV
# Momentum for particle 2338 = 45.7647 GeV
# Momentum for particle 2339 = 45.8753 GeV
# Momentum for particle 2340 = 43.6523 GeV
# Momentum for particle 2341 = 45.6495 GeV
# Momentum for particle 2342 = 45.5843 GeV
# Momentum for particle 2343 = 45.7441 GeV
# Momentum for particle 2344 = 38.7150 GeV
# Momentum for particle 2345 = 45.5351 GeV
# Momentum for particle 2346 = 45.5452 GeV
# Momentum for particle 2347 = 44.9517 GeV
# Momentum for particle 2348 = 44.6928 GeV
# Momentum for particle 2349 = 45.7708 GeV
# Momentum for particle 2350 = 45.4362 GeV
# Momentum for particle 2351 = 45.6151 GeV
# Momentum for particle 2352 = 45.5868 GeV
# Momentum for particle 2353 = 45.3219 GeV
# Momentum for particle 2354 = 45.6009 GeV
# Momentum for particle 2355 = 45.5954 GeV
# Momentum for particle 2356 = 45.4435 GeV
# Momentum for particle 2357 = 45.2707 GeV
# Momentum for particle 2358 = 45.2221 GeV
# Momentum for particle 2359 = 45.1629 GeV
# Momentum for particle 2360 = 45.1575 GeV
# Momentum for particle 2361 = 45.1413 GeV
# Momentum for particle 2362 = 45.1145 GeV
# Momentum for particle 2363 = 45.0666 GeV
# Momentum for particle 2364 = 45.0241 GeV
# Momentum for particle 2365 = 45.0136 GeV
# Momentum for particle 2366 = 45.0031 GeV
# Momentum for particle 2367 = 44.9925 GeV
# Momentum for particle 2368 = 25.8920 GeV
# Momentum for particle 2369 = 37.0661 GeV
# Momentum for particle 2370 = 45.6991 GeV
# Momentum for particle 2371 = 45.5186 GeV
# Momentum for particle 2372 = 45.8622 GeV
# Momentum for particle 2373 = 45.4647 GeV
# Momentum for particle 2374 = 45.3694 GeV
# Momentum for particle 2375 = 27.3464 GeV
# Momentum for particle 2376 = 27.3600 GeV
# Momentum for particle 2377 = 27.3948 GeV
# Momentum for particle 2378 = 27.4277 GeV
# Momentum for particle 2379 = 27.2433 GeV
# Momentum for particle 2380 = 27.3446 GeV
# Momentum for particle 2381 = 27.3118 GeV
# Momentum for particle 2382 = 45.4559 GeV
# Momentum for particle 2383 = 45.9048 GeV
# Momentum for particle 2384 = 45.4143 GeV
# Momentum for particle 2385 = 45.4205 GeV
# Momentum for particle 2386 = 45.3999 GeV
# Momentum for particle 2387 = 45.4342 GeV
# Momentum for particle 2388 = 45.3657 GeV
# Momentum for particle 2389 = 44.9185 GeV
# Momentum for particle 2390 = 45.3589 GeV
# Momentum for particle 2391 = 45.0126 GeV
# Momentum for particle 2392 = 25.2803 GeV
# Momentum for particle 2393 = 45.1470 GeV
# Momentum for particle 2394 = 45.1470 GeV
# Momentum for particle 2395 = 45.2506 GeV
# Momentum for particle 2396 = 45.2506 GeV
# Momentum for particle 2397 = 45.7869 GeV
# Momentum for particle 2398 = 45.5267 GeV
# Momentum for particle 2399 = 45.5650 GeV
# Momentum for particle 2400 = 45.3503 GeV
# Momentum for particle 2401 = 45.6656 GeV
# Momentum for particle 2402 = 45.4898 GeV
# Momentum for particle 2403 = 45.4728 GeV
# Momentum for particle 2404 = 45.6266 GeV
# Momentum for particle 2405 = 45.7987 GeV
# Momentum for particle 2406 = 45.9950 GeV
# Momentum for particle 2407 = 46.2512 GeV
# Momentum for particle 2408 = 45.6148 GeV
# Momentum for particle 2409 = 45.3327 GeV
# Momentum for particle 2410 = 45.3258 GeV
# Momentum for particle 2411 = 45.3532 GeV
# Momentum for particle 2412 = 45.3874 GeV
# Momentum for particle 2413 = 45.3173 GeV
# Momentum for particle 2414 = 44.9925 GeV
# Momentum for particle 2415 = 45.6221 GeV
# Momentum for particle 2416 = 45.5665 GeV
# Momentum for particle 2417 = 45.5697 GeV
# Momentum for particle 2418 = 45.8228 GeV
# Momentum for particle 2419 = 45.7158 GeV
# Momentum for particle 2420 = 45.4747 GeV
# Momentum for particle 2421 = 45.4747 GeV
# Momentum for particle 2422 = 45.8394 GeV
# Momentum for particle 2423 = 46.0861 GeV
# Momentum for particle 2424 = 46.0246 GeV
# Momentum for particle 2425 = 45.9633 GeV
# Momentum for particle 2426 = 45.9634 GeV
# Momentum for particle 2427 = 45.5299 GeV
# Momentum for particle 2428 = 45.4864 GeV
# Momentum for particle 2429 = 45.4802 GeV
# Momentum for particle 2430 = 45.5732 GeV
# Momentum for particle 2431 = 45.5302 GeV
# Momentum for particle 2432 = 45.6827 GeV
# Momentum for particle 2433 = 46.0109 GeV
# Momentum for particle 2434 = 45.4760 GeV
# Momentum for particle 2435 = 45.1224 GeV
# Momentum for particle 2436 = 45.1161 GeV
# Momentum for particle 2437 = 45.0410 GeV
# Momentum for particle 2438 = 45.0284 GeV
# Momentum for particle 2439 = 45.0409 GeV
# Momentum for particle 2440 = 45.0597 GeV
# Momentum for particle 2441 = 45.0659 GeV
# Momentum for particle 2442 = 45.7581 GeV
# Momentum for particle 2443 = 44.9717 GeV
# Momentum for particle 2444 = 44.9586 GeV
# Momentum for particle 2445 = 45.4219 GeV
# Momentum for particle 2446 = 37.7577 GeV
# Momentum for particle 2447 = 45.6909 GeV
# Momentum for particle 2448 = 45.6909 GeV
# Momentum for particle 2449 = 45.6217 GeV
# Momentum for particle 2450 = 45.6218 GeV
# Momentum for particle 2451 = 45.1457 GeV
# Momentum for particle 2452 = 45.8115 GeV
# Momentum for particle 2453 = 45.7706 GeV
# Momentum for particle 2454 = 45.7637 GeV
# Momentum for particle 2455 = 45.8263 GeV
# Momentum for particle 2456 = 45.9031 GeV
# Momentum for particle 2457 = 45.9381 GeV
# Momentum for particle 2458 = 45.5624 GeV
# Momentum for particle 2459 = 45.5693 GeV
# Momentum for particle 2460 = 29.3260 GeV
# Momentum for particle 2461 = 45.2887 GeV
# Momentum for particle 2462 = 45.6395 GeV
# Momentum for particle 2463 = 45.5571 GeV
# Momentum for particle 2464 = 45.6497 GeV
# Momentum for particle 2465 = 41.7182 GeV
# Momentum for particle 2466 = 45.5036 GeV
# Momentum for particle 2467 = 45.6383 GeV
# Momentum for particle 2468 = 45.4914 GeV
# Momentum for particle 2469 = 45.6053 GeV
# Momentum for particle 2470 = 45.5716 GeV
# Momentum for particle 2471 = 45.4563 GeV
# Momentum for particle 2472 = 45.3562 GeV
# Momentum for particle 2473 = 45.9098 GeV
# Momentum for particle 2474 = 45.5946 GeV
# Momentum for particle 2475 = 45.2513 GeV
# Momentum for particle 2476 = 45.6878 GeV
# Momentum for particle 2477 = 45.3976 GeV
# Momentum for particle 2478 = 45.4054 GeV
# Momentum for particle 2479 = 45.5543 GeV
# Momentum for particle 2480 = 45.6933 GeV
# Momentum for particle 2481 = 45.6863 GeV
# Momentum for particle 2482 = 45.9381 GeV
# Momentum for particle 2483 = 46.1855 GeV
# Momentum for particle 2484 = 46.3066 GeV
# Momentum for particle 2485 = 45.6863 GeV
# Momentum for particle 2486 = 45.4820 GeV
# Momentum for particle 2487 = 44.1982 GeV
# Momentum for particle 2488 = 45.6241 GeV
# Momentum for particle 2489 = 45.4875 GeV
# Momentum for particle 2490 = 45.6076 GeV
# Momentum for particle 2491 = 45.7885 GeV
# Momentum for particle 2492 = 44.2554 GeV
# Momentum for particle 2493 = 45.2756 GeV
# Momentum for particle 2494 = 45.4549 GeV
# Momentum for particle 2495 = 45.6303 GeV
# Momentum for particle 2496 = 45.6304 GeV
# Momentum for particle 2497 = 45.6304 GeV
# Momentum for particle 2498 = 45.9702 GeV
# Momentum for particle 2499 = 46.3152 GeV
# Momentum for particle 2500 = 46.5952 GeV
# Momentum for particle 2501 = 46.5954 GeV
# Momentum for particle 2502 = 45.4884 GeV
# Momentum for particle 2503 = 45.5407 GeV
# Momentum for particle 2504 = 45.5197 GeV
# Momentum for particle 2505 = 45.0253 GeV
# Momentum for particle 2506 = 45.5205 GeV
# Momentum for particle 2507 = 45.5472 GeV
# Momentum for particle 2508 = 45.5405 GeV
# Momentum for particle 2509 = 45.5271 GeV
# Momentum for particle 2510 = 45.5675 GeV
# Momentum for particle 2511 = 45.5271 GeV
# Momentum for particle 2512 = 45.4868 GeV
# Momentum for particle 2513 = 45.5069 GeV
# Momentum for particle 2514 = 45.5338 GeV
# Momentum for particle 2515 = 45.5607 GeV
# Momentum for particle 2516 = 45.5338 GeV
# Momentum for particle 2517 = 45.6621 GeV
# Momentum for particle 2518 = 45.5409 GeV
# Momentum for particle 2519 = 44.4573 GeV
# Momentum for particle 2520 = 45.3333 GeV
# Momentum for particle 2521 = 41.4758 GeV
# Momentum for particle 2522 = 41.4758 GeV
# Momentum for particle 2523 = 41.6468 GeV
# Momentum for particle 2524 = 41.8191 GeV
# Momentum for particle 2525 = 41.9348 GeV
# Momentum for particle 2526 = 45.2979 GeV
# Momentum for particle 2527 = 45.4938 GeV
# Momentum for particle 2528 = 45.5248 GeV
# Momentum for particle 2529 = 45.5922 GeV
# Momentum for particle 2530 = 45.8573 GeV
# Momentum for particle 2531 = 45.5689 GeV
# Momentum for particle 2532 = 45.6535 GeV
# Momentum for particle 2533 = 45.5268 GeV
# Momentum for particle 2534 = 45.3479 GeV
# Momentum for particle 2535 = 45.7481 GeV
# Momentum for particle 2536 = 45.7674 GeV
# Momentum for particle 2537 = 45.6041 GeV
# Momentum for particle 2538 = 45.6554 GeV
# Momentum for particle 2539 = 45.4515 GeV
# Momentum for particle 2540 = 45.4515 GeV
# Momentum for particle 2541 = 45.3212 GeV
# Momentum for particle 2542 = 45.1914 GeV
# Momentum for particle 2543 = 45.4106 GeV
# Momentum for particle 2544 = 45.4673 GeV
# Momentum for particle 2545 = 45.5930 GeV
# Momentum for particle 2546 = 45.6552 GeV
# Momentum for particle 2547 = 45.6662 GeV
# Momentum for particle 2548 = 45.4890 GeV
# Momentum for particle 2549 = 45.4890 GeV
# Momentum for particle 2550 = 45.4891 GeV
# Momentum for particle 2551 = 45.4213 GeV
# Momentum for particle 2552 = 45.4213 GeV
# Momentum for particle 2553 = 45.4214 GeV
# Momentum for particle 2554 = 45.3538 GeV
# Momentum for particle 2555 = 45.2192 GeV
# Momentum for particle 2556 = 45.2191 GeV
# Momentum for particle 2557 = 42.0177 GeV
# Momentum for particle 2558 = 34.3633 GeV
# Momentum for particle 2559 = 45.7772 GeV
# Momentum for particle 2560 = 45.6126 GeV
# Momentum for particle 2561 = 45.5424 GeV
# Momentum for particle 2562 = 45.3489 GeV
# Momentum for particle 2563 = 45.3847 GeV
# Momentum for particle 2564 = 45.4052 GeV
# Momentum for particle 2565 = 45.5524 GeV
# Momentum for particle 2566 = 45.4795 GeV
# Momentum for particle 2567 = 45.3924 GeV
# Momentum for particle 2568 = 45.5739 GeV
# Momentum for particle 2569 = 45.5384 GeV
# Momentum for particle 2570 = 45.5853 GeV
# Momentum for particle 2571 = 45.5233 GeV
# Momentum for particle 2572 = 45.1955 GeV
# Momentum for particle 2573 = 45.7453 GeV
# Momentum for particle 2574 = 45.4397 GeV
# Momentum for particle 2575 = 45.5399 GeV
# Momentum for particle 2576 = 45.3321 GeV
# Momentum for particle 2577 = 45.3914 GeV
# Momentum for particle 2578 = 45.1555 GeV
# Momentum for particle 2579 = 44.6333 GeV
# Momentum for particle 2580 = 44.2919 GeV
# Momentum for particle 2581 = 45.0545 GeV
# Momentum for particle 2582 = 45.0662 GeV
# Momentum for particle 2583 = 44.7702 GeV
# Momentum for particle 2584 = 44.6667 GeV
# Momentum for particle 2585 = 45.6095 GeV
# Momentum for particle 2586 = 45.4718 GeV
# Momentum for particle 2587 = 45.5643 GeV
# Momentum for particle 2588 = 45.5643 GeV
# Momentum for particle 2589 = 45.9028 GeV
# Momentum for particle 2590 = 45.6317 GeV
# Momentum for particle 2591 = 45.2308 GeV
# Momentum for particle 2592 = 45.7330 GeV
# Momentum for particle 2593 = 45.4921 GeV
# Momentum for particle 2594 = 45.5386 GeV
# Momentum for particle 2595 = 45.5386 GeV
# Momentum for particle 2596 = 45.6720 GeV
# Momentum for particle 2597 = 45.8061 GeV
# Momentum for particle 2598 = 45.2843 GeV
# Momentum for particle 2599 = 45.6706 GeV
# Momentum for particle 2600 = 45.6706 GeV
# Momentum for particle 2601 = 45.6452 GeV
# Momentum for particle 2602 = 43.1107 GeV
# Momentum for particle 2603 = 43.1107 GeV
# Momentum for particle 2604 = 43.0493 GeV
# Momentum for particle 2605 = 42.9270 GeV
# Momentum for particle 2606 = 42.8054 GeV
# Momentum for particle 2607 = 42.8661 GeV
# Momentum for particle 2608 = 43.1107 GeV
# Momentum for particle 2609 = 43.1107 GeV
# Momentum for particle 2610 = 43.0493 GeV
# Momentum for particle 2611 = 42.9270 GeV
# Momentum for particle 2612 = 42.8054 GeV
# Momentum for particle 2613 = 42.8661 GeV
# Momentum for particle 2614 = 43.0495 GeV
# Momentum for particle 2615 = 43.0495 GeV
# Momentum for particle 2616 = 42.9882 GeV
# Momentum for particle 2617 = 42.8662 GeV
# Momentum for particle 2618 = 42.7450 GeV
# Momentum for particle 2619 = 42.8056 GeV
# Momentum for particle 2620 = 45.2698 GeV
# Momentum for particle 2621 = 45.9450 GeV
# Momentum for particle 2622 = 45.9292 GeV
# Momentum for particle 2623 = 45.5506 GeV
# Momentum for particle 2624 = 45.8030 GeV
# Momentum for particle 2625 = 45.6893 GeV
# Momentum for particle 2626 = 42.0216 GeV
# Momentum for particle 2627 = 41.5542 GeV
# Momentum for particle 2628 = 45.5727 GeV
# Momentum for particle 2629 = 45.4687 GeV
# Momentum for particle 2630 = 45.9464 GeV
# Momentum for particle 2631 = 45.7770 GeV
# Momentum for particle 2632 = 45.8573 GeV
# Momentum for particle 2633 = 32.7520 GeV
# Momentum for particle 2634 = 32.7674 GeV
# Momentum for particle 2635 = 32.8167 GeV
# Momentum for particle 2636 = 32.8661 GeV
# Momentum for particle 2637 = 32.9218 GeV
# Momentum for particle 2638 = 32.8044 GeV
# Momentum for particle 2639 = 32.6724 GeV
# Momentum for particle 2640 = 32.6449 GeV
# Momentum for particle 2641 = 45.7894 GeV
# Momentum for particle 2642 = 45.5943 GeV
# Momentum for particle 2643 = 45.5943 GeV
# Momentum for particle 2644 = 45.5945 GeV
# Momentum for particle 2645 = 45.6593 GeV
# Momentum for particle 2646 = 45.6595 GeV
# Momentum for particle 2647 = 45.6597 GeV
# Momentum for particle 2648 = 45.5303 GeV
# Momentum for particle 2649 = 45.5901 GeV
# Momentum for particle 2650 = 45.2331 GeV
# Momentum for particle 2651 = 45.6115 GeV
# Momentum for particle 2652 = 45.5792 GeV
# Momentum for particle 2653 = 45.6866 GeV
# Momentum for particle 2654 = 45.4330 GeV
# Momentum for particle 2655 = 45.6814 GeV
# Momentum for particle 2656 = 45.4067 GeV
# Momentum for particle 2657 = 45.4062 GeV
# Momentum for particle 2658 = 45.6103 GeV
# Momentum for particle 2659 = 45.6365 GeV
# Momentum for particle 2660 = 45.4264 GeV
# Momentum for particle 2661 = 45.5591 GeV
# Momentum for particle 2662 = 45.4680 GeV
# Momentum for particle 2663 = 45.4680 GeV
# Momentum for particle 2664 = 45.5303 GeV
# Momentum for particle 2665 = 45.6274 GeV
# Momentum for particle 2666 = 45.5168 GeV
# Momentum for particle 2667 = 45.3275 GeV
# Momentum for particle 2668 = 45.5002 GeV
# Momentum for particle 2669 = 45.8094 GeV
# Momentum for particle 2670 = 45.6468 GeV
# Momentum for particle 2671 = 45.5063 GeV
# Momentum for particle 2672 = 45.5594 GeV
# Momentum for particle 2673 = 45.3485 GeV
# Momentum for particle 2674 = 45.1914 GeV
# Momentum for particle 2675 = 45.2442 GeV
# Momentum for particle 2676 = 45.2969 GeV
# Momentum for particle 2677 = 45.3497 GeV
# Momentum for particle 2678 = 45.4024 GeV
# Momentum for particle 2679 = 45.4026 GeV
# Momentum for particle 2680 = 45.4076 GeV
# Momentum for particle 2681 = 45.1465 GeV
# Momentum for particle 2682 = 43.7632 GeV
# Momentum for particle 2683 = 44.5943 GeV
# Momentum for particle 2684 = 42.0814 GeV
# Momentum for particle 2685 = 42.0814 GeV
# Momentum for particle 2686 = 42.0239 GeV
# Momentum for particle 2687 = 41.9667 GeV
# Momentum for particle 2688 = 41.9095 GeV
# Momentum for particle 2689 = 41.7958 GeV
# Momentum for particle 2690 = 30.6465 GeV
# Momentum for particle 2691 = 45.1202 GeV

# %% [markdown]
# # Part 4
#
# ##### In this question, the existence of double counting has become an unignorable nuisance. Therefore, I will average over all the values corresponding to a similar theta to the true data and treat them as a single average particle.

# %%
# Part 4

subtracted_momenta = []
accepted_momenta = []
counter = 0

for i in range(1000):
    theta1 = truthData.iloc[2*i,2]
    mom1 = truthData.iloc[2*i,3]
    theta2 = truthData.iloc[2*i+1,2]
    mom2 = truthData.iloc[2*i+1,3]
    if len(np.array(pair_phi_values[i])>0): # remove all events without pairs
        p1 = []
        p2 = []
        for j in np.mean(pair_theta_values[i],axis=1): # Loop over all theta pairs
            if math.fabs(j-theta1) < 0.001: # Finds the particle corresponding to true theta1 value
                p1.append(p[counter]) #appends the corresponding momentum
                counter += 1 #Ensures we keep up with the position of the momentum array
            elif math.fabs(j-theta2) < 0.001: # Finds the particle corresponding to true theta2 value
                p2.append(p[counter]) #appends the corresponding momentum
                counter += 1 #Ensures we keep up with the position of the momentum array
            else:
                counter += 1 # If not close to anything, the corresponded momentum will be ignored
        if len(p1)>0: # Ensures no errors are thrown in case of an empty list
            subtracted_momenta.append(np.mean(p1)-mom1) # Subtracts the calculated value from the true value
            accepted_momenta.append(mom1) # Ensures we subtract the correct true momenta
        if len(p2)>0: # Same as above but for particle 2 rather than particle 1
            subtracted_momenta.append(np.mean(p2)-mom2)
            accepted_momenta.append(mom2)

# %%
calibrated_p = np.asarray(subtracted_momenta)/np.asarray(accepted_momenta) # Find the calibration value

# Plotting the calibration values
plt.hist(calibrated_p,bins = 100)
plt.title("Histogram of all the calibrated momenta")
plt.xlabel("($P_{cal}-P_{true})/P_{true}$")
plt.ylabel("Frequency")
plt.show()
# Removing outliers to get a clearer picture
plt.hist(calibrated_p[(calibrated_p<0.1) & (calibrated_p>-0.1)],bins=100)
plt.title("Histogram of calibrated momenta between $\pm0.1$")
plt.xlabel("($P_{cal}-P_{true})/P_{true}$")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# # Part 5

# %%
reconstructed_e = []
count = 0

# Loop over all momenta events
for i in range(1000):
    if len(pair_theta_values[i]) == 2: # Only accept values with exactly 2 pairs
        reconstructed_e.append(p[count]+p[count+1]) 
        count += 2 # Ensure we keep up with the position in the p array
    else:
        count += len(pair_theta_values[i]) # Ensure we keep up with the position in the p array
        
reconstructed_e = np.asarray(reconstructed_e) 

# Plot histogram of all values
plt.hist(reconstructed_e,bins=100)
plt.title("Mass Distribution of the Detected Particle Mass")
plt.xlabel("Mass (GeV)")
plt.ylabel("Frequency")
plt.show()
# Remove outliers
plt.hist(reconstructed_e[(reconstructed_e>80) & (reconstructed_e<100)],bins=100)
plt.title("Constrained Mass Distribution of the Detected Particle Mass")
plt.xlabel("Mass (GeV)")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# Looking at these graphs, it appears the majority of data points lie within 90-92 GeV. As a result, the particle mass will be equal to the mean value within this range. On top of this, the width of the mass will be equal to the standard deviation of this range.

# %%
mass = np.mean(reconstructed_e[(reconstructed_e>90) & (reconstructed_e<92)])
width = np.std(reconstructed_e[(reconstructed_e>90) & (reconstructed_e<92)])
print("Mass of particle = {:.4f} GeV with partial decay width = {:.4f} GeV".format(mass,width))
# Out:
# Mass of particle = 91.0438 GeV with partial decay width = 0.3049 GeV

# %% [markdown]
# The mass of this particle lies very close to the mass of the Z boson, given by the PDG value of 91.1876 GeV. The partial decay width, $\Gamma_{\mu\mu}$, of this particle is significantly greater than the one given by the PDG value (0.09 GeV) but that is likely due to the approximations we made in our data analysis giving us a wider peak. On top of this, the Z-boson decay $Z\rightarrow\mu^++\mu^-$ is an allowed decay so the result makes perfect sense.
